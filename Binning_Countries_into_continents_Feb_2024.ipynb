# %% [markdown]
# # Binning Countries into continents

# %%
#DISCLAIMER: ChatGPT was utilised to prepare the initial continent lists of countries

# %%
# Country codes and continent groups generated by ChatGPT
country_codes = [
    "US", "RU", "CN", "GB", "BE", "AU", "IR", "FR", "CZ", "JP", 
    "IT", "PL", "CL", "DE", "ES", "MX", "CH", "NL", "UA", "NZ", 
    "CA", "FI", "IN", "TW", "SA", "TH", "EG", "RS", "ZA", "DK", 
    "KR", "TJ", "BR", "HK", "SE", "PT", "LT", "SG", "AZ", "LV", 
    "GR", "ID", "AE", "TR", "PK", "AR", "HU", "IL", "BG", "NO", 
    "NG", "AT", "BO", "BY", "EE", "IS", "IE", "PR", "SI", "SK", 
    "KE", "GP", "BZ", "VN", "LB", "AM", "RO", "NP", "MM", "IQ", 
    "RW", "GE", "EC", "KZ", "MA", "BD", "HR", "UY", "CO", "CU", 
    "DZ", "LY", "MY", "TN", "LK", "MK", "AL", "VA", "GH", "BA", 
    "UZ", "VE", "MO", "CM", "MN", "FJ", "OM", "ET", "MG", "QA", 
    "MZ", "CG", "CY", "PE", "SD", "ZW", "BW", "KW", "JO", "MT", 
    "PF", "KG", "BF", "LU", "NI", "KH", "CR", "SV", "UG", "ME", 
    "ZM", "TZ", "PH", "MD", "PA", "BN", "SY", "PG", "GT", "PS", 
    "HN", "BH", "CD", "LI", "YE", "NC", "NE", "MC", "GA", "JM", 
    "CI", "BJ", "ST", "NA", "BB", "GD", "SN", "BI", "MW", "SS", 
    "MU", "SZ", "GL", "TT", "VG", "BS", "DO", "XK", "GM", "CF", 
    "PY", "MS", "BT", "GU", "SJ", "TG", "HT", "RE", "AX", "AF", 
    "SC", "VU", "KP", "MV", "LA", "FO", "MR", "SX", "AO", "LS", 
    "WS", "ML", "TM", "LR", "TC", "PW", "TO", "GI", "GF", "DM", 
    "JE", "BM", "KN", "FK", "SL", "AG", "GW", "TD"
]

north_south_america_codes = [
    "US", "MX", "CA", "BR", "AR", "CL", "CO", "VE", "PE", "EC", 
    "UY", "PY", "BO", "PR", "CU", "DO", "GT", "HN", "CR", "PA", 
    "NI", "SV", "BZ", "JM", "TT", "BS", "VG", "GD", "BB", "KN", 
    "AG", "DM", "GP", "GF", "MS", "FK"
]

asia_oceania_codes = [
    "CN", "JP", "IN", "KR", "ID", "TH", "PK", "MY", "PH", "VN", 
    "LK", "BD", "NP", "MM", "TW", "HK", "SG", "MN", "KH", "LA", 
    "BT", "MO", "BN", "MV", "AU", "NZ", "PG", "FJ", 
    "VU", "NC", "PF", "GU", "WS", "NC", "TO", "PW"
]

europe_codes = [
    "RU", "GB", "FR", "DE", "IT", "ES", "PL", "RO", "NL", "BE", 
    "GR", "CZ", "PT", "SE", "HU", "BY", "AT", "CH", "DK", "FI", 
    "SK", "NO", "IE", "HR", "SI", "LV", "LT", "EE", "IS", "MT", 
    "LU", "MC", "VA", "RS", "ME", "MK", "AL", "BA", 
    "XK", "UA", "MD", "BG", "CY", "TR", "GE", "AM", "AZ", "LI"
]

africa_codes = [
    "DZ", "AO", "EG", "LY", "MA", "SD", "TN", "ET", "KE", "TZ", 
    "UG", "DZ", "NG", "GH", "CI", "SN", "ML", "CD", "ZW", 
    "RW", "ZM", "MG", "MW", "AO", "CM", "BF", "NE", "MU", 
    "MZ", "LS", "BW", "GM", "TD", "CG", "NA", "SS", "SZ", "BJ", 
    "LR", "SL", "GW", "TG", "CF", "CI", "GA", 
    "ST", "SC", "MR", "BI", "RE"
]

# %%
# Removing duplicate entries if any in each list
country_codes_set = set(country_codes)
north_south_america_set = set(north_south_america_codes)
asia_oceania_set = set(asia_oceania_codes)
europe_set = set(europe_codes)
africa_set = set(africa_codes)

# Combining all the continent sets
combined_continents_set = north_south_america_set.union(asia_oceania_set, europe_set, africa_set)

# Count of unique country codes and combined continents
unique_country_codes_count = len(country_codes_set)
combined_continents_count = len(combined_continents_set)

(unique_country_codes_count, combined_continents_count)
# Out:
# (198, 166)

# %%
# Checking if all continent countries are part of country_codes
are_all_continents_in_country_codes = combined_continents_set.issubset(country_codes_set)

# Result
are_all_continents_in_country_codes
# Out:
# True

# %%
# Finding countries in the continent groups not in country_codes
countries_not_in_country_codes = combined_continents_set - country_codes_set

# Listing these countries
list(countries_not_in_country_codes)
# Out:
# []

# %%
# Finding countries in country_codes not mentioned in any continent list
countries_in_country_codes_not_in_continents = country_codes_set - combined_continents_set

# Listing these countries
list(countries_in_country_codes_not_in_continents)
# Out:
# ['KW',
#  'SJ',
#  'AF',
#  'AE',
#  'SY',
#  'JE',
#  'TJ',
#  'BM',
#  'KZ',
#  'KG',
#  'TC',
#  'IL',
#  'PS',
#  'LB',
#  'KP',
#  'HT',
#  'BH',
#  'ZA',
#  'SX',
#  'IQ',
#  'YE',
#  'JO',
#  'IR',
#  'AX',
#  'QA',
#  'FO',
#  'GI',
#  'OM',
#  'UZ',
#  'TM',
#  'GL',
#  'SA']

# %%
north_south_america_codes = north_south_america_codes + ['HT']  # Haiti is in the North American continent, part of the Caribbean
europe_codes = europe_codes + ['SJ', 'JE', 'AX', 'FO', 'GI', 'BM', 'TC', 'SX', 'GL']  # Including territories often associated with Europe
africa_codes = africa_codes + ['ZA']  # South Africa
asia_oceania_codes = asia_oceania_codes + [
    'KW', 'AF', 'AE', 'SY', 'TJ', 'KZ', 'KG', 'IL', 'PS', 'LB', 
    'KP', 'BH', 'IQ', 'YE', 'JO', 'IR', 'QA', 'OM', 'UZ', 'TM', 'SA'
]

# %%
north_south_america_codes, europe_codes, africa_codes, asia_oceania_codes
# Out:
# (['US',
#   'MX',
#   'CA',
#   'BR',
#   'AR',
#   'CL',
#   'CO',
#   'VE',
#   'PE',
#   'EC',
#   'UY',
#   'PY',
#   'BO',
#   'PR',
#   'CU',
#   'DO',
#   'GT',
#   'HN',
#   'CR',
#   'PA',
#   'NI',
#   'SV',
#   'BZ',
#   'JM',
#   'TT',
#   'BS',
#   'VG',
#   'GD',
#   'BB',
#   'KN',
#   'AG',
#   'DM',
#   'GP',
#   'GF',
#   'MS',
#   'FK',
#   'HT'],
#  ['RU',
#   'GB',
#   'FR',
#   'DE',
#   'IT',
#   'ES',
#   'PL',
#   'RO',
#   'NL',
#   'BE',
#   'GR',
#   'CZ',
#   'PT',
#   'SE',
#   'HU',
#   'BY',
#   'AT',
#   'CH',
#   'DK',
#   'FI',
#   'SK',
#   'NO',
#   'IE',
#   'HR',
#   'SI',
#   'LV',
#   'LT',
#   'EE',
#   'IS',
#   'MT',
#   'LU',
#   'MC',
#   'VA',
#   'RS',
#   'ME',
#   'MK',
#   'AL',
#   'BA',
#   'XK',
#   'UA',
#   'MD',
#   'BG',
#   'CY',
#   'TR',
#   'GE',
#   'AM',
#   'AZ',
#   'LI',
#   'SJ',
#   'JE',
#   'AX',
#   'FO',
#   'GI',
#   'BM',
#   'TC',
#   'SX',
#   'GL'],
#  ['DZ',
#   'AO',
#   'EG',
#   'LY',
#   'MA',
# ...

# %%
# Removing duplicate entries if any in each list
country_codes_set = set(country_codes)
north_south_america_set = set(north_south_america_codes)
asia_oceania_set = set(asia_oceania_codes)
europe_set = set(europe_codes)
africa_set = set(africa_codes)

# Combining all the continent sets
combined_continents_set = north_south_america_set.union(asia_oceania_set, europe_set, africa_set)

# Count of unique country codes and combined continents
unique_country_codes_count = len(country_codes_set)
combined_continents_count = len(combined_continents_set)

(unique_country_codes_count, combined_continents_count)
# Out:
# (198, 198)

# %%
asia_oceania_codes
# Out:
# ['CN',
#  'JP',
#  'IN',
#  'KR',
#  'ID',
#  'TH',
#  'PK',
#  'MY',
#  'PH',
#  'VN',
#  'LK',
#  'BD',
#  'NP',
#  'MM',
#  'TW',
#  'HK',
#  'SG',
#  'MN',
#  'KH',
#  'LA',
#  'BT',
#  'MO',
#  'BN',
#  'MV',
#  'AU',
#  'NZ',
#  'PG',
#  'FJ',
#  'VU',
#  'NC',
#  'PF',
#  'GU',
#  'WS',
#  'NC',
#  'TO',
#  'PW',
#  'KW',
#  'AF',
#  'AE',
#  'SY',
#  'TJ',
#  'KZ',
#  'KG',
#  'IL',
#  'PS',
#  'LB',
#  'KP',
#  'BH',
#  'IQ',
#  'YE',
#  'JO',
#  'IR',
#  'QA',
#  'OM',
#  'UZ',
#  'TM',
#  'SA']

# %%
# Combined list of North and South American countries
north_south_america = [
    'US', 'MX', 'CA', 'BR', 'AR', 'CL', 'CO', 'VE', 'PE', 'EC', 
    'UY', 'PY', 'BO', 'PR', 'CU', 'DO', 'GT', 'HN', 'CR', 'PA', 
    'NI', 'SV', 'BZ', 'JM', 'TT', 'BS', 'VG', 'GD', 'BB', 'KN', 
    'AG', 'DM', 'GP', 'GF', 'MS', 'FK', 'HT'
]

# North American countries (including Central America and the Caribbean)
north_america = [
    'US', 'MX', 'CA', 'PR', 'CU', 'DO', 'GT', 'HN', 'CR', 'PA', 
    'NI', 'SV', 'BZ', 'JM', 'TT', 'BS', 'VG', 'GD', 'BB', 'KN', 
    'AG', 'DM', 'GP', 'GF', 'MS', 'FK', 'HT'
]

# South American countries
south_america = [
    'BR', 'AR', 'CL', 'CO', 'VE', 'PE', 'EC', 'UY', 'PY', 'BO'
]

# %%
# Verify that all countries are accounted for and correctly categorized
all_countries_sorted = sorted(north_south_america)
combined_sorted = sorted(north_america + south_america)

# Check if all countries match in the combined sorted list and the all countries sorted list
verification = all_countries_sorted == combined_sorted

# Output the lists and verification result
north_america, south_america, verification
# Out:
# (['US',
#   'MX',
#   'CA',
#   'PR',
#   'CU',
#   'DO',
#   'GT',
#   'HN',
#   'CR',
#   'PA',
#   'NI',
#   'SV',
#   'BZ',
#   'JM',
#   'TT',
#   'BS',
#   'VG',
#   'GD',
#   'BB',
#   'KN',
#   'AG',
#   'DM',
#   'GP',
#   'GF',
#   'MS',
#   'FK',
#   'HT'],
#  ['BR', 'AR', 'CL', 'CO', 'VE', 'PE', 'EC', 'UY', 'PY', 'BO'],
#  True)

# %% [markdown]
# # Telescope Label Analysis

# %%
import pandas as pd
import numpy as np
import re

# %%
Labels = pd.read_csv('Labels.csv')

# Rename the first column to 'Labels'
Labels.columns = ['Labels']
Labels
# Out:
#                                                  Labels
# 0                  Abastumani Astrophysical Observatory
# 1                      Abu Reyhan-e Birooni Observatory
# 2                         Adirondack Public Observatory
# 3                                 Adolphson Observatory
# 4                            Airdrie Public Observatory
# ...                                                 ...
# 1037                                           ULTRASAT
# 1038  Nancy Grace Roman Space Telescope (Wide Field ...
# 1039                                              ARIEL
# 1040  Advanced Telescope for High Energy Astrophysic...
# 1041          Laser Interferometer Space Antenna (LISA)
#
# [1042 rows x 1 columns]

# %%
abstract_df = pd.read_csv('preprocessed_data_Jul14.csv')
abstract_df = abstract_df['concatenated_title_abstract']
abstract_df
# Out:
# 0        KINEMATIC TREATMENT OF CORONAL MASS EJECTION E...
# 1        The imaging performance of the Hubble Space Te...
# 2        Numerical Simulations of Mass Outflows Driven ...
# 3        The Origin of X-shaped Radio Galaxies: Clues f...
# 4        The Ghost of Sagittarius and Lumps in the Halo...
#                                ...
# 63994    Accretion Disk Spectra of the Ultra-luminous X...
# 63995    The ghost of a dwarf galaxy: fossils of the hi...
# 63996    Observations of the Solar Corona from Space Sp...
# 63997    Constraints on the topology of the Universe de...
# 63998    Formation of Kuiper-belt binaries through mult...
# Name: concatenated_title_abstract, Length: 63999, dtype: object

# %%
full_text = pd.read_csv('preprocessed_FullText_data.csv')
full_text = full_text['fullText']
full_text
# Out:
# /tmp/ipykernel_79276/2594632076.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_text = pd.read_csv('preprocessed_FullText_data.csv')
# 0        ['THE FLASH SPECTRUM. BY S. A. MITCHELL. (Read...
# 1        ['MAY 9, 1913] SCIENCE must be sought the key ...
# 2        ['OCTOBER 4, 1912] SCIENCE astronomy, increasi...
# 3        ["SCIENTIFIC NOTES AND NEWS A SPECIAL act of c...
# 4        ['Wfeek-ly morbidity and mnortality tatble, ci...
#                                ...
# 24995    ['Atmos. Chem. Phys., 16, 7709–7724, 2016\nwww...
# 24996    ['Ann. Geophys., 31, 187–196, 2013\nwww.ann-ge...
# 24997    ['Research Article\nTrack-to-Track Association...
# 24998    ['Nonlin. Processes Geophys., 26, 91–108, 2019...
# 24999    ['Contribution of Ancestral Lines in the Devel...
# Name: fullText, Length: 25000, dtype: object

# %%
# Count the occurrences of the words in abstracts data
telescope_count = abstract_df.str.count('telescope').sum()
satellite_count = abstract_df.str.count('satellite').sum()
array_count = abstract_df.str.count('array').sum()

# results
print(f"'telescope' appears {telescope_count} times in abstracts data.")
print(f"'satellite' appears {satellite_count} times in abstracts data.")
print(f"'array' appears {array_count} times in abstracts data.")
# Out:
# 'telescope' appears 5758 times in abstracts data.
# 'satellite' appears 6072 times in abstracts data.
# 'array' appears 1126 times in abstracts data.

# %%
# Count the occurrences of the words in full text data
telescope_count = full_text.str.count('telescope').sum()
satellite_count = full_text.str.count('satellite').sum()
array_count = full_text.str.count('array').sum()

# results
print(f"'telescope' appears {telescope_count} times in full text data.")
print(f"'satellite' appears {satellite_count} times in full text data.")
print(f"'array' appears {array_count} times in full text data.")
# Out:
# 'telescope' appears 7887 times in full text data.
# 'satellite' appears 72784 times in full text data.
# 'array' appears 11717 times in full text data.

# %% [markdown]
# # Abstract Analysis

# %%
# Count the occurrences of each label
label_counts = {}
for label in Labels['Labels']:
    escaped_label = re.escape(label)
    label_counts[label] = abstract_df.str.contains(escaped_label, case=False, na=False).sum()

# Results
for label, count in label_counts.items():
    print(f"'{label}' appears {count} times.")
# Out:
# 'Abastumani Astrophysical Observatory' appears 0 times.
# 'Abu Reyhan-e Birooni Observatory' appears 0 times.
# 'Adirondack Public Observatory' appears 0 times.
# 'Adolphson Observatory' appears 0 times.
# 'Airdrie Public Observatory' appears 0 times.
# 'Aker Observatory' appears 0 times.
# 'Aldershot Observatory' appears 0 times.
# 'Algonquin Radio Observatory' appears 0 times.
# 'Allegheny Observatory' appears 1 times.
# 'Ametlla de Mar Observatory' appears 0 times.
# 'AMiBA' appears 0 times.
# 'Anderson Mesa Station' appears 0 times.
# 'Angell Hall Observatory' appears 0 times.
# 'Ankara University Observatory' appears 1 times.
# 'Antarctic Muon and Neutrino Detector Array' appears 0 times.
# 'Antarctic Submillimeter Telescope and Remote Observatory' appears 10 times.
# 'ANTARES' appears 28 times.
# 'Apache-Sitgreaves Observatory' appears 0 times.
# 'Apache Point Observatory' appears 37 times.
# 'Apatity Cosmic-Ray Station' appears 0 times.
# 'Apollo Observatory' appears 0 times.
# 'Arcetri Observatory' appears 0 times.
# 'Arecibo Observatory' appears 46 times.
# 'Argentine Institute of Radio Astronomy' appears 0 times.
# 'Armagh Observatory' appears 0 times.
# 'Aryabhatta Research Institute of Observational Sciences' appears 4 times.
# 'Ashton Observatory' appears 0 times.
# 'Asiago Astrophysical Observatory' appears 0 times.
# 'Assheton Observatory' appears 0 times.
# 'Astron (defunct)' appears 0 times.
# 'Astronomical Observatory Aurora' appears 0 times.
# 'Astronomical Observatory of Lisbon' appears 0 times.
# 'Astronomy Centre' appears 6 times.
# 'Astronomy Tower of the Sorbonne' appears 0 times.
# 'Astrophysical Institute Potsdam' appears 0 times.
# 'Atacama Pathfinder Experiment (APEX)' appears 0 times.
# 'Australia Telescope Compact Array' appears 212 times.
# 'Australian Astronomical Observatory' appears 1 times.
# 'Badlands Observatory' appears 0 times.
# 'Baikal Deep Underwater Neutrino Telescope' appears 0 times.
# 'Bangladesh Astronomical Observatory' appears 0 times.
# 'Baker Observatory' appears 0 times.
# 'Baksan Neutrino Observatory' appears 4 times.
# 'Ball State University Observatory' appears 0 times.
# 'Barnard Observatory (defunct)' appears 0 times.
# 'Bareket Observatory' appears 0 times.
# 'Barnett Observatory' appears 0 times.
# 'Bayfordbury Observatory' appears 0 times.
# 'Behlen Observatory' appears 4 times.
# 'Beijing Astronomical Observatory' appears 10 times.
# 'Beijing Ancient Observatory' appears 0 times.
# 'Belgrade Observatory' appears 0 times.
# 'Belogradchik Observatory' appears 0 times.
# 'Benmore Peak Observatory' appears 0 times.
# 'BeppoSAX (defunct)' appears 0 times.
# 'Bergisch Gladbach Observatory' appears 0 times.
# 'Berlin Observatory' appears 0 times.
# 'Besançon Observatory' appears 0 times.
# 'BESS' appears 60 times.
# 'Bidston Observatory' appears 0 times.
# 'Big Bear Lake Solar Observatory' appears 0 times.
# 'Bisdee Tier Optical Astronomy Observatory' appears 0 times.
# 'Black Moshannon Observatory (defunct)' appears 0 times.
# 'Blackett Observatory' appears 0 times.
# 'Blue Mesa Observatory (defunct)' appears 0 times.
# 'Boambee Observatory' appears 0 times.
# 'Bohyunsan Optical Astronomy Observatory (BOAO)' appears 0 times.
# 'BOOTES' appears 67 times.
# 'Bordeaux Observatory' appears 0 times.
# 'Bosscha Observatory' appears 0 times.
# 'Boswell Observatory (defunct)' appears 0 times.
# 'Bowman Observatory' appears 0 times.
# 'Boyden Observatory' appears 0 times.
# 'Bradstreet Observatory' appears 0 times.
# 'Bradley Observatory' appears 0 times.
# 'Braeside Observatory (defunct)' appears 0 times.
# 'Brera Observatory' appears 0 times.
# 'Bridgewater State University Observatory' appears 0 times.
# 'Brooks Observatory' appears 0 times.
# 'Brooks Astronomical Observatory' appears 0 times.
# 'Brorfelde Observatory' appears 0 times.
# 'Bucharest Observatory' appears 0 times.
# 'Bucknell Observatory' appears 0 times.
# 'Burrell Memorial Observatory' appears 0 times.
# 'Byurakan Observatory' appears 5 times.
# 'Cagigal Observatory' appears 0 times.
# 'Cagliari Observatory' appears 0 times.
# 'Calais Observatory (defunct)' appears 0 times.
# 'Calar Alto Observatory' appears 12 times.
# 'Caltech Submillimeter Observatory (defunct)' appears 0 times.
# 'Cambridge Observatory' appears 0 times.
# 'Camille Flammarion Observatory' appears 0 times.
# 'Campbelltown Rotary Observatory' appears 0 times.
# 'Campo Imperatore Near-Earth Object Survey' appears 0 times.
# 'Canopus Hill Observatory' appears 0 times.
# 'Capilla Peak Observatory' appears 0 times.
# 'Capodimonte Observatory' appears 0 times.
# 'Carter Observatory' appears 0 times.
# 'Catania Astrophysical Observatory' appears 3 times.
# 'Cawthron Atkinson Observatory' appears 0 times.
# 'Celestial Observatory' appears 0 times.
# 'Centennial Observatory' appears 0 times.
# 'Center for Astrophysics | Harvard & Smithsonian' appears 2 times.
# 'Cerro Armazones Observatory' appears 0 times.
# 'Cerro Tololo Inter-American Observatory' appears 86 times.
# 'Cerro Pachón Observatory' appears 0 times.
# 'Chabot Space & Science Center' appears 0 times.
# 'Chamberlin Observatory' appears 0 times.
# 'Changchun Astronomical Observatory' appears 0 times.
# 'Chandra X-ray Observatory' appears 479 times.
# 'Chianti Polifunctional Observatory' appears 0 times.
# 'Chico Community Observatory' appears 0 times.
# 'Chilbolton Observatory' appears 0 times.
# 'Cima Ekar Observing Station' appears 0 times.
# 'Cincinnati Observatory' appears 0 times.
# 'City Observatory, Edinburgh' appears 0 times.
# 'Clarke Observatory' appears 0 times.
# 'Class of 1951 Observatory' appears 0 times.
# 'Cloudcroft Observatory (defunct)' appears 0 times.
# 'Coats Observatory' appears 0 times.
# 'Coit Observatory' appears 0 times.
# 'Collins Observatory' appears 0 times.
# 'Collm Observatory' appears 0 times.
# 'Colombo University Observatory' appears 0 times.
# 'Compton Gamma-Ray Observatory (defunct)' appears 0 times.
# 'ÇOMÜ Ulupınar Observatory' appears 0 times.
# 'Concordia College Observatory' appears 0 times.
# 'Consell Observatory' appears 0 times.
# 'Copenhagen University Observatory' appears 0 times.
# 'Cordell–Lorenz Observatory' appears 0 times.
# 'COROT' appears 483 times.
# 'Cosmic Background Imager (CBI) (defunct)' appears 0 times.
# 'Côte d'Azur Observatory' appears 0 times.
# 'Crane Observatory' appears 0 times.
# 'Crawford Observatory' appears 0 times.
# 'Creighton University Observatory (defunct)' appears 0 times.
# 'Crimean Astrophysical Observatory' appears 14 times.
# 'Črni Vrh Observatory' appears 0 times.
# 'Cupillari Observatory' appears 0 times.
# 'Custer Observatory' appears 0 times.
# 'The Cyprus Planetarium & Observatory' appears 0 times.
# 'Daniel S. Schanck Observatory (defunct)' appears 0 times.
# 'Daniel Scholl Observatory (defunct)' appears 0 times.
# 'Daocheng Solar Radio Telescope' appears 0 times.
# 'Dark Sky Observatory' appears 0 times.
# 'Dark Matter Particle Explorer (DAMPE)' appears 11 times.
# 'Darling's Observatory (defunct)' appears 0 times.
# 'Dearborn Observatory' appears 0 times.
# 'Detroit Observatory' appears 0 times.
# 'David Dunlap Observatory' appears 9 times.
# 'Dome C' appears 10 times.
# 'Dominion Observatory' appears 0 times.
# 'Dominion Astrophysical Observatory' appears 9 times.
# 'Dominion Radio Astrophysical Observatory' appears 11 times.
# 'Dunsink Observatory' appears 0 times.
# 'Durham University Observatory' appears 0 times.
# 'Dyer Observatory' appears 0 times.
# 'Effelsberg 100-m Radio Telescope' appears 0 times.
# 'Ege University Observatory' appears 1 times.
# 'Einstein Observatory (defunct)' appears 0 times.
# 'Elginfield Observatory' appears 2 times.
# 'Ellis Observatory' appears 0 times.
# 'Embry-Riddle Observatory' appears 0 times.
# 'Eskdalemuir Observatory' appears 0 times.
# 'European Gravitational Observatory' appears 0 times.
# 'Euclid Telescope' appears 0 times.
# 'European Southern Observatory La Silla Observatory New Technology Telescope Llano de Chajnantor Observatory Very Large Telescope Paranal Observatory European Extremely Large Telescope' appears 0 times.
# 'Fabra Observatory' appears 0 times.
# 'Fan Mountain Observatory' appears 0 times.
# 'Five-hundred-meter Aperture Spherical Radio Telescope' appears 1 times.
# 'Félix Aguilar Observatory' appears 0 times.
# 'Fernbank Observatory' appears 0 times.
# 'Fermi Gamma-ray Space Telescope' appears 58 times.
# 'Fick Observatory' appears 0 times.
# 'Five College Radio Astronomy Observatory (defunct)' appears 0 times.
# 'Flarestar Observatory' appears 0 times.
# 'Foggy Bottom Observatory' appears 2 times.
# 'Foothill Observatory' appears 0 times.
# 'Ford Observatory' appears 3 times.
# 'Fox Observatory' appears 0 times.
# 'Fox Park Public Observatory' appears 0 times.
# 'Francis Marion University Observatory' appears 0 times.
# 'Fred Lawrence Whipple Observatory' appears 10 times.
# 'Fremont Peak Observatory' appears 0 times.
# 'Frosty Drew Observatory' appears 0 times.
# 'Fuertes Observatory' appears 0 times.
# 'Galaxy Evolution Explorer (GALEX)' appears 94 times.
# 'Gaocheng Astronomical Observatory' appears 0 times.
# 'Gauribidanur Radio Observatory' appears 3 times.
# 'Gemini Observatory' appears 9 times.
# 'Giant Meterwave Radio Telescope (GMRT)' appears 6 times.
# 'Gifford Observatory' appears 0 times.
# 'Girawali Observatory' appears 0 times.
# 'Glen D. Riley Observatory' appears 0 times.
# 'Godlee Observatory' appears 0 times.
# 'Goodsell Observatory' appears 0 times.
# 'Goethe Link Observatory' appears 0 times.
# 'Goldendale Observatory' appears 0 times.
# 'Gornergrat (HFSJG) (defunct)' appears 0 times.
# 'Granat (defunct)' appears 0 times.
# 'Gran Telescopio Canarias' appears 19 times.
# 'Grant O. Gale Observatory' appears 0 times.
# 'Green Bank Telescope,' appears 20 times.
# 'Green Point Observatory,' appears 0 times.
# 'Grenfell Observatory' appears 0 times.
# 'Griffith Observatory' appears 0 times.
# 'Guillermo Haro Observatory' appears 0 times.
# 'HALCA (defunct)' appears 0 times.
# 'Haleakala Observatory' appears 0 times.
# 'Halley Observatory' appears 0 times.
# 'Hamburg Observatory' appears 0 times.
# 'Hat Creek Radio Observatory' appears 2 times.
# 'Hard Labor Creek Observatory' appears 0 times.
# 'Space Hard X-Ray Modulation Telescope (HXMT)' appears 0 times.
# 'Hartung–Boothroyd Observatory' appears 0 times.
# 'Hartebeesthoek Radio Astronomy Observatory' appears 4 times.
# 'Hartwell House' appears 0 times.
# 'Harvard College Observatory' appears 14 times.
# 'Haute-Provence Observatory' appears 0 times.
# 'Haystack Observatory' appears 4 times.
# 'Hector J Robinson Observatory' appears 0 times.
# 'Helium and Lead Observatory' appears 0 times.
# 'Helmos Observatory' appears 0 times.
# 'Helsinki University Observatory' appears 0 times.
# 'Herrett Observatory' appears 0 times.
# 'Herschel Space Observatory' appears 50 times.
# 'Hidden Valley Observatory' appears 0 times.
# 'Hida Observatory, Kyoto University' appears 0 times.
# 'Heyden Observatory, Georgetown University' appears 0 times.
# 'High Altitude Water Cherenkov Observatory' appears 0 times.
# 'High Energy Stereoscopic System' appears 44 times.
# 'Highland Road Park Observatory' appears 0 times.
# 'Hinode' appears 98 times.
# 'Hirsch Observatory' appears 0 times.
# 'Hobbs Observatory' appears 0 times.
# 'Hoher List Observatory' appears 0 times.
# 'Holcomb Observatory and Planetarium' appears 0 times.
# 'Hong Kong Observatory' appears 0 times.
# 'Hoober Observatory' appears 0 times.
# 'Hopkins Observatory' appears 0 times.
# 'Howell Observatory' appears 0 times.
# 'Hradec Králové Observatory' appears 0 times.
# 'Huairou Solar Observing Station' appears 7 times.
# 'Hubble Space Telescope' appears 3154 times.
# 'Huggins Observatory defunct' appears 0 times.
# 'Hume Cronyn Memorial Observatory' appears 0 times.
# 'Hyde Memorial Observatory' appears 0 times.
# 'IceCube Neutrino Observatory' appears 7 times.
# 'Indian Astronomical Observatory' appears 0 times.
# 'Instituto de Astrofísica de Canarias' appears 2 times.
# 'INTEGRAL' appears 1036 times.
# 'Infrared Astronomical Satellite (IRAS) (defunct)' appears 0 times.
# 'Infrared Space Observatory (ISO) (defunct)' appears 0 times.
# 'Innsbruck Observatory' appears 0 times.
# 'IRAM 30m telescope' appears 0 times.
# 'IRAM Plateau de Bure Interferometer' appears 20 times.
# 'Iranian National Observatory' appears 0 times.
# 'Isaac Newton Group of Telescopes' appears 0 times.
# 'Isasc Roberts' Observatory (defunct)' appears 0 times.
# 'Iso-Heikkilä Observatory (defunct)' appears 0 times.
# 'Constantinople Observatory of Taqi ad-Din' appears 0 times.
# 'Istanbul University Observatory' appears 0 times.
# 'Istituto Ricerche Solari Locarno, IRSOL' appears 0 times.
# 'IXPE' appears 3 times.
# 'Jack C. Davis Observatory' appears 0 times.
# 'Astronomical Observatory of the Jagiellonian University' appears 0 times.
# 'James Clerk Maxwell Telescope' appears 159 times.
# 'James Gregory Telescope' appears 0 times.
# 'James Webb Space Telescope' appears 120 times.
# 'James Wylie Shepherd Observatory' appears 0 times.
# 'Jakarta Observatory' appears 0 times.
# 'Jantar Mantar' appears 0 times.
# 'Jena Observatory' appears 0 times.
# 'Jewett Observatory' appears 0 times.
# 'Jodrell Bank Observatory' appears 3 times.
# 'JAC Johor Astronomy' appears 0 times.
# 'Jones Observatory' appears 0 times.
# 'Judson B. Coit Observatory' appears 0 times.
# 'KAIRA' appears 0 times.
# 'Khajeh Nasiredin Observatory' appears 0 times.
# 'Kamioka Observatory' appears 1 times.
# 'Kanzelhoehe Solar Observatory' appears 1 times.
# 'Karl Schwarzschild Observatory' appears 0 times.
# 'Keck Observatory' appears 116 times.
# 'Keeble Observatory' appears 0 times.
# 'Keele Observatory' appears 0 times.
# 'Kennon Observatory' appears 0 times.
# 'Kepler Space Observatory' appears 0 times.
# 'Kevola Observatory' appears 0 times.
# 'Kielder Observatory' appears 0 times.
# 'King's Observatory (defunct)' appears 0 times.
# 'Kirkwood Observatory' appears 0 times.
# 'Kitami Observatory' appears 0 times.
# 'Kitt Peak National Observatory' appears 50 times.
# 'Kleť Observatory' appears 0 times.
# 'Kodaikanal Solar Observatory' appears 3 times.
# 'Konkoly Observatory' appears 4 times.
# 'Kopernik Observatory & Science Center' appears 0 times.
# 'KOSMA observatory' appears 0 times.
# 'Kottamia Astronomical Observatory' appears 0 times.
# 'Kuffner observatory' appears 0 times.
# 'Kuiper Airborne Observatory (retired)' appears 0 times.
# 'Kwasan Observatory, Kyoto University' appears 1 times.
# 'Kvistaberg Observatory' appears 0 times.
# 'Kyung Hee Observatory' appears 0 times.
# 'Laboratoire d'Astrophysique de Grenoble' appears 0 times.
# 'Observatorio de La Cañada (La Cañada Observatory)' appears 0 times.
# 'Ladd Observatory' appears 0 times.
# 'Lake Afton Public Observatory' appears 0 times.
# 'Lamont–Hussey Observatory (defunct)' appears 0 times.
# 'Landessternwarte Heidelberg-Königstuhl' appears 3 times.
# 'Landolt Astronomical Observatory' appears 0 times.
# 'La Plata Astronomical Observatory' appears 0 times.
# 'La Silla Observatory' appears 3 times.
# 'Large High Altitude Air Shower Observatory (LHAASO)' appears 6 times.
# 'Large Sky Area Multi-Object Fibre Spectroscopic Telescope (LAMOST)' appears 0 times.
# 'Large Millimeter Telescope' appears 1 times.
# 'Las Brisas Observatory' appears 0 times.
# 'Las Campanas Observatory' appears 47 times.
# 'Las Cumbres Observatory Global Telescope' appears 0 times.
# 'Laws Observatory' appears 0 times.
# 'Leander McCormick Observatory' appears 0 times.
# 'Lee Observatory' appears 0 times.
# 'Leiden Observatory' appears 8 times.
# 'Leipzig Observatory' appears 0 times.
# 'Leoncito Astronomical Complex' appears 0 times.
# 'Levenhagen Observatory' appears 0 times.
# 'Lick Observatory' appears 85 times.
# 'LightBuckets (commercial observatory)' appears 0 times.
# 'LIGO' appears 326 times.
# 'Lindheimer Astrophysical Research Center (defunct)' appears 0 times.
# 'Llano de Chajnantor Observatory' appears 0 times.
# 'Llano del Hato National Astronomical Observatory' appears 0 times.
# 'Lockyer Technology Centre' appears 0 times.
# 'Long Wavelength Array' appears 1 times.
# 'Longa Vista Observatory' appears 0 times.
# 'Lowell Observatory Anderson Mesa Station' appears 0 times.
# 'Lucknow (King of Oudh's) Observatory' appears 0 times.
# 'Lulin Observatory' appears 2 times.
# 'Lund Observatory' appears 0 times.
# 'Luoxue Mountain Cosmic Rays Research Center' appears 0 times.
# 'Lyon Observatory' appears 0 times.
# 'Macalester College Observatory' appears 0 times.
# 'Macfarlane Observatory defunct' appears 0 times.
# 'Magdalena Ridge Observatory (under construction)' appears 0 times.
# 'Majorca Observatory' appears 0 times.
# 'Malakoff Tower' appears 0 times.
# 'Manastash Ridge Observatory' appears 4 times.
# 'Manuel Foster Observatory (defunct)' appears 0 times.
# 'Maragheh Observatory' appears 0 times.
# 'Margaret M. Jacoby Observatory' appears 0 times.
# 'Maria Mitchell Observatory' appears 0 times.
# 'Marina Towers Observatory (Not In Use)' appears 0 times.
# 'Markree Observatory (defunct)' appears 0 times.
# 'Marseille Observatory' appears 0 times.
# 'Martz Observatory' appears 0 times.
# 'Mauna Kea Observatory' appears 10 times.
# 'Mauna Loa Solar Observatory' appears 17 times.
# 'Maynard F. Jordan Observatory' appears 0 times.
# 'McDonald Observatory' appears 43 times.
# 'McKim Observatory' appears 0 times.
# 'McMath–Hulbert Solar Observatory' appears 0 times.
# 'MDM Observatory' appears 14 times.
# 'Mead Observatory' appears 0 times.
# 'Medicina Radio Observatory' appears 0 times.
# 'Mees Observatory' appears 0 times.
# 'Mehalso Observatory' appears 0 times.
# 'Melbourne Observatory' appears 0 times.
# 'Melton Memorial Observatory' appears 0 times.
# 'Mendenhall Observatory' appears 0 times.
# 'Menke Observatory' appears 0 times.
# 'Metsähovi Observatory' appears 0 times.
# 'Meudon Observatory' appears 3 times.
# 'Meyer–Womble Observatory' appears 0 times.
# 'Michigan State University Observatory' appears 0 times.
# 'Observatoire Midi-Pyrénées Pic du Midi Observatory Toulouse Observatory' appears 0 times.
# 'Milagro' appears 32 times.
# 'Miller Observatory' appears 0 times.
# 'Mills Observatory' appears 0 times.
# 'Mind's Eye Observatory IAU W42' appears 0 times.
# 'MMT Observatory' appears 7 times.
# 'Modine-Benstead Observatory' appears 0 times.
# 'Modra Observatory' appears 0 times.
# 'Mohr Observatory (demolished)' appears 0 times.
# 'Moletai Astronomical Observatory' appears 0 times.
# 'Molonglo Observatory Synthesis Telescope (MOST)' appears 6 times.
# 'Mont Mégantic Observatory' appears 0 times.
# 'Monterey Institute for Research in Astronomy(Oliver Observing Station)' appears 0 times.
# 'Montevideo National Observatory' appears 0 times.
# 'Moore Observatory' appears 0 times.
# 'Morgan–Monroe Observatory' appears 0 times.
# 'Morris Observatory' appears 0 times.
# 'Morrison Observatory' appears 0 times.
# 'Moscow Cosmic-Ray Station' appears 0 times.
# 'Mount Stony Brook Observatory' appears 0 times.
# 'Mounds Observatory' appears 0 times.
# 'Mount Abu InfraRed Observatory' appears 0 times.
# 'Mount Burnett Observatory' appears 0 times.
# 'Mount Cuba Astronomical Observatory' appears 0 times.
# 'Mount Graham International Observatory' appears 3 times.
# 'Mount John University Observatory' appears 0 times.
# 'Mount Laguna Observatory' appears 3 times.
# 'Mount Lemmon Observatory' appears 0 times.
# 'Mount Pleasant Radio Observatory' appears 4 times.
# 'Mount Stromlo Observatory' appears 1 times.
# 'Mount Suhora Observatory' appears 0 times.
# 'Mount Wilson Observatory' appears 30 times.
# 'Mountain Skies Observatory' appears 0 times.
# 'Mullard Radio Astronomy Observatory' appears 0 times.
# 'Murchison Radio-astronomy Observatory' appears 7 times.
# 'Nachi-Katsuura Observatory' appears 0 times.
# 'Nançay Radio Telescope' appears 0 times.
# 'Nanjing Astronomical Instruments Research Centre' appears 0 times.
# 'National Astronomical Observatory (Colombia)' appears 0 times.
# 'National Astronomical Observatory of Japan' appears 3 times.
# 'National Astronomical Observatory (Mexico)' appears 0 times.
# 'National Observatory (Brazil)' appears 0 times.
# 'National Observatory of Athens' appears 5 times.
# 'National Optical Astronomy Observatory Cerro Tololo Inter-American Observatory Gemini Observatory Kitt Peak National Observatory National Solar Observatory' appears 0 times.
# 'National Optical Observatory' appears 1 times.
# 'National Radio Astronomy Observatory Atacama Large Millimeter Array Green Bank Telescope Very Large Array Very Long Baseline Array' appears 0 times.
# 'National Research Institute of Astronomy and Geophysics (NRIAG)' appears 0 times.
# 'National Solar Observatory' appears 37 times.
# 'Naval Research Lab. Radio Sta.' appears 0 times.
# 'Naylor Observatory' appears 0 times.
# 'Neuchâtel Observatory' appears 1 times.
# 'Nice Observatory' appears 0 times.
# 'Nizamia Observatory' appears 0 times.
# 'Nordic Optical Telescope' appears 26 times.
# 'Norilsk Cosmic-Ray Station' appears 0 times.
# 'Norman Lockyer Observatory' appears 0 times.
# 'Northern Arizona University Observatory' appears 0 times.
# 'Northern Skies Observatory' appears 0 times.
# 'Northolt Branch Observatory' appears 0 times.
# 'Northolt Branch Observatory 2, Shepherd's Bush' appears 0 times.
# 'Northolt Branch Observatory 3, Blandford Forum' appears 0 times.
# 'North Georgia Astronomical Observatory' appears 0 times.
# 'North Otago Astronomical Society Observatory' appears 0 times.
# 'Nyrölä Observatory' appears 3 times.
# 'OAC (Observatorio Astronómico de Córdoba)' appears 0 times.
# 'OAO (Observatorio de Aras de los Olmos)' appears 0 times.
# 'O'Brien Observatory' appears 0 times.
# 'Observatoire du Pic de Château-Renard' appears 0 times.
# 'Observatorio Astronómico Nacional (Colombia)' appears 0 times.
# 'Observatorio Astronomico Nacional Tonantzintla' appears 0 times.
# 'Observatorio Solar Carl Sagan' appears 0 times.
# 'Observatory House (defunct)' appears 0 times.
# 'Observatory of the rue Serpente (defunct)' appears 0 times.
# 'Oil Region Astronomical Observatory' appears 0 times.
# 'Onan Observatory' appears 0 times.
# 'Ondokuz Mayıs University Observatory' appears 0 times.
# 'Ondřejov Observatory' appears 4 times.
# 'Onsala Space Observatory' appears 0 times.
# 'Ooty Radio Telescope' appears 8 times.
# 'Orchard Hill Observatory' appears 0 times.
# 'Orioloromano Observatory' appears 0 times.
# 'Orion 1 (defunct)' appears 0 times.
# 'Orion 2 (defunct)' appears 0 times.
# 'Orion Ranch Observatory' appears 0 times.
# 'Orwell Park School Observatory' appears 0 times.
# 'Ostrowik Observatory' appears 0 times.
# 'Otter Creek Observatory' appears 0 times.
# 'Oulu Cosmic-Ray Station' appears 0 times.
# 'Owens Valley Radio Observatory' appears 46 times.
# 'Pachmarhi Array of Cerenkov Telescopes (PACT)' appears 0 times.
# 'Palisades-Dows Observatory' appears 0 times.
# 'PAGASA Astronomical Observatory' appears 0 times.
# 'Palermo Observatory' appears 0 times.
# 'Palomar Observatory' appears 56 times.
# 'Panzano Observatory' appears 0 times.
# 'Paranal Observatory' appears 1 times.
# 'Paris Observatory' appears 3 times.
# 'Parkes Observatory' appears 3 times.
# 'Paul Robinson Observatory' appears 0 times.
# 'Peach Mountain Observatory' appears 0 times.
# 'Perkins Observatory' appears 0 times.
# 'Perth Observatory' appears 0 times.
# 'Peterberg Observatory' appears 0 times.
# 'Pic du Midi Observatory' appears 1 times.
# 'Pico dos Dias Observatory' appears 0 times.
# 'Piera Observatory' appears 0 times.
# 'Pierre Auger Observatory' appears 37 times.
# 'Pine Bluff Observatory' appears 0 times.
# 'Pine Mountain Observatory' appears 0 times.
# 'Pistoia Mountains Astronomical Observatory' appears 0 times.
# 'Piwnice Ovservatory' appears 0 times.
# 'Planetarium and Astronomical Observatory in Grudziądz' appears 0 times.
# 'Pollock Astronomical Observatory' appears 0 times.
# 'Portage Lake Observatory (defunct)' appears 0 times.
# 'Poznań Observatory' appears 0 times.
# 'Puckett Observatory' appears 0 times.
# 'Pula Observatory' appears 0 times.
# 'Pulkovo Observatory' appears 1 times.
# 'Purple Mountain Observatory' appears 18 times.
# 'Quito Astronomical Observatory' appears 0 times.
# 'Radcliffe Observatory' appears 0 times.
# 'Rainwater Observatory' appears 0 times.
# 'Ralph A. Worley Observatory' appears 0 times.
# 'Rankin Science Observatory' appears 0 times.
# 'Rancho Mirage Library and Observatory' appears 0 times.
# 'Rattlesnake Mountain Observatory (defunct)' appears 0 times.
# 'Real Instituto y Observatorio de la Armada (Spain)' appears 0 times.
# 'Red Barn Observatory' appears 0 times.
# 'Red Buttes Observatory' appears 0 times.
# 'Riley Observatory' appears 0 times.
# 'RIT Observatory' appears 0 times.
# 'Ritter Observatory' appears 0 times.
# 'Robert A. Schommer Observatory' appears 0 times.
# 'Robert Brownlee Observatory' appears 0 times.
# 'Robinson Observatory' appears 0 times.
# 'Robotic Lunar Observatory (defunct)' appears 0 times.
# 'Roger Twitchell Observatory[3]' appears 0 times.
# 'Rogers Observatory' appears 0 times.
# 'Rolnick Observatory' appears 0 times.
# 'Rome Observatory' appears 0 times.
# 'Roseland Observatory' appears 0 times.
# 'Rossall School Observatory' appears 0 times.
# 'Rothney Astrophysical Observatory' appears 0 times.
# 'Royal Observatory, Greenwich' appears 4 times.
# 'Royal Observatory, Edinburgh' appears 3 times.
# 'Roque de los Muchachos Observatory' appears 6 times.
# 'Rosemary Hill Observatory' appears 0 times.
# 'Rozhen Observatory' appears 4 times.
# 'Rutherford Observatory' appears 0 times.
# 'San Fernando Observatory (SFO)' appears 1 times.
# 'Sankt Andreasberg Observatory' appears 0 times.
# 'Sayan Spectrographic Cosmic Ray Complex' appears 0 times.
# 'SFA Observatory' appears 0 times.
# 'Sagamore Hill Radio Observatory' appears 0 times.
# 'Shattuck Observatory' appears 0 times.
# 'Sherwood Observatory' appears 0 times.
# 'Seven Hills Observatory' appears 0 times.
# 'Shamakhi Astrophysical Observatory' appears 0 times.
# 'Shanghai Astronomical Observatory' appears 11 times.
# 'Sherzer Observatory' appears 0 times.
# 'Sheshan Astronomical Observatory' appears 0 times.
# 'Siding Spring Observatory' appears 25 times.
# 'Sidmouth Observatory' appears 0 times.
# 'Sierra Nevada Observatory' appears 0 times.
# 'Silesian Planetarium and Astronomical Observatory' appears 0 times.
# 'Simeiz Observatory' appears 0 times.
# 'Skalnaté Pleso Observatory' appears 0 times.
# 'Skinakas Observatory' appears 0 times.
# 'Skylab' appears 57 times.
# 'Smith Observatory' appears 0 times.
# 'Smithsonian Astrophysical Observatory' appears 4 times.
# 'Sobaeksan Optical Astronomy Observatory' appears 0 times.
# 'Sola Fide Observatory' appears 0 times.
# 'Solar and Heliospheric Observatory (SOHO)' appears 133 times.
# 'Solar Space Telescope' appears 0 times.
# 'Sommers–Bausch Observatory' appears 0 times.
# 'Sonnenborgh Observatory' appears 0 times.
# 'Sonoma State Observatory' appears 0 times.
# 'South African Astronomical Observatory Cape Town Sutherland' appears 0 times.
# 'Southern Astrophysical Research Telescope (SOAR)' appears 0 times.
# 'South Pole Telescope' appears 19 times.
# 'Spanish National Observatory' appears 0 times.
# 'Special Astrophysical Observatory of the Russian Academy of Sciences' appears 13 times.
# 'Sperry Observatory' appears 0 times.
# 'Spitzer Space Telescope' appears 664 times.
# 'Springfield Observatory' appears 0 times.
# 'Sproul Observatory' appears 0 times.
# 'Stardome Observatory' appears 0 times.
# 'Starkenburg Observatory' appears 0 times.
# 'Štefánik's Observatory' appears 0 times.
# 'Stellafane Observatory' appears 0 times.
# 'Stephens Memorial Observatory' appears 0 times.
# 'Steward Observatory MMT Observatory Mount Graham International Observatory Mount Lemmon Observatory' appears 0 times.
# 'Stickney Observatory[4]' appears 0 times.
# 'Stjerneborg' appears 0 times.
# 'Stockholm Observatory' appears 0 times.
# 'Stokesville Observatory' appears 0 times.
# 'Stone Observatory' appears 0 times.
# 'Stonyhurst Observatory' appears 0 times.
# 'Strasbourg Observatory' appears 0 times.
# 'Stratospheric Observatory for Infrared Astronomy' appears 11 times.
# 'Stull Observatory' appears 0 times.
# 'Stuttgart Observatory' appears 0 times.
# 'Submillimeter Array' appears 152 times.
# 'St. Thomas Observatory' appears 0 times.
# 'Sudbury Neutrino Observatory' appears 15 times.
# 'Sunriver Observatory' appears 0 times.
# 'Swift Gamma-Ray Burst Mission' appears 1 times.
# 'Swiss Observatory Polychron and Astronomy' appears 0 times.
# 'Sydney Observatory' appears 0 times.
# 'Table Mountain Observatory' appears 0 times.
# 'Tacubaya Observatory' appears 0 times.
# 'Taeduk Radio Astronomy Observatory' appears 0 times.
# 'Tamke-Allan Observatory' appears 0 times.
# 'Tartu Observatory' appears 0 times.
# 'Teide Observatory' appears 9 times.
# 'Ten Acre Observatory' appears 0 times.
# 'Terskol Peak Observatory' appears 0 times.
# 'Thai National Observatory' appears 0 times.
# 'The Dam Observatory' appears 0 times.
# 'The Heights Observatory' appears 0 times.
# 'Texas A&M Astronomical Observatory' appears 0 times.
# 'Theodore Jacobsen Observatory' appears 0 times.
# 'Thompson Observatory' appears 0 times.
# 'Tien Shan Astronomical Observatory' appears 0 times.
# 'Tuorla Observatory' appears 5 times.
# 'Trieste Observatory' appears 0 times.
# 'Troodos Observatory' appears 0 times.
# 'Turin Observatory' appears 0 times.
# 'Udaipur Solar Observatory' appears 5 times.
# 'Ukrainian T-shaped Radio telescope, second modification' appears 0 times.
# 'Ulugh Beg Observatory' appears 0 times.
# 'University of Alabama Observatory' appears 0 times.
# 'University of Alabama Observatory (Old)' appears 0 times.
# 'University of North Alabama Observatory' appears 0 times.
# 'University of Illinois Astronomical Observatory' appears 0 times.
# 'University of London Observatory' appears 0 times.
# 'University of Maryland Observatory' appears 0 times.
# 'University of Michigan-Dearborn Observatory' appears 0 times.
# 'University of New Hampshire Observatory' appears 0 times.
# 'University of Oklahoma Observatory' appears 0 times.
# 'University of Puerto Rico at Humacao Observatory[5]' appears 0 times.
# 'University of Valencia Astronomical Observatory' appears 0 times.
# 'Uppsala Astronomical Observatory' appears 0 times.
# 'Urania (Antwerp)' appears 0 times.
# 'Urania (Berlin)' appears 0 times.
# 'Urania (Vienna)' appears 0 times.
# 'Urania Observatory (Zürich)' appears 0 times.
# 'Uraniborg' appears 0 times.
# 'Urumqi Astronomical Observatory' appears 4 times.
# 'U.S. Naval Observatory (USNO)[6] Depot of Charts and Instruments (U.S. Navy) (precursor, renamed to USNO) U.S. Naval Observatory (Flagstaff Station)' appears 0 times.
# 'Valongo Observatory' appears 0 times.
# 'Vainu Bappu Observatory' appears 2 times.
# 'Astronomical observatory of Aosta Valley' appears 0 times.
# 'Van Vleck Observatory' appears 0 times.
# 'Vanderbilt University Observatory' appears 0 times.
# 'Vartiovuori Observatory (defunct)' appears 0 times.
# 'Vassar College Observatory (defunct)' appears 0 times.
# 'Vatican Observatory Vatican Advanced Technology Telescope' appears 0 times.
# 'Veen Observatory' appears 0 times.
# 'Vega–Bray Observatory' appears 0 times.
# 'Ventspils Starptautiskais Radioastronomijas Centrs' appears 0 times.
# 'Vernonia Peak Observatory' appears 0 times.
# 'Very Large Array' appears 661 times.
# 'Very Long Baseline Array' appears 274 times.
# 'Vienna Observatory' appears 0 times.
# 'Vilnius University Observatory' appears 0 times.
# 'Višnjan Observatory' appears 0 times.
# 'Vsetín Observatory' appears 0 times.
# 'Warkworth Radio Observatory' appears 0 times.
# 'Warner Observatory (defunct)' appears 0 times.
# 'Warner and Swasey Observatory' appears 0 times.
# 'Warren Rupp Observatory' appears 0 times.
# 'Warsaw University Observatory' appears 1 times.
# 'Washburn Observatory' appears 0 times.
# 'Wast Hills Observatory' appears 0 times.
# 'Weaver Student Observatory' appears 0 times.
# 'Weitkamp Observatory' appears 0 times.
# 'West Mountain Observatory' appears 0 times.
# 'Whakatane Astronomical Society' appears 0 times.
# 'Whitin Observatory' appears 0 times.
# 'Widener University Observatory' appears 0 times.
# 'Wilder Observatory' appears 0 times.
# 'Willard L. Eccles Observatory' appears 0 times.
# 'William Brydone Jack Observatory' appears 0 times.
# 'Williams Observatory' appears 0 times.
# 'Winer Observatory' appears 1 times.
# 'Winfree Observatory' appears 0 times.
# 'Wise Observatory' appears 19 times.
# 'Witte Observatory' appears 0 times.
# 'WIYN Observatory' appears 2 times.
# 'Wyoming Infrared Observatory' appears 2 times.
# 'Xiangfen Astronomical Observatory' appears 0 times.
# 'Xinglong Station (NAOC)' appears 0 times.
# 'Xinjiang Astronomical Observatory' appears 0 times.
# 'XMM-Newton' appears 885 times.
# 'XRISM' appears 7 times.
# 'Xujiahui Astronomical Observatory' appears 0 times.
# 'Arctic Space Weather Center' appears 0 times.
# 'Yale Student Observatory' appears 0 times.
# 'Yangbajing International Cosmic-Ray Observatory' appears 0 times.
# 'Yantra Mandir' appears 0 times.
# 'Yerevan Cosmic-Ray Station' appears 0 times.
# 'Yerkes Observatory' appears 3 times.
# 'York University Observatory' appears 0 times.
# 'Yuba City Astronomical Observatory' appears 0 times.
# 'Yunnan Astronomical Observatory' appears 3 times.
# 'Zimmerwald Observatory' appears 0 times.
# 'Zadko Observatory' appears 0 times.
# 'AVN-Ghana' appears 0 times.
# 'C-BASS South' appears 0 times.
# 'HartRAO 26m' appears 0 times.
# 'HartRAO XDM' appears 0 times.
# 'Hydrogen Epoch of Reionization Array (HERA)' appears 0 times.
# 'Hydrogen Intensity and Real-time Analysis eXperiment (HIRAX)' appears 0 times.
# 'Indlebe' appears 0 times.
# 'KAT-7' appears 0 times.
# 'MeerKAT' appears 15 times.
# 'Precision Array for Probing the Epoch of Reionization (PAPER)' appears 0 times.
# 'Degree Angular Scale Interferometer (DASI)' appears 6 times.
# 'South Pole Telescope (SPT)' appears 9 times.
# 'Delingha 13.7 m' appears 0 times.
# 'Sheshan' appears 0 times.
# 'Nanshan 25m' appears 0 times.
# 'Primeval Structure Telescope (PaST)' appears 0 times.
# 'Chinese Spectral Radio Heliograph (CSRH)' appears 0 times.
# 'Miyun Synthesis Radio Telescope (MSRT)' appears 0 times.
# 'Miyun 50m Radio Telescope' appears 0 times.
# 'Kunming 40m Radio Telescope' appears 0 times.
# 'Tian Ma 65m Radio Telescope' appears 0 times.
# 'Giant Metrewave Radio Telescope (GMRT)' appears 58 times.
# 'Ooty Radio Telescope (ORT)' appears 0 times.
# 'Nobeyama radio observatory' appears 11 times.
# 'Siberian Solar Radio Telescope (SSRT)' appears 1 times.
# 'Badary Radio Astronomical Observatory' appears 0 times.
# 'Galenki RT-70 radio telescope' appears 0 times.
# 'Suffa RT-70 radio telescope' appears 0 times.
# 'Five hundred meter Aperture Spherical Telescope (FAST)' appears 0 times.
# 'Qitai Radio Telescope' appears 0 times.
# 'Thai National Radio Telescope' appears 0 times.
# 'VERA' appears 14757 times.
# 'Mingantu interplanetary scintillation telescope' appears 0 times.
# 'Taeduk Radio Astronomy Observatory (TRAO)' appears 0 times.
# 'Korean VLBI Network (KVN)' appears 0 times.
# 'Australian Square Kilometre Array Pathfinder (ASKAP)' appears 14 times.
# 'Australia Telescope Compact Array (ATCA)' appears 64 times.
# 'Canberra Deep Space Communication Complex (CDSCC)' appears 0 times.
# 'Ceduna Radio Observatory' appears 0 times.
# 'Mopra Radio Telescope' appears 4 times.
# 'Mount Pleasant Radio Telescope' appears 0 times.
# 'Murchison Widefield Array (MWA)' appears 23 times.
# 'Parkes Radio Telescope' appears 70 times.
# 'Ukrainian T-shaped Radio telescope, second modification (UTR-2)' appears 0 times.
# 'Giant Ukrainian Radio Telescope (GURT)' appears 4 times.
# 'Lovell Telescope' appears 6 times.
# 'Yevpatoria RT-70 radio telescope' appears 0 times.
# 'RATAN-600' appears 11 times.
# 'RT-64 (TNA-1500)' appears 0 times.
# 'RT-22' appears 1 times.
# 'DKR-1000' appears 0 times.
# 'BSA' appears 605 times.
# 'Radioastronomical Observatory Zelenchukskaya' appears 0 times.
# 'Svetloe Radio Astronomical Observatory' appears 0 times.
# 'RT-7.5 (Bauman's radio telescope)' appears 0 times.
# 'Yebes RT 40 m' appears 0 times.
# 'Toruń RT4 32 m' appears 0 times.
# 'RT-32' appears 0 times.
# 'Northern Cross Radio Telescope' appears 0 times.
# '32 m VLBI dish' appears 0 times.
# 'MERLIN (Multi-Element Radio Linked Interferometer Network)' appears 0 times.
# 'EAARO – East Anglian Astrophysiscal Research Organisation' appears 0 times.
# 'TNA-400' appears 0 times.
# 'IRAM – 30m' appears 0 times.
# 'Mark II' appears 31 times.
# 'Stockert' appears 0 times.
# 'Toruń RT3 15 m' appears 0 times.
# 'Westerbork Synthesis Radio Telescope (WSRT)' appears 18 times.
# '25 m telescope' appears 0 times.
# 'Dwingeloo (CAMRAS)' appears 0 times.
# '22 m telescope' appears 0 times.
# '20 m telescope' appears 0 times.
# 'Pluton (complex)' appears 0 times.
# 'RT-16' appears 0 times.
# 'Metsähovi Radio Observatory' appears 8 times.
# 'Ryle Telescope' appears 17 times.
# 'Erciyes University Radio Observatory' appears 0 times.
# 'Wurzburg v2.0 LAB/OASU (Bordeaux Observatory radio telescope)' appears 0 times.
# 'European VLBI Network (EVN)' appears 5 times.
# 'Plateau de Bure Interferometer' appears 42 times.
# 'Northern Extended Millimeter Array' appears 0 times.
# 'Nançay Radio Telescope (NRT)' appears 0 times.
# 'Nançay Decameter Array (DAM)' appears 0 times.
# 'Nançay Radio Heliographe (NRH)' appears 0 times.
# 'ALLBIN (Amateur Linked Long Baseline Interferometer Network)' appears 0 times.
# 'LOFAR (LOw Frequency ARray)' appears 0 times.
# 'São Gião radio telescope (SGRT)' appears 0 times.
# 'Arcminute Microkelvin Imager' appears 2 times.
# 'The European Radio Astronomy Club Telescope and Development Facility (ERAC Telescope)' appears 0 times.
# 'ERAC Phased Array' appears 0 times.
# '64 m Sardinia Radio Telescope' appears 0 times.
# 'ROT-54/2.6' appears 0 times.
# 'Algonquin Radio Telescope' appears 0 times.
# 'Allen Telescope Array' appears 17 times.
# 'ARO 12m Radio Telescope' appears 0 times.
# 'C-BASS North' appears 0 times.
# 'Canadian Hydrogen Intensity Mapping Experiment (CHIME)' appears 3 times.
# 'CfA 1.2 m Millimeter-Wave Telescope' appears 0 times.
# 'Combined Array for Research in Millimeter-wave Astronomy (CARMA)' appears 3 times.
# 'Distributed Array Radio Telescope (DART)' appears 0 times.
# 'Five College Radio Astronomy Observatory (FCRAO)' appears 0 times.
# 'Goldstone Radio Telescope' appears 0 times.
# 'Green Bank Interferometer (GBI)' appears 0 times.
# 'Green Bank Telescope (GBT)' appears 24 times.
# 'Green Bank 140 Foot Telescope (140foot)' appears 0 times.
# 'Green Bank 20m Telescope' appears 0 times.
# 'Heinrich Hertz Submillimeter Telescope (SMT)' appears 2 times.
# 'Large Millimeter Telescope (LMT)' appears 0 times.
# 'Leuschner Observatory' appears 0 times.
# 'Long Wavelength Array (LWA)' appears 0 times.
# 'Morehead State University 21m.' appears 0 times.
# 'Paul Plishner Radio Astronomy and Space Sciences Center' appears 0 times.
# 'OVRO 40 meter Telescope' appears 0 times.
# 'Solar monitor, two 1.8 m dishes' appears 0 times.
# 'SRI International Antenna Facility' appears 0 times.
# 'Synthesis Telescope, seven-element interferometer' appears 0 times.
# 'Very Large Array (VLA)' appears 216 times.
# 'Very Small Array (VSA)' appears 4 times.
# 'Very Long Baseline Array (VLBA)' appears 122 times.
# 'Pisgah Astronomical Research Institute (PARI)' appears 0 times.
# 'Atacama B-Mode Search (ABS)' appears 0 times.
# 'Atacama Cosmology Telescope (ACT)' appears 15 times.
# 'Atacama Large Millimeter Array (ALMA)' appears 11 times.
# 'Atacama Submillimeter Telescope Experiment (ASTE)' appears 4 times.
# 'Baryon Acoustic Oscillations in Integrated Neutral Gas Observations (BINGO)' appears 0 times.
# 'Brazilian Decimetric Array (BDA)' appears 0 times.
# 'Cosmic Background Imager (CBI)' appears 21 times.
# 'Itapetinga Radio Observatory' appears 0 times.
# 'Jicamarca Radio Observatory (ROJ)' appears 0 times.
# 'Cosmology Large Angular Scale Surveyor (CLASS)' appears 1 times.
# 'NANTEN2 Observatory (NANTEN2)' appears 0 times.
# 'Northeastern Space Radio Observatory' appears 0 times.
# 'Polarization Emission of Millimeter Activity at the Sun' appears 0 times.
# 'Q/U Imaging Experiment (QUIET)' appears 0 times.
# 'Solar Submillimeter Telescope (SST)' appears 0 times.
# 'Swedish-ESO Submillimetre Telescope (SEST)' appears 8 times.
# 'Estación de Espacio Lejano [es]' appears 0 times.
# 'Malargüe Station' appears 0 times.
# 'Greenland Telescope' appears 0 times.
# 'Eiscat Radio Telescope' appears 0 times.
# 'Arecibo Telescope' appears 40 times.
# 'Mauritius Radio Telescope' appears 0 times.
# 'Caltech Submillimeter Observatory' appears 39 times.
# 'Submillimeter Array (SMA)' appears 23 times.
# 'Warkworth Radio Telescope' appears 0 times.
# 'Warkworth 2 dish' appears 0 times.
# 'Transient Array Radio Telescope' appears 0 times.
# 'HALCA (Highly Advanced Laboratory for Communications and Astronomy)' appears 0 times.
# 'Zond 3' appears 0 times.
# 'Spektr-R or RadioAstron' appears 0 times.
# 'Chang'e 4' appears 0 times.
# 'EAARO - East Anglian Astrophysical Research Organisation' appears 0 times.
# 'Large Latin American Millimeter Array (LLAMA)' appears 0 times.
# 'Qitai 110m Radio Telescope (QTT)' appears 0 times.
# 'Square Kilometer Array (SKA-Phase1)' appears 0 times.
# '30m Sub-Millimeter Telescope (TSMT)' appears 0 times.
# 'LOFAR Super Station (LSS)' appears 0 times.
# 'Lunar Crater Radio Telescope (LCRT)' appears 0 times.
# 'Square Kilometer Array (SKA-Phase2)' appears 0 times.
# 'Daniel K. Inouye Solar Telescope (DKIST)' appears 6 times.
# 'Chinese Large Solar Telescope (CLST)' appears 0 times.
# 'GREGOR, Teide Observatory' appears 0 times.
# 'Goode Solar Telescope (GST), Big Bear Solar Observatory' appears 0 times.
# 'New Vacuum Solar Telescope (NVST), Yunnan Astronomical Observatory' appears 0 times.
# 'Andrei Severny Tower Solar Telescope, Crimean Astrophysical Observatory' appears 0 times.
# 'Multi-Purpose Automated Solar Telescope, Sayan Solar Observatory' appears 0 times.
# 'Large Solar Vakuum Telescope, Baikal Astrophysical Observatory' appears 0 times.
# 'Optical and Near-Infrared Solar Eruption Tracer (ONSET), School of Astronomy & Space Science, Nanjing University' appears 0 times.
# 'Bulgarian 15-cm Solar Coronagraph,[10] Rozhen National Astronomical Observatory Bulgaria' appears 0 times.
# 'Swedish Solar Telescope (SST), Roque de los Muchachos Observatory' appears 0 times.
# 'Prairie View Solar Observatory (PVSO)[12]' appears 0 times.
# 'Upgraded Coronal Multi-Channel Polarimeter (UCOMP)' appears 0 times.
# 'K-Coronagraph (K-COR)' appears 0 times.
# 'Dutch Open Telescope (DOT), Roque de los Muchachos Observatory' appears 0 times.
# 'THÉMIS Solar Telescope, Teide Observatory' appears 0 times.
# 'Vacuum Tower Telescope (VTT), Teide Observatory' appears 0 times.
# 'Hida Domeless Solar Telescope (ja)' appears 0 times.
# 'Udaipur Solar ObservatoryMASTFull Disk H-alpha TelescopeH-alpha Spar TelescopeCoudé Telescope' appears 0 times.
# 'Richard B. Dunn Solar Telescope (DST), Sacramento Peak' appears 0 times.
# 'Solar Observatory Tower Meudon' appears 0 times.
# 'McMath–Pierce solar telescope, KPO' appears 0 times.
# 'ARIES Observatory' appears 0 times.
# 'Solar Tunnel Telescope, Kodaikanal Solar Observatory' appears 0 times.
# '45-cm-Turmteleskop' appears 0 times.
# 'Gregory Coudé Telescope' appears 0 times.
# 'Solar Tower Telescope by Zeiss' appears 0 times.
# 'Einsteinturm' appears 0 times.
# '150-foot tower, Mount Wilson Observatory' appears 0 times.
# 'Snow Solar Telescope, Mount Wilson Observatory' appears 0 times.
# 'Lerebour/Grubb-Parsons, Kodaikanal Solar Observatory' appears 0 times.
# 'Solar-T [pt]' appears 0 times.
# 'Swedish Vacuum Solar Telescope, Roque de los Muchachos Observatory' appears 0 times.
# 'Gregory Coude Telescope (GCT)' appears 0 times.
# 'Evans Solar Facility (ESF), Sacramento Peak' appears 0 times.
# 'Göttinger Sonnenturm (Solar Tower Telescope)' appears 0 times.
# 'McMath-Hulbert Observatory' appears 0 times.
# '50-foot tower, McMath-Hulbert Observatory' appears 0 times.
# '10.5 inch, McMath-Hulbert Observatory' appears 0 times.
# 'Arcetri Solar Tower, Arcetri Observatory' appears 0 times.
# 'Chinese Spectral Radioheliograph (CSRH)' appears 0 times.
# 'Nançay Radioheliographe (NRH), Nançay Radio Observatory' appears 0 times.
# 'Expanded Owens Valley Solar Array (EOVSA)' appears 0 times.
# 'Nobeyama Radioheliograph (NoRH), Nobeyama Radio Observatory' appears 0 times.
# 'Nobeyama Radio Polarimeters, Nobeyama Radio Observatory' appears 0 times.
# 'Solar Submillimeter Telescope (SST), Complejo Astronomico El Leoncito' appears 0 times.
# 'Polarization Emission of Millimeter Activity at the Sun (POEMAS), Complejo Astronomico El Leoncito' appears 0 times.
# 'Bleien Radio Observatory' appears 0 times.
# 'Radio Solar Telescope Network (RSTN)' appears 4 times.
# 'Proton-1' appears 0 times.
# 'Proton-2' appears 0 times.
# 'Proton-4' appears 0 times.
# 'Small Astronomy Satellite 2 (SAS-B)' appears 0 times.
# 'Cos-B' appears 11 times.
# 'High Energy Astronomy Observatory 3 (HEAO 3)' appears 0 times.
# 'Granat' appears 16 times.
# 'Gamma' appears 4273 times.
# 'Compton Gamma Ray Observatory (CGRO)' appears 43 times.
# 'Low Energy Gamma Ray Imager (LEGRI)' appears 0 times.
# 'High Energy Transient Explorer 2 (HETE 2)' appears 0 times.
# 'International Gamma Ray Astrophysics Laboratory (INTEGRAL)' appears 0 times.
# 'Swift Gamma Ray Burst Explorer' appears 0 times.
# 'Astrorivelatore Gamma ad Immagini LEggero (AGILE)' appears 0 times.
# 'Gamma-Ray Burst Polarimeter (GAP)' appears 2 times.
# 'Uhuru (Small Astronomy Satellite 1, SAS-A)' appears 0 times.
# 'Astronomical Netherlands Satellite (ANS)' appears 4 times.
# 'Ariel V' appears 11 times.
# 'Aryabhata' appears 0 times.
# 'Small Astronomy Satellite 3 (SAS-C)' appears 0 times.
# 'Cosmic Radiation Satellite (CORSA)' appears 0 times.
# 'High Energy Astronomy Observatory 1 (HEAO 1)' appears 0 times.
# 'Einstein Observatory (HEAO 2)' appears 0 times.
# 'Hakucho (CORSA-b)' appears 0 times.
# 'Tenma (Astro-B)' appears 0 times.
# 'Astron' appears 3137 times.
# 'EXOSAT' appears 34 times.
# 'Ginga (Astro-C)' appears 0 times.
# 'ROSAT' appears 853 times.
# 'Broad Band X-ray Telescope / Astro 1' appears 0 times.
# 'Advanced Satellite for Cosmology and Astrophysics (ASCA, Astro-D)' appears 0 times.
# 'Array of Low Energy X-ray Imaging Sensors (Alexis)' appears 0 times.
# 'Rossi X-ray Timing Explorer (RXTE)' appears 174 times.
# 'BeppoSAX' appears 238 times.
# 'A Broadband Imaging X-ray All-sky Survey (ABRIXAS)' appears 0 times.
# 'Suzaku (Astro-E2)' appears 0 times.
# 'AGILE' appears 80 times.
# 'Nuclear Spectroscopic Telescope Array (NuSTAR)' appears 2 times.
# 'Astrosat' appears 43 times.
# 'Hitomi (Astro-H)' appears 0 times.
# 'Mikhailo Lomonosov' appears 0 times.
# 'Neutron Star Interior Composition Explorer (NICER)' appears 3 times.
# 'Hard X-ray Modulation Telescope (HXMT)' appears 3 times.
# 'Spektr-RG' appears 2 times.
# 'OAO-2 (Stargazer)' appears 0 times.
# 'Orion 1 and Orion 2 Space Observatories' appears 0 times.
# 'Far Ultraviolet Camera/Spectrograph (UVC)' appears 0 times.
# 'OAO-3 Copernicus' appears 0 times.
# 'International Ultraviolet Explorer (IUE)' appears 46 times.
# 'Extreme Ultraviolet Explorer (EUVE)' appears 35 times.
# 'Astro 2' appears 0 times.
# 'Far Ultraviolet Spectroscopic Explorer (FUSE)' appears 119 times.
# 'Cosmic Hot Interstellar Spectrometer (CHIPS)' appears 0 times.
# 'Korea Advanced Institute of Science and Technology Satellite 4 (Kaistsat 4)' appears 0 times.
# 'Swift Gamma Ray Burst Explorer (Swift)' appears 0 times.
# 'Interface Region Imaging Spectrograph (IRIS)' appears 16 times.
# 'Hisaki (SPRINT-A)' appears 0 times.
# 'Venus Spectral Rocket Experiment' appears 0 times.
# 'Lunar-based ultraviolet telescope (LUT)' appears 0 times.
# 'Spatial Heterodyne Interferometric Emission Line Dynamics Spectrometer (SHIELDS)' appears 0 times.
# 'Hipparcos' appears 465 times.
# 'MOST' appears 17492 times.
# 'Kepler' appears 1154 times.
# 'BRITE constellation' appears 0 times.
# 'Near Earth Object Surveillance Satellite (NEOSSat)' appears 0 times.
# 'Gaia (astrometry)' appears 0 times.
# 'Transiting Exoplanet Survey Satellite (TESS)' appears 14 times.
# 'CHEOPS' appears 11 times.
# 'IRAS' appears 1113 times.
# 'Infrared Telescope in Space' appears 8 times.
# 'Infrared Space Observatory (ISO)' appears 136 times.
# 'Midcourse Space Experiment (MSX)' appears 18 times.
# 'Submillimeter Wave Astronomy Satellite (SWAS)' appears 4 times.
# 'Wide Field Infrared Explorer (WIRE)' appears 2 times.
# 'Akari (Astro-F)' appears 0 times.
# 'Wide-field Infrared Survey Explorer (WISE)' appears 15 times.
# 'James Webb Space Telescope (JWST)' appears 35 times.
# 'Euclid' appears 81 times.
# 'Cosmic Background Explorer (COBE)' appears 43 times.
# 'Odin' appears 290 times.
# 'WMAP' appears 380 times.
# 'Planck' appears 485 times.
# 'Highly Advanced Laboratory for Communications and Astronomy (HALCA, VSOP or MUSES-B)' appears 0 times.
# 'Spektr-R (RadioAstron)' appears 0 times.
# 'High Energy Astrophysics Observatory 3 (HEAO 3)' appears 0 times.
# 'SAMPEX' appears 4 times.
# 'Alpha Magnetic Spectrometer 01 (AMS-01)' appears 0 times.
# 'Payload for Antimatter Matter Exploration and Light-nuclei Astrophysics (PAMELA)' appears 0 times.
# 'IBEX' appears 14 times.
# 'Alpha Magnetic Spectrometer 02 (AMS-02)' appears 0 times.
# 'Lunar Surface Gravimeter' appears 0 times.
# 'X-ray Polarimeter Satellite (XPoSat)' appears 0 times.
# 'International Lunar Observatory Precursor (ILO-X)' appears 0 times.
# 'TOLIMAN' appears 0 times.
# 'Xuntian' appears 0 times.
# 'SPHEREx' appears 2 times.
# 'Astrosat-2' appears 0 times.
# 'PLATO' appears 12 times.
# 'ULTRASAT' appears 0 times.
# 'Nancy Grace Roman Space Telescope (Wide Field Infrared Survey Telescope; WFIRST)' appears 0 times.
# 'ARIEL' appears 56 times.
# 'Advanced Telescope for High Energy Astrophysics (Athena)' appears 4 times.
# 'Laser Interferometer Space Antenna (LISA)' appears 69 times.

# %%
def generate_bigrams(label):
    #Generate bigrams from a given label.
    tokens = label.split()
    return [" ".join(tokens[i:i+2]) for i in range(len(tokens)-1)]


# Process each label and count occurrences of its tokens and bigrams
for idx, label in enumerate(Labels['Labels']):
    # Token counts
    tokens = label.split()  # Split the label into tokens
    token_counts = [abstract_df.str.contains(re.escape(token), case=False, na=False).sum() for token in tokens]
    print(f"{tokens} appears {token_counts} times in abstracts data.")
    
    # Bigram counts
    bigrams = generate_bigrams(label)
    bigram_counts = [abstract_df.str.contains(re.escape(bigram), case=False, na=False).sum() for bigram in bigrams]
    print(f"{bigrams} appears {bigram_counts} times in abstracts data.")
    print('-' * 80)
# Out:
# ['Abastumani', 'Astrophysical', 'Observatory'] appears [5, 1907, 3950] times in abstracts data.
# ['Abastumani Astrophysical', 'Astrophysical Observatory'] appears [0, 112] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Abu', 'Reyhan-e', 'Birooni', 'Observatory'] appears [6344, 0, 0, 3950] times in abstracts data.
# ['Abu Reyhan-e', 'Reyhan-e Birooni', 'Birooni Observatory'] appears [0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Adirondack', 'Public', 'Observatory'] appears [0, 668, 3950] times in abstracts data.
# ['Adirondack Public', 'Public Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Adolphson', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Adolphson Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Airdrie', 'Public', 'Observatory'] appears [0, 668, 3950] times in abstracts data.
# ['Airdrie Public', 'Public Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Aker', 'Observatory'] appears [1001, 3950] times in abstracts data.
# ['Aker Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Aldershot', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Aldershot Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Algonquin', 'Radio', 'Observatory'] appears [0, 9524, 3950] times in abstracts data.
# ['Algonquin Radio', 'Radio Observatory'] appears [0, 98] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Allegheny', 'Observatory'] appears [3, 3950] times in abstracts data.
# ['Allegheny Observatory'] appears [1] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Ametlla', 'de', 'Mar', 'Observatory'] appears [0, 62741, 9995, 3950] times in abstracts data.
# ['Ametlla de', 'de Mar', 'Mar Observatory'] appears [0, 35, 56] times in abstracts data.
# --------------------------------------------------------------------------------
# ['AMiBA'] appears [0] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Anderson', 'Mesa', 'Station'] appears [14, 10, 879] times in abstracts data.
# ['Anderson Mesa', 'Mesa Station'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Angell', 'Hall', 'Observatory'] appears [0, 2557, 3950] times in abstracts data.
# ['Angell Hall', 'Hall Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Ankara', 'University', 'Observatory'] appears [1, 617, 3950] times in abstracts data.
# ['Ankara University', 'University Observatory'] appears [1, 28] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Antarctic', 'Muon', 'and', 'Neutrino', 'Detector', 'Array'] appears [75, 134, 62845, 1141, 1412, 2905] times in abstracts data.
# ['Antarctic Muon', 'Muon and', 'and Neutrino', 'Neutrino Detector', 'Detector Array'] appears [0, 9, 157, 38, 40] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Antarctic', 'Submillimeter', 'Telescope', 'and', 'Remote', 'Observatory'] appears [75, 843, 10808, 62845, 253, 3950] times in abstracts data.
# ['Antarctic Submillimeter', 'Submillimeter Telescope', 'Telescope and', 'and Remote', 'Remote Observatory'] appears [10, 59, 638, 32, 10] times in abstracts data.
# --------------------------------------------------------------------------------
# ['ANTARES'] appears [28] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Apache-Sitgreaves', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Apache-Sitgreaves Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Apache', 'Point', 'Observatory'] appears [39, 6078, 3950] times in abstracts data.
# ['Apache Point', 'Point Observatory'] appears [39, 37] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Apatity', 'Cosmic-Ray', 'Station'] appears [1, 773, 879] times in abstracts data.
# ['Apatity Cosmic-Ray', 'Cosmic-Ray Station'] appears [0, 3] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Apollo', 'Observatory'] appears [45, 3950] times in abstracts data.
# ['Apollo Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Arcetri', 'Observatory'] appears [5, 3950] times in abstracts data.
# ['Arcetri Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Arecibo', 'Observatory'] appears [234, 3950] times in abstracts data.
# ['Arecibo Observatory'] appears [46] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Argentine', 'Institute', 'of', 'Radio', 'Astronomy'] appears [5, 314, 63810, 9524, 1242] times in abstracts data.
# ['Argentine Institute', 'Institute of', 'of Radio', 'Radio Astronomy'] appears [0, 137, 1524, 175] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Armagh', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Armagh Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Aryabhatta', 'Research', 'Institute', 'of', 'Observational', 'Sciences'] appears [4, 1054, 314, 63810, 5662, 163] times in abstracts data.
# ['Aryabhatta Research', 'Research Institute', 'Institute of', 'of Observational', 'Observational Sciences'] appears [4, 26, 137, 339, 4] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Ashton', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Ashton Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Asiago', 'Astrophysical', 'Observatory'] appears [15, 1907, 3950] times in abstracts data.
# ['Asiago Astrophysical', 'Astrophysical Observatory'] appears [0, 112] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Assheton', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Assheton Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Astron', '(defunct)'] appears [3137, 0] times in abstracts data.
# ['Astron (defunct)'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Astronomical', 'Observatory', 'Aurora'] appears [1486, 3950, 233] times in abstracts data.
# ['Astronomical Observatory', 'Observatory Aurora'] appears [113, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Astronomical', 'Observatory', 'of', 'Lisbon'] appears [1486, 3950, 63810, 1] times in abstracts data.
# ['Astronomical Observatory', 'Observatory of', 'of Lisbon'] appears [113, 127, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Astronomy', 'Centre'] appears [1242, 1880] times in abstracts data.
# ['Astronomy Centre'] appears [6] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Astronomy', 'Tower', 'of', 'the', 'Sorbonne'] appears [1242, 52, 63810, 63868, 11] times in abstracts data.
# ['Astronomy Tower', 'Tower of', 'of the', 'the Sorbonne'] appears [0, 3, 58406, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Astrophysical', 'Institute', 'Potsdam'] appears [1907, 314, 21] times in abstracts data.
# ['Astrophysical Institute', 'Institute Potsdam'] appears [9, 3] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Atacama', 'Pathfinder', 'Experiment', '(APEX)'] appears [132, 77, 2619, 2] times in abstracts data.
# ['Atacama Pathfinder', 'Pathfinder Experiment', 'Experiment (APEX)'] appears [3, 4, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Australia', 'Telescope', 'Compact', 'Array'] appears [530, 10808, 4627, 2905] times in abstracts data.
# ['Australia Telescope', 'Telescope Compact', 'Compact Array'] appears [255, 217, 218] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Australian', 'Astronomical', 'Observatory'] appears [208, 1486, 3950] times in abstracts data.
# ['Australian Astronomical', 'Astronomical Observatory'] appears [1, 113] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Badlands', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Badlands Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Baikal', 'Deep', 'Underwater', 'Neutrino', 'Telescope'] appears [7, 4638, 4, 1141, 10808] times in abstracts data.
# ['Baikal Deep', 'Deep Underwater', 'Underwater Neutrino', 'Neutrino Telescope'] appears [0, 0, 0, 57] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bangladesh', 'Astronomical', 'Observatory'] appears [0, 1486, 3950] times in abstracts data.
# ['Bangladesh Astronomical', 'Astronomical Observatory'] appears [0, 113] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Baker', 'Observatory'] appears [11, 3950] times in abstracts data.
# ['Baker Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Baksan', 'Neutrino', 'Observatory'] appears [12, 1141, 3950] times in abstracts data.
# ['Baksan Neutrino', 'Neutrino Observatory'] appears [4, 33] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Ball', 'State', 'University', 'Observatory'] appears [857, 5139, 617, 3950] times in abstracts data.
# ['Ball State', 'State University', 'University Observatory'] appears [0, 68, 28] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Barnard', 'Observatory', '(defunct)'] appears [41, 3950, 0] times in abstracts data.
# ['Barnard Observatory', 'Observatory (defunct)'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bareket', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Bareket Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Barnett', 'Observatory'] appears [1, 3950] times in abstracts data.
# ['Barnett Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bayfordbury', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Bayfordbury Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Behlen', 'Observatory'] appears [4, 3950] times in abstracts data.
# ['Behlen Observatory'] appears [4] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Beijing', 'Astronomical', 'Observatory'] appears [35, 1486, 3950] times in abstracts data.
# ['Beijing Astronomical', 'Astronomical Observatory'] appears [10, 113] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Beijing', 'Ancient', 'Observatory'] appears [35, 225, 3950] times in abstracts data.
# ['Beijing Ancient', 'Ancient Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Belgrade', 'Observatory'] appears [12, 3950] times in abstracts data.
# ['Belgrade Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Belogradchik', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Belogradchik Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Benmore', 'Peak', 'Observatory'] appears [0, 5495, 3950] times in abstracts data.
# ['Benmore Peak', 'Peak Observatory'] appears [0, 2] times in abstracts data.
# --------------------------------------------------------------------------------
# ['BeppoSAX', '(defunct)'] appears [238, 0] times in abstracts data.
# ['BeppoSAX (defunct)'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bergisch', 'Gladbach', 'Observatory'] appears [1, 0, 3950] times in abstracts data.
# ['Bergisch Gladbach', 'Gladbach Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Berlin', 'Observatory'] appears [6, 3950] times in abstracts data.
# ['Berlin Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Besançon', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Besançon Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['BESS'] appears [60] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bidston', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Bidston Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Big', 'Bear', 'Lake', 'Solar', 'Observatory'] appears [1987, 395, 38, 10845, 3950] times in abstracts data.
# ['Big Bear', 'Bear Lake', 'Lake Solar', 'Solar Observatory'] appears [41, 0, 0, 141] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bisdee', 'Tier', 'Optical', 'Astronomy', 'Observatory'] appears [0, 125, 12092, 1242, 3950] times in abstracts data.
# ['Bisdee Tier', 'Tier Optical', 'Optical Astronomy', 'Astronomy Observatory'] appears [0, 0, 24, 92] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Black', 'Moshannon', 'Observatory', '(defunct)'] appears [6992, 0, 3950, 0] times in abstracts data.
# ['Black Moshannon', 'Moshannon Observatory', 'Observatory (defunct)'] appears [0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Blackett', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Blackett Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Blue', 'Mesa', 'Observatory', '(defunct)'] appears [3619, 10, 3950, 0] times in abstracts data.
# ['Blue Mesa', 'Mesa Observatory', 'Observatory (defunct)'] appears [0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Boambee', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Boambee Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bohyunsan', 'Optical', 'Astronomy', 'Observatory', '(BOAO)'] appears [2, 12092, 1242, 3950, 0] times in abstracts data.
# ['Bohyunsan Optical', 'Optical Astronomy', 'Astronomy Observatory', 'Observatory (BOAO)'] appears [2, 24, 92, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['BOOTES'] appears [67] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bordeaux', 'Observatory'] appears [2, 3950] times in abstracts data.
# ['Bordeaux Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bosscha', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Bosscha Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Boswell', 'Observatory', '(defunct)'] appears [0, 3950, 0] times in abstracts data.
# ['Boswell Observatory', 'Observatory (defunct)'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bowman', 'Observatory'] appears [4, 3950] times in abstracts data.
# ['Bowman Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Boyden', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Boyden Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bradstreet', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Bradstreet Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bradley', 'Observatory'] appears [7, 3950] times in abstracts data.
# ['Bradley Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Braeside', 'Observatory', '(defunct)'] appears [0, 3950, 0] times in abstracts data.
# ['Braeside Observatory', 'Observatory (defunct)'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Brera', 'Observatory'] appears [11, 3950] times in abstracts data.
# ['Brera Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bridgewater', 'State', 'University', 'Observatory'] appears [0, 5139, 617, 3950] times in abstracts data.
# ['Bridgewater State', 'State University', 'University Observatory'] appears [0, 68, 28] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Brooks', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Brooks Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Brooks', 'Astronomical', 'Observatory'] appears [0, 1486, 3950] times in abstracts data.
# ['Brooks Astronomical', 'Astronomical Observatory'] appears [0, 113] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Brorfelde', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Brorfelde Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bucharest', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Bucharest Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Bucknell', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Bucknell Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Burrell', 'Memorial', 'Observatory'] appears [2, 7, 3950] times in abstracts data.
# ['Burrell Memorial', 'Memorial Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Byurakan', 'Observatory'] appears [37, 3950] times in abstracts data.
# ['Byurakan Observatory'] appears [5] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cagigal', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Cagigal Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cagliari', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Cagliari Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Calais', 'Observatory', '(defunct)'] appears [0, 3950, 0] times in abstracts data.
# ['Calais Observatory', 'Observatory (defunct)'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Calar', 'Alto', 'Observatory'] appears [348, 152, 3950] times in abstracts data.
# ['Calar Alto', 'Alto Observatory'] appears [32, 12] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Caltech', 'Submillimeter', 'Observatory', '(defunct)'] appears [89, 843, 3950, 0] times in abstracts data.
# ['Caltech Submillimeter', 'Submillimeter Observatory', 'Observatory (defunct)'] appears [44, 39, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cambridge', 'Observatory'] appears [83, 3950] times in abstracts data.
# ['Cambridge Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Camille', 'Flammarion', 'Observatory'] appears [0, 0, 3950] times in abstracts data.
# ['Camille Flammarion', 'Flammarion Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Campbelltown', 'Rotary', 'Observatory'] appears [0, 0, 3950] times in abstracts data.
# ['Campbelltown Rotary', 'Rotary Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Campo', 'Imperatore', 'Near-Earth', 'Object', 'Survey'] appears [12, 1, 138, 11475, 11372] times in abstracts data.
# ['Campo Imperatore', 'Imperatore Near-Earth', 'Near-Earth Object', 'Object Survey'] appears [1, 0, 36, 13] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Canopus', 'Hill', 'Observatory'] appears [6, 261, 3950] times in abstracts data.
# ['Canopus Hill', 'Hill Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Capilla', 'Peak', 'Observatory'] appears [0, 5495, 3950] times in abstracts data.
# ['Capilla Peak', 'Peak Observatory'] appears [0, 2] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Capodimonte', 'Observatory'] appears [5, 3950] times in abstracts data.
# ['Capodimonte Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Carter', 'Observatory'] appears [11, 3950] times in abstracts data.
# ['Carter Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Catania', 'Astrophysical', 'Observatory'] appears [9, 1907, 3950] times in abstracts data.
# ['Catania Astrophysical', 'Astrophysical Observatory'] appears [3, 112] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cawthron', 'Atkinson', 'Observatory'] appears [0, 0, 3950] times in abstracts data.
# ['Cawthron Atkinson', 'Atkinson Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Celestial', 'Observatory'] appears [301, 3950] times in abstracts data.
# ['Celestial Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Centennial', 'Observatory'] appears [7, 3950] times in abstracts data.
# ['Centennial Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Center', 'for', 'Astrophysics', '|', 'Harvard', '&', 'Smithsonian'] appears [4689, 56668, 1088, 575, 78, 3299, 32] times in abstracts data.
# ['Center for', 'for Astrophysics', 'Astrophysics |', '| Harvard', 'Harvard &', '& Smithsonian'] appears [122, 117, 2, 2, 4, 4] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cerro', 'Armazones', 'Observatory'] appears [140, 3, 3950] times in abstracts data.
# ['Cerro Armazones', 'Armazones Observatory'] appears [3, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cerro', 'Tololo', 'Inter-American', 'Observatory'] appears [140, 133, 93, 3950] times in abstracts data.
# ['Cerro Tololo', 'Tololo Inter-American', 'Inter-American Observatory'] appears [114, 93, 89] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cerro', 'Pachón', 'Observatory'] appears [140, 0, 3950] times in abstracts data.
# ['Cerro Pachón', 'Pachón Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Chabot', 'Space', '&', 'Science', 'Center'] appears [0, 10148, 3299, 1385, 4689] times in abstracts data.
# ['Chabot Space', 'Space &', '& Science', 'Science Center'] appears [0, 0, 0, 17] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Chamberlin', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Chamberlin Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Changchun', 'Astronomical', 'Observatory'] appears [0, 1486, 3950] times in abstracts data.
# ['Changchun Astronomical', 'Astronomical Observatory'] appears [0, 113] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Chandra', 'X-ray', 'Observatory'] appears [2630, 11374, 3950] times in abstracts data.
# ['Chandra X-ray', 'X-ray Observatory'] appears [716, 519] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Chianti', 'Polifunctional', 'Observatory'] appears [17, 0, 3950] times in abstracts data.
# ['Chianti Polifunctional', 'Polifunctional Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Chico', 'Community', 'Observatory'] appears [1, 297, 3950] times in abstracts data.
# ['Chico Community', 'Community Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Chilbolton', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Chilbolton Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cima', 'Ekar', 'Observing', 'Station'] appears [15, 17, 1319, 879] times in abstracts data.
# ['Cima Ekar', 'Ekar Observing', 'Observing Station'] appears [0, 0, 17] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cincinnati', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Cincinnati Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['City', 'Observatory,', 'Edinburgh'] appears [15518, 451, 22] times in abstracts data.
# ['City Observatory,', 'Observatory, Edinburgh'] appears [0, 3] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Clarke', 'Observatory'] appears [13, 3950] times in abstracts data.
# ['Clarke Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Class', 'of', '1951', 'Observatory'] appears [7015, 63810, 32, 3950] times in abstracts data.
# ['Class of', 'of 1951', '1951 Observatory'] appears [1231, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cloudcroft', 'Observatory', '(defunct)'] appears [3, 3950, 0] times in abstracts data.
# ['Cloudcroft Observatory', 'Observatory (defunct)'] appears [2, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Coats', 'Observatory'] appears [1, 3950] times in abstracts data.
# ['Coats Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Coit', 'Observatory'] appears [2, 3950] times in abstracts data.
# ['Coit Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Collins', 'Observatory'] appears [2, 3950] times in abstracts data.
# ['Collins Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Collm', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Collm Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Colombo', 'University', 'Observatory'] appears [10, 617, 3950] times in abstracts data.
# ['Colombo University', 'University Observatory'] appears [0, 28] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Compton', 'Gamma-Ray', 'Observatory', '(defunct)'] appears [1581, 3389, 3950, 0] times in abstracts data.
# ['Compton Gamma-Ray', 'Gamma-Ray Observatory', 'Observatory (defunct)'] appears [47, 67, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['ÇOMÜ', 'Ulupınar', 'Observatory'] appears [0, 0, 3950] times in abstracts data.
# ['ÇOMÜ Ulupınar', 'Ulupınar Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Concordia', 'College', 'Observatory'] appears [8, 77, 3950] times in abstracts data.
# ['Concordia College', 'College Observatory'] appears [0, 14] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Consell', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Consell Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Copenhagen', 'University', 'Observatory'] appears [20, 617, 3950] times in abstracts data.
# ['Copenhagen University', 'University Observatory'] appears [0, 28] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cordell–Lorenz', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Cordell–Lorenz Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['COROT'] appears [483] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cosmic', 'Background', 'Imager', '(CBI)', '(defunct)'] appears [5786, 4430, 698, 21, 0] times in abstracts data.
# ['Cosmic Background', 'Background Imager', 'Imager (CBI)', '(CBI) (defunct)'] appears [182, 27, 21, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Côte', "d'Azur", 'Observatory'] appears [1, 1, 3950] times in abstracts data.
# ["Côte d'Azur", "d'Azur Observatory"] appears [1, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Crane', 'Observatory'] appears [2, 3950] times in abstracts data.
# ['Crane Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Crawford', 'Observatory'] appears [3, 3950] times in abstracts data.
# ['Crawford Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Creighton', 'University', 'Observatory', '(defunct)'] appears [0, 617, 3950, 0] times in abstracts data.
# ['Creighton University', 'University Observatory', 'Observatory (defunct)'] appears [0, 28, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Crimean', 'Astrophysical', 'Observatory'] appears [23, 1907, 3950] times in abstracts data.
# ['Crimean Astrophysical', 'Astrophysical Observatory'] appears [14, 112] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Črni', 'Vrh', 'Observatory'] appears [0, 0, 3950] times in abstracts data.
# ['Črni Vrh', 'Vrh Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cupillari', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Cupillari Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Custer', 'Observatory'] appears [4, 3950] times in abstracts data.
# ['Custer Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['The', 'Cyprus', 'Planetarium', '&', 'Observatory'] appears [63868, 0, 9, 3299, 3950] times in abstracts data.
# ['The Cyprus', 'Cyprus Planetarium', 'Planetarium &', '& Observatory'] appears [0, 0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Daniel', 'S.', 'Schanck', 'Observatory', '(defunct)'] appears [26, 56435, 0, 3950, 0] times in abstracts data.
# ['Daniel S.', 'S. Schanck', 'Schanck Observatory', 'Observatory (defunct)'] appears [0, 0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Daniel', 'Scholl', 'Observatory', '(defunct)'] appears [26, 2, 3950, 0] times in abstracts data.
# ['Daniel Scholl', 'Scholl Observatory', 'Observatory (defunct)'] appears [0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Daocheng', 'Solar', 'Radio', 'Telescope'] appears [0, 10845, 9524, 10808] times in abstracts data.
# ['Daocheng Solar', 'Solar Radio', 'Radio Telescope'] appears [0, 93, 611] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dark', 'Sky', 'Observatory'] appears [6494, 6025, 3950] times in abstracts data.
# ['Dark Sky', 'Sky Observatory'] appears [16, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dark', 'Matter', 'Particle', 'Explorer', '(DAMPE)'] appears [6494, 7279, 4528, 1333, 11] times in abstracts data.
# ['Dark Matter', 'Matter Particle', 'Particle Explorer', 'Explorer (DAMPE)'] appears [4476, 228, 15, 11] times in abstracts data.
# --------------------------------------------------------------------------------
# ["Darling's", 'Observatory', '(defunct)'] appears [0, 3950, 0] times in abstracts data.
# ["Darling's Observatory", 'Observatory (defunct)'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dearborn', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Dearborn Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Detroit', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Detroit Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['David', 'Dunlap', 'Observatory'] appears [43, 9, 3950] times in abstracts data.
# ['David Dunlap', 'Dunlap Observatory'] appears [9, 9] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dome', 'C'] appears [37, 63990] times in abstracts data.
# ['Dome C'] appears [10] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dominion', 'Observatory'] appears [20, 3950] times in abstracts data.
# ['Dominion Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dominion', 'Astrophysical', 'Observatory'] appears [20, 1907, 3950] times in abstracts data.
# ['Dominion Astrophysical', 'Astrophysical Observatory'] appears [9, 112] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dominion', 'Radio', 'Astrophysical', 'Observatory'] appears [20, 9524, 1907, 3950] times in abstracts data.
# ['Dominion Radio', 'Radio Astrophysical', 'Astrophysical Observatory'] appears [11, 11, 112] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dunsink', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Dunsink Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Durham', 'University', 'Observatory'] appears [28, 617, 3950] times in abstracts data.
# ['Durham University', 'University Observatory'] appears [2, 28] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dyer', 'Observatory'] appears [1, 3950] times in abstracts data.
# ['Dyer Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Effelsberg', '100-m', 'Radio', 'Telescope'] appears [40, 38, 9524, 10808] times in abstracts data.
# ['Effelsberg 100-m', '100-m Radio', 'Radio Telescope'] appears [5, 0, 611] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Ege', 'University', 'Observatory'] appears [1339, 617, 3950] times in abstracts data.
# ['Ege University', 'University Observatory'] appears [3, 28] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Einstein', 'Observatory', '(defunct)'] appears [826, 3950, 0] times in abstracts data.
# ['Einstein Observatory', 'Observatory (defunct)'] appears [121, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Elginfield', 'Observatory'] appears [2, 3950] times in abstracts data.
# ['Elginfield Observatory'] appears [2] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Ellis', 'Observatory'] appears [36, 3950] times in abstracts data.
# ['Ellis Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Embry-Riddle', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Embry-Riddle Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Eskdalemuir', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Eskdalemuir Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['European', 'Gravitational', 'Observatory'] appears [312, 6527, 3950] times in abstracts data.
# ['European Gravitational', 'Gravitational Observatory'] appears [0, 6] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Euclid', 'Telescope'] appears [81, 10808] times in abstracts data.
# ['Euclid Telescope'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['European', 'Southern', 'Observatory', 'La', 'Silla', 'Observatory', 'New', 'Technology', 'Telescope', 'Llano', 'de', 'Chajnantor', 'Observatory', 'Very', 'Large', 'Telescope', 'Paranal', 'Observatory', 'European', 'Extremely', 'Large', 'Telescope'] appears [312, 1073, 3950, 62738, 41, 3950, 14443, 298, 10808, 8, 62741, 0, 3950, 15587, 23305, 10808, 12, 3950, 312, 2228, 23305, 10808] times in abstracts data.
# ['European Southern', 'Southern Observatory', 'Observatory La', 'La Silla', 'Silla Observatory', 'Observatory New', 'New Technology', 'Technology Telescope', 'Telescope Llano', 'Llano de', 'de Chajnantor', 'Chajnantor Observatory', 'Observatory Very', 'Very Large', 'Large Telescope', 'Telescope Paranal', 'Paranal Observatory', 'Observatory European', 'European Extremely', 'Extremely Large', 'Large Telescope'] appears [114, 114, 13, 29, 3, 1, 43, 41, 0, 2, 0, 0, 24, 1584, 515, 0, 1, 0, 1, 111, 515] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fabra', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Fabra Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fan', 'Mountain', 'Observatory'] appears [379, 76, 3950] times in abstracts data.
# ['Fan Mountain', 'Mountain Observatory'] appears [0, 24] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Five-hundred-meter', 'Aperture', 'Spherical', 'Radio', 'Telescope'] appears [3, 696, 2158, 9524, 10808] times in abstracts data.
# ['Five-hundred-meter Aperture', 'Aperture Spherical', 'Spherical Radio', 'Radio Telescope'] appears [3, 9, 4, 611] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Félix', 'Aguilar', 'Observatory'] appears [0, 8, 3950] times in abstracts data.
# ['Félix Aguilar', 'Aguilar Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fernbank', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Fernbank Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fermi', 'Gamma-ray', 'Space', 'Telescope'] appears [624, 3389, 10148, 10808] times in abstracts data.
# ['Fermi Gamma-ray', 'Gamma-ray Space', 'Space Telescope'] appears [62, 64, 4281] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fick', 'Observatory'] appears [3, 3950] times in abstracts data.
# ['Fick Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Five', 'College', 'Radio', 'Astronomy', 'Observatory', '(defunct)'] appears [2689, 77, 9524, 1242, 3950, 0] times in abstracts data.
# ['Five College', 'College Radio', 'Radio Astronomy', 'Astronomy Observatory', 'Observatory (defunct)'] appears [20, 18, 175, 92, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Flarestar', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Flarestar Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Foggy', 'Bottom', 'Observatory'] appears [2, 259, 3950] times in abstracts data.
# ['Foggy Bottom', 'Bottom Observatory'] appears [2, 2] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Foothill', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Foothill Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Ford', 'Observatory'] appears [311, 3950] times in abstracts data.
# ['Ford Observatory'] appears [3] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fox', 'Observatory'] appears [2, 3950] times in abstracts data.
# ['Fox Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fox', 'Park', 'Public', 'Observatory'] appears [2, 529, 668, 3950] times in abstracts data.
# ['Fox Park', 'Park Public', 'Public Observatory'] appears [0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Francis', 'Marion', 'University', 'Observatory'] appears [22, 3, 617, 3950] times in abstracts data.
# ['Francis Marion', 'Marion University', 'University Observatory'] appears [0, 0, 28] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fred', 'Lawrence', 'Whipple', 'Observatory'] appears [41, 34, 108, 3950] times in abstracts data.
# ['Fred Lawrence', 'Lawrence Whipple', 'Whipple Observatory'] appears [10, 10, 59] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fremont', 'Peak', 'Observatory'] appears [0, 5495, 3950] times in abstracts data.
# ['Fremont Peak', 'Peak Observatory'] appears [0, 2] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Frosty', 'Drew', 'Observatory'] appears [2, 28, 3950] times in abstracts data.
# ['Frosty Drew', 'Drew Observatory'] appears [0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Fuertes', 'Observatory'] appears [0, 3950] times in abstracts data.
# ['Fuertes Observatory'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Galaxy', 'Evolution', 'Explorer', '(GALEX)'] appears [17325, 14449, 1333, 112] times in abstracts data.
# ['Galaxy Evolution', 'Evolution Explorer', 'Explorer (GALEX)'] appears [756, 138, 94] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Gaocheng', 'Astronomical', 'Observatory'] appears [0, 1486, 3950] times in abstracts data.
# ['Gaocheng Astronomical', 'Astronomical Observatory'] appears [0, 113] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Gauribidanur', 'Radio', 'Observatory'] appears [5, 9524, 3950] times in abstracts data.
# ['Gauribidanur Radio', 'Radio Observatory'] appears [4, 98] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Gemini', 'Observatory'] appears [365, 3950] times in abstracts data.
# ['Gemini Observatory'] appears [9] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Giant', 'Meterwave', 'Radio', 'Telescope', '(GMRT)'] appears [6155, 19, 9524, 10808, 73] times in abstracts data.
# ['Giant Meterwave', 'Meterwave Radio', 'Radio Telescope', 'Telescope (GMRT)'] appears [14, 17, 611, 73] times in abstracts data.
# ...
# ['Korea Advanced', 'Advanced Institute', 'Institute of', 'of Science', 'Science and', 'and Technology', 'Technology Satellite', 'Satellite 4', '4 (Kaistsat', '(Kaistsat 4)'] appears [0, 1, 137, 161, 83, 59, 0, 0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Swift', 'Gamma', 'Ray', 'Burst', 'Explorer', '(Swift)'] appears [678, 4273, 18529, 7926, 1333, 0] times in abstracts data.
# ['Swift Gamma', 'Gamma Ray', 'Ray Burst', 'Burst Explorer', 'Explorer (Swift)'] appears [30, 911, 2689, 7, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Interface', 'Region', 'Imaging', 'Spectrograph', '(IRIS)'] appears [359, 15323, 5137, 1919, 20] times in abstracts data.
# ['Interface Region', 'Region Imaging', 'Imaging Spectrograph', 'Spectrograph (IRIS)'] appears [36, 24, 441, 16] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Hisaki', '(SPRINT-A)'] appears [0, 0] times in abstracts data.
# ['Hisaki (SPRINT-A)'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Venus', 'Spectral', 'Rocket', 'Experiment'] appears [134, 9575, 113, 2619] times in abstracts data.
# ['Venus Spectral', 'Spectral Rocket', 'Rocket Experiment'] appears [0, 0, 5] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Lunar-based', 'ultraviolet', 'telescope', '(LUT)'] appears [2, 3260, 10808, 0] times in abstracts data.
# ['Lunar-based ultraviolet', 'ultraviolet telescope', 'telescope (LUT)'] appears [0, 51, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Astrosat'] appears [43] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Spatial', 'Heterodyne', 'Interferometric', 'Emission', 'Line', 'Dynamics', 'Spectrometer', '(SHIELDS)'] appears [4914, 36, 506, 17713, 20997, 3392, 1267, 0] times in abstracts data.
# ['Spatial Heterodyne', 'Heterodyne Interferometric', 'Interferometric Emission', 'Emission Line', 'Line Dynamics', 'Dynamics Spectrometer', 'Spectrometer (SHIELDS)'] appears [2, 0, 0, 3232, 0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Hipparcos'] appears [465] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Hubble', 'Space', 'Telescope'] appears [4804, 10148, 10808] times in abstracts data.
# ['Hubble Space', 'Space Telescope'] appears [3165, 4281] times in abstracts data.
# --------------------------------------------------------------------------------
# ['MOST'] appears [17492] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Swift', 'Gamma', 'Ray', 'Burst', 'Explorer'] appears [678, 4273, 18529, 7926, 1333] times in abstracts data.
# ['Swift Gamma', 'Gamma Ray', 'Ray Burst', 'Burst Explorer'] appears [30, 911, 2689, 7] times in abstracts data.
# --------------------------------------------------------------------------------
# ['COROT'] appears [483] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Kepler'] appears [1154] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['BRITE', 'constellation'] appears [8, 135] times in abstracts data.
# ['BRITE constellation'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Near', 'Earth', 'Object', 'Surveillance', 'Satellite', '(NEOSSat)'] appears [19211, 2578, 11475, 5, 3148, 0] times in abstracts data.
# ['Near Earth', 'Earth Object', 'Object Surveillance', 'Surveillance Satellite', 'Satellite (NEOSSat)'] appears [47, 44, 1, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Gaia', '(astrometry)'] appears [300, 0] times in abstracts data.
# ['Gaia (astrometry)'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Astrosat'] appears [43] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Transiting', 'Exoplanet', 'Survey', 'Satellite', '(TESS)'] appears [744, 1007, 11372, 3148, 18] times in abstracts data.
# ['Transiting Exoplanet', 'Exoplanet Survey', 'Survey Satellite', 'Satellite (TESS)'] appears [149, 32, 22, 16] times in abstracts data.
# --------------------------------------------------------------------------------
# ['CHEOPS'] appears [11] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['IRAS'] appears [1113] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Infrared', 'Telescope', 'in', 'Space'] appears [8134, 10808, 63942, 10148] times in abstracts data.
# ['Infrared Telescope', 'Telescope in', 'in Space'] appears [210, 311, 289] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Infrared', 'Space', 'Observatory', '(ISO)'] appears [8134, 10148, 3950, 140] times in abstracts data.
# ['Infrared Space', 'Space Observatory', 'Observatory (ISO)'] appears [323, 409, 136] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Midcourse', 'Space', 'Experiment', '(MSX)'] appears [44, 10148, 2619, 36] times in abstracts data.
# ['Midcourse Space', 'Space Experiment', 'Experiment (MSX)'] appears [44, 60, 26] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Submillimeter', 'Wave', 'Astronomy', 'Satellite', '(SWAS)'] appears [843, 11432, 1242, 3148, 4] times in abstracts data.
# ['Submillimeter Wave', 'Wave Astronomy', 'Astronomy Satellite', 'Satellite (SWAS)'] appears [124, 89, 47, 4] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Wide', 'Field', 'Infrared', 'Explorer', '(WIRE)'] appears [5974, 14352, 8134, 1333, 5] times in abstracts data.
# ['Wide Field', 'Field Infrared', 'Infrared Explorer', 'Explorer (WIRE)'] appears [621, 52, 5, 5] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Spitzer', 'Space', 'Telescope'] appears [1639, 10148, 10808] times in abstracts data.
# ['Spitzer Space', 'Space Telescope'] appears [664, 4281] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Akari', '(Astro-F)'] appears [33, 0] times in abstracts data.
# ['Akari (Astro-F)'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Herschel', 'Space', 'Observatory'] appears [315, 10148, 3950] times in abstracts data.
# ['Herschel Space', 'Space Observatory'] appears [53, 409] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Wide-field', 'Infrared', 'Survey', 'Explorer', '(WISE)'] appears [615, 8134, 11372, 1333, 19] times in abstracts data.
# ['Wide-field Infrared', 'Infrared Survey', 'Survey Explorer', 'Explorer (WISE)'] appears [36, 227, 27, 19] times in abstracts data.
# --------------------------------------------------------------------------------
# ['CHEOPS'] appears [11] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['James', 'Webb', 'Space', 'Telescope', '(JWST)'] appears [318, 136, 10148, 10808, 38] times in abstracts data.
# ['James Webb', 'Webb Space', 'Space Telescope', 'Telescope (JWST)'] appears [121, 122, 4281, 37] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Euclid'] appears [81] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Cosmic', 'Background', 'Explorer', '(COBE)'] appears [5786, 4430, 1333, 43] times in abstracts data.
# ['Cosmic Background', 'Background Explorer', 'Explorer (COBE)'] appears [182, 57, 43] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Odin'] appears [290] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['WMAP'] appears [380] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Planck'] appears [485] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Highly', 'Advanced', 'Laboratory', 'for', 'Communications', 'and', 'Astronomy', '(HALCA,', 'VSOP', 'or', 'MUSES-B)'] appears [3683, 1005, 840, 56668, 20, 62845, 1242, 0, 4, 63332, 0] times in abstracts data.
# ['Highly Advanced', 'Advanced Laboratory', 'Laboratory for', 'for Communications', 'Communications and', 'and Astronomy', 'Astronomy (HALCA,', '(HALCA, VSOP', 'VSOP or', 'or MUSES-B)'] appears [1, 0, 98, 2, 2, 97, 0, 0, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Spektr-R', '(RadioAstron)'] appears [3, 0] times in abstracts data.
# ['Spektr-R (RadioAstron)'] appears [0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Proton-1'] appears [0] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Proton-2'] appears [0] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['High', 'Energy', 'Astrophysics', 'Observatory', '3', '(HEAO', '3)'] appears [28343, 11726, 1088, 3950, 39020, 11, 4412] times in abstracts data.
# ['High Energy', 'Energy Astrophysics', 'Astrophysics Observatory', 'Observatory 3', '3 (HEAO', '(HEAO 3)'] appears [825, 60, 0, 11, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['SAMPEX'] appears [4] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Alpha', 'Magnetic', 'Spectrometer', '01', '(AMS-01)'] appears [1500, 7933, 1267, 9024, 0] times in abstracts data.
# ['Alpha Magnetic', 'Magnetic Spectrometer', 'Spectrometer 01', '01 (AMS-01)'] appears [6, 12, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Payload', 'for', 'Antimatter', 'Matter', 'Exploration', 'and', 'Light-nuclei', 'Astrophysics', '(PAMELA)'] appears [74, 56668, 44, 7279, 295, 62845, 7, 1088, 0] times in abstracts data.
# ['Payload for', 'for Antimatter', 'Antimatter Matter', 'Matter Exploration', 'Exploration and', 'and Light-nuclei', 'Light-nuclei Astrophysics', 'Astrophysics (PAMELA)'] appears [9, 11, 7, 7, 21, 7, 7, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['IBEX'] appears [14] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Alpha', 'Magnetic', 'Spectrometer', '02', '(AMS-02)'] appears [1500, 7933, 1267, 5997, 1] times in abstracts data.
# ['Alpha Magnetic', 'Magnetic Spectrometer', 'Spectrometer 02', '02 (AMS-02)'] appears [6, 12, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Dark', 'Matter', 'Particle', 'Explorer', '(DAMPE)'] appears [6494, 7279, 4528, 1333, 11] times in abstracts data.
# ['Dark Matter', 'Matter Particle', 'Particle Explorer', 'Explorer (DAMPE)'] appears [4476, 228, 15, 11] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Lunar', 'Surface', 'Gravimeter'] appears [226, 7405, 1] times in abstracts data.
# ['Lunar Surface', 'Surface Gravimeter'] appears [27, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['X-ray', 'Polarimeter', 'Satellite', '(XPoSat)'] appears [11374, 227, 3148, 0] times in abstracts data.
# ['X-ray Polarimeter', 'Polarimeter Satellite', 'Satellite (XPoSat)'] appears [17, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['International', 'Lunar', 'Observatory', 'Precursor', '(ILO-X)'] appears [419, 226, 3950, 460, 0] times in abstracts data.
# ['International Lunar', 'Lunar Observatory', 'Observatory Precursor', 'Precursor (ILO-X)'] appears [2, 5, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['TOLIMAN'] appears [0] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Xuntian'] appears [0] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['SPHEREx'] appears [2] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Astrosat-2'] appears [0] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['PLATO'] appears [12] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['ULTRASAT'] appears [0] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Nancy', 'Grace', 'Roman', 'Space', 'Telescope', '(Wide', 'Field', 'Infrared', 'Survey', 'Telescope;', 'WFIRST)'] appears [1, 5, 35, 10148, 10808, 2, 14352, 8134, 11372, 25, 11] times in abstracts data.
# ['Nancy Grace', 'Grace Roman', 'Roman Space', 'Space Telescope', 'Telescope (Wide', '(Wide Field', 'Field Infrared', 'Infrared Survey', 'Survey Telescope;', 'Telescope; WFIRST)'] appears [0, 0, 0, 4281, 0, 0, 52, 227, 0, 0] times in abstracts data.
# --------------------------------------------------------------------------------
# ['ARIEL'] appears [56] times in abstracts data.
# [] appears [] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Advanced', 'Telescope', 'for', 'High', 'Energy', 'Astrophysics', '(Athena)'] appears [1005, 10808, 56668, 28343, 11726, 1088, 4] times in abstracts data.
# ['Advanced Telescope', 'Telescope for', 'for High', 'High Energy', 'Energy Astrophysics', 'Astrophysics (Athena)'] appears [5, 106, 805, 825, 60, 4] times in abstracts data.
# --------------------------------------------------------------------------------
# ['Laser', 'Interferometer', 'Space', 'Antenna', '(LISA)'] appears [384, 877, 10148, 396, 77] times in abstracts data.
# ['Laser Interferometer', 'Interferometer Space', 'Space Antenna', 'Antenna (LISA)'] appears [209, 113, 117, 73] times in abstracts data.
# --------------------------------------------------------------------------------

# %%
def generate_bigrams(label):
    """Generate bigrams from a given label."""
    tokens = label.split()
    return [" ".join(tokens[i:i+2]) for i in range(len(tokens)-1)]

def get_indices(abstract_df, pattern):
    """Return indices of rows in abstract_df containing the pattern."""
    return set(abstract_df[abstract_df.str.contains(re.escape(pattern), case=False, na=False)].index.tolist())

# Collect indices of all rows that contain any bigram
all_bigram_indices = set()

for label in Labels['Labels']:
    bigrams = generate_bigrams(label)
    for bigram in bigrams:
        all_bigram_indices.update(get_indices(abstract_df, bigram))

# Determine indices of rows that don't contain any bigram
no_bigram_indices = set(abstract_df.index) - all_bigram_indices

# Display results
print(f"Number of rows that don't contain any bigram: {len(no_bigram_indices)}")
print(f"Indices of rows without any bigrams: {sorted(list(no_bigram_indices))}")
# Out:
# Number of rows that don't contain any bigram: 1507
# Indices of rows without any bigrams: [39, 64, 65, 83, 101, 225, 235, 236, 266, 324, 342, 399, 453, 462, 470, 634, 642, 643, 698, 699, 735, 786, 789, 830, 1041, 1104, 1117, 1135, 1151, 1187, 1208, 1261, 1276, 1335, 1402, 1414, 1425, 1476, 1477, 1484, 1510, 1563, 1576, 1603, 1699, 1784, 1793, 1812, 1884, 1934, 1956, 1959, 2246, 2338, 2351, 2398, 2428, 2488, 2489, 2494, 2531, 2555, 2658, 2679, 2690, 2701, 2762, 2763, 3026, 3051, 3059, 3060, 3098, 3109, 3123, 3127, 3158, 3220, 3221, 3235, 3263, 3285, 3365, 3368, 3388, 3534, 3636, 3735, 3770, 3796, 3828, 3905, 3908, 3926, 3934, 3955, 3957, 3968, 4071, 4072, 4088, 4234, 4258, 4354, 4381, 4454, 4467, 4586, 4617, 4622, 4658, 4732, 4825, 4841, 4842, 4843, 4863, 4870, 4898, 4935, 5114, 5129, 5130, 5197, 5198, 5210, 5293, 5378, 5391, 5401, 5414, 5416, 5457, 5471, 5542, 5567, 5614, 5694, 5736, 5769, 5892, 6008, 6075, 6103, 6124, 6184, 6201, 6228, 6249, 6276, 6324, 6354, 6392, 6400, 6430, 6471, 6513, 6514, 6623, 6648, 6677, 6680, 6736, 6751, 6901, 6985, 7091, 7104, 7180, 7250, 7305, 7335, 7392, 7395, 7417, 7548, 7549, 7579, 7580, 7606, 7663, 7748, 7749, 7803, 7876, 7911, 7913, 8000, 8123, 8165, 8249, 8263, 8272, 8273, 8299, 8317, 8359, 8366, 8380, 8405, 8471, 8669, 8680, 8695, 8741, 8819, 8833, 8834, 8851, 8873, 8915, 8933, 9000, 9133, 9134, 9199, 9208, 9231, 9324, 9329, 9466, 9477, 9547, 9555, 9564, 9593, 9616, 9632, 9633, 9665, 9721, 9722, 9762, 9766, 9799, 9816, 9834, 9839, 9874, 9900, 9944, 9979, 10041, 10190, 10195, 10206, 10223, 10239, 10285, 10307, 10449, 10543, 10554, 10605, 10621, 10661, 10679, 10680, 10684, 10690, 10758, 10794, 10795, 10823, 10933, 10955, 11000, 11102, 11109, 11122, 11201, 11207, 11245, 11251, 11259, 11388, 11397, 11399, 11422, 11423, 11455, 11479, 11502, 11522, 11561, 11564, 11614, 11650, 11653, 12133, 12134, 12179, 12186, 12189, 12261, 12358, 12372, 12409, 12435, 12442, 12450, 12519, 12520, 12584, 12719, 12729, 12730, 12733, 12760, 12806, 12831, 12850, 12918, 12995, 13055, 13085, 13089, 13140, 13176, 13185, 13198, 13230, 13250, 13256, 13267, 13306, 13376, 13444, 13477, 13483, 13592, 13605, 13631, 13642, 13698, 13738, 13825, 13840, 13841, 13843, 13895, 13971, 14011, 14095, 14105, 14341, 14352, 14416, 14422, 14523, 14599, 14632, 14649, 14701, 14728, 14745, 14815, 14861, 14862, 14941, 14954, 14966, 15016, 15161, 15178, 15215, 15286, 15346, 15347, 15376, 15392, 15405, 15430, 15451, 15482, 15492, 15505, 15506, 15534, 15687, 15707, 15708, 15789, 15896, 15982, 16023, 16051, 16062, 16117, 16147, 16181, 16187, 16249, 16264, 16265, 16433, 16525, 16562, 16564, 16568, 16641, 16690, 16714, 16734, 16813, 16956, 16976, 17069, 17084, 17146, 17352, 17414, 17415, 17522, 17560, 17561, 17583, 17663, 17702, 17826, 17868, 17920, 17973, 18011, 18089, 18122, 18212, 18235, 18255, 18276, 18313, 18454, 18486, 18501, 18649, 18695, 18715, 18755, 18763, 18840, 18857, 18876, 18880, 18887, 18895, 18946, 18994, 19023, 19061, 19111, 19112, 19187, 19191, 19244, 19325, 19400, 19406, 19409, 19428, 19444, 19495, 19500, 19514, 19593, 19603, 19613, 19614, 19685, 19710, 19844, 19845, 19875, 19975, 20074, 20075, 20079, 20097, 20143, 20157, 20159, 20186, 20244, 20245, 20306, 20318, 20364, 20388, 20421, 20455, 20520, 20524, 20563, 20576, 20666, 20671, 20672, 20673, 20674, 20717, 20718, 20839, 20865, 20866, 20868, 20894, 21054, 21074, 21213, 21258, 21289, 21325, 21369, 21385, 21399, 21409, 21430, 21445, 21590, 21621, 21747, 21759, 21940, 21941, 22001, 22055, 22146, 22147, 22149, 22154, 22173, 22221, 22265, 22414, 22485, 22585, 22588, 22598, 22663, 22664, 22672, 22704, 22810, 22814, 22848, 22945, 23131, 23147, 23196, 23395, 23453, 23454, 23479, 23608, 23610, 23652, 23685, 23733, 23869, 23870, 23889, 24000, 24041, 24057, 24072, 24111, 24153, 24208, 24294, 24383, 24421, 24464, 24475, 24491, 24527, 24605, 24616, 24626, 24671, 24802, 24814, 24817, 24822, 24907, 24927, 24969, 24983, 24984, 25047, 25195, 25198, 25328, 25367, 25487, 25493, 25520, 25537, 25605, 25614, 25691, 25693, 25706, 25710, 25728, 25749, 2585 ...

# %% [markdown]
# # Full Text Data

# %%
# Count the occurrences of each label
label_counts = {}
for label in Labels['Labels']:
    escaped_label = re.escape(label)
    label_counts[label] = full_text.str.contains(escaped_label, case=False, na=False).sum()

# Results
for label, count in label_counts.items():
    print(f"'{label}' appears {count} times.")
# Out:
# 'Abastumani Astrophysical Observatory' appears 3 times.
# 'Abu Reyhan-e Birooni Observatory' appears 0 times.
# 'Adirondack Public Observatory' appears 0 times.
# 'Adolphson Observatory' appears 0 times.
# 'Airdrie Public Observatory' appears 0 times.
# 'Aker Observatory' appears 0 times.
# 'Aldershot Observatory' appears 0 times.
# 'Algonquin Radio Observatory' appears 0 times.
# 'Allegheny Observatory' appears 75 times.
# 'Ametlla de Mar Observatory' appears 0 times.
# 'AMiBA' appears 2 times.
# 'Anderson Mesa Station' appears 1 times.
# 'Angell Hall Observatory' appears 0 times.
# 'Ankara University Observatory' appears 0 times.
# 'Antarctic Muon and Neutrino Detector Array' appears 0 times.
# 'Antarctic Submillimeter Telescope and Remote Observatory' appears 0 times.
# 'ANTARES' appears 73 times.
# 'Apache-Sitgreaves Observatory' appears 0 times.
# 'Apache Point Observatory' appears 2 times.
# 'Apatity Cosmic-Ray Station' appears 0 times.
# 'Apollo Observatory' appears 0 times.
# 'Arcetri Observatory' appears 0 times.
# 'Arecibo Observatory' appears 21 times.
# 'Argentine Institute of Radio Astronomy' appears 0 times.
# 'Armagh Observatory' appears 3 times.
# 'Aryabhatta Research Institute of Observational Sciences' appears 4 times.
# 'Ashton Observatory' appears 0 times.
# 'Asiago Astrophysical Observatory' appears 0 times.
# 'Assheton Observatory' appears 0 times.
# 'Astron (defunct)' appears 0 times.
# 'Astronomical Observatory Aurora' appears 0 times.
# 'Astronomical Observatory of Lisbon' appears 0 times.
# 'Astronomy Centre' appears 4 times.
# 'Astronomy Tower of the Sorbonne' appears 0 times.
# 'Astrophysical Institute Potsdam' appears 2 times.
# 'Atacama Pathfinder Experiment (APEX)' appears 0 times.
# 'Australia Telescope Compact Array' appears 0 times.
# 'Australian Astronomical Observatory' appears 0 times.
# 'Badlands Observatory' appears 0 times.
# 'Baikal Deep Underwater Neutrino Telescope' appears 0 times.
# 'Bangladesh Astronomical Observatory' appears 0 times.
# 'Baker Observatory' appears 0 times.
# 'Baksan Neutrino Observatory' appears 0 times.
# 'Ball State University Observatory' appears 0 times.
# 'Barnard Observatory (defunct)' appears 0 times.
# 'Bareket Observatory' appears 0 times.
# 'Barnett Observatory' appears 0 times.
# 'Bayfordbury Observatory' appears 2 times.
# 'Behlen Observatory' appears 0 times.
# 'Beijing Astronomical Observatory' appears 0 times.
# 'Beijing Ancient Observatory' appears 0 times.
# 'Belgrade Observatory' appears 0 times.
# 'Belogradchik Observatory' appears 0 times.
# 'Benmore Peak Observatory' appears 0 times.
# 'BeppoSAX (defunct)' appears 0 times.
# 'Bergisch Gladbach Observatory' appears 0 times.
# 'Berlin Observatory' appears 29 times.
# 'Besançon Observatory' appears 0 times.
# 'BESS' appears 974 times.
# 'Bidston Observatory' appears 1 times.
# 'Big Bear Lake Solar Observatory' appears 0 times.
# 'Bisdee Tier Optical Astronomy Observatory' appears 0 times.
# 'Black Moshannon Observatory (defunct)' appears 0 times.
# 'Blackett Observatory' appears 0 times.
# 'Blue Mesa Observatory (defunct)' appears 0 times.
# 'Boambee Observatory' appears 0 times.
# 'Bohyunsan Optical Astronomy Observatory (BOAO)' appears 0 times.
# 'BOOTES' appears 11 times.
# 'Bordeaux Observatory' appears 1 times.
# 'Bosscha Observatory' appears 0 times.
# 'Boswell Observatory (defunct)' appears 0 times.
# 'Bowman Observatory' appears 0 times.
# 'Boyden Observatory' appears 0 times.
# 'Bradstreet Observatory' appears 0 times.
# 'Bradley Observatory' appears 0 times.
# 'Braeside Observatory (defunct)' appears 0 times.
# 'Brera Observatory' appears 0 times.
# 'Bridgewater State University Observatory' appears 0 times.
# 'Brooks Observatory' appears 0 times.
# 'Brooks Astronomical Observatory' appears 0 times.
# 'Brorfelde Observatory' appears 0 times.
# 'Bucharest Observatory' appears 0 times.
# 'Bucknell Observatory' appears 0 times.
# 'Burrell Memorial Observatory' appears 0 times.
# 'Byurakan Observatory' appears 0 times.
# 'Cagigal Observatory' appears 0 times.
# 'Cagliari Observatory' appears 1 times.
# 'Calais Observatory (defunct)' appears 0 times.
# 'Calar Alto Observatory' appears 2 times.
# 'Caltech Submillimeter Observatory (defunct)' appears 0 times.
# 'Cambridge Observatory' appears 12 times.
# 'Camille Flammarion Observatory' appears 0 times.
# 'Campbelltown Rotary Observatory' appears 0 times.
# 'Campo Imperatore Near-Earth Object Survey' appears 0 times.
# 'Canopus Hill Observatory' appears 0 times.
# 'Capilla Peak Observatory' appears 0 times.
# 'Capodimonte Observatory' appears 0 times.
# 'Carter Observatory' appears 0 times.
# 'Catania Astrophysical Observatory' appears 1 times.
# 'Cawthron Atkinson Observatory' appears 0 times.
# 'Celestial Observatory' appears 0 times.
# 'Centennial Observatory' appears 0 times.
# 'Center for Astrophysics | Harvard & Smithsonian' appears 0 times.
# 'Cerro Armazones Observatory' appears 0 times.
# 'Cerro Tololo Inter-American Observatory' appears 1 times.
# 'Cerro Pachón Observatory' appears 0 times.
# 'Chabot Space & Science Center' appears 0 times.
# 'Chamberlin Observatory' appears 21 times.
# 'Changchun Astronomical Observatory' appears 0 times.
# 'Chandra X-ray Observatory' appears 4 times.
# 'Chianti Polifunctional Observatory' appears 0 times.
# 'Chico Community Observatory' appears 0 times.
# 'Chilbolton Observatory' appears 4 times.
# 'Cima Ekar Observing Station' appears 0 times.
# 'Cincinnati Observatory' appears 17 times.
# 'City Observatory, Edinburgh' appears 0 times.
# 'Clarke Observatory' appears 0 times.
# 'Class of 1951 Observatory' appears 0 times.
# 'Cloudcroft Observatory (defunct)' appears 0 times.
# 'Coats Observatory' appears 0 times.
# 'Coit Observatory' appears 0 times.
# 'Collins Observatory' appears 0 times.
# 'Collm Observatory' appears 3 times.
# 'Colombo University Observatory' appears 0 times.
# 'Compton Gamma-Ray Observatory (defunct)' appears 0 times.
# 'ÇOMÜ Ulupınar Observatory' appears 0 times.
# 'Concordia College Observatory' appears 0 times.
# 'Consell Observatory' appears 0 times.
# 'Copenhagen University Observatory' appears 0 times.
# 'Cordell–Lorenz Observatory' appears 0 times.
# 'COROT' appears 135 times.
# 'Cosmic Background Imager (CBI) (defunct)' appears 0 times.
# 'Côte d'Azur Observatory' appears 0 times.
# 'Crane Observatory' appears 0 times.
# 'Crawford Observatory' appears 0 times.
# 'Creighton University Observatory (defunct)' appears 0 times.
# 'Crimean Astrophysical Observatory' appears 2 times.
# 'Črni Vrh Observatory' appears 0 times.
# 'Cupillari Observatory' appears 0 times.
# 'Custer Observatory' appears 0 times.
# 'The Cyprus Planetarium & Observatory' appears 0 times.
# 'Daniel S. Schanck Observatory (defunct)' appears 0 times.
# 'Daniel Scholl Observatory (defunct)' appears 0 times.
# 'Daocheng Solar Radio Telescope' appears 0 times.
# 'Dark Sky Observatory' appears 0 times.
# 'Dark Matter Particle Explorer (DAMPE)' appears 0 times.
# 'Darling's Observatory (defunct)' appears 0 times.
# 'Dearborn Observatory' appears 19 times.
# 'Detroit Observatory' appears 15 times.
# 'David Dunlap Observatory' appears 0 times.
# 'Dome C' appears 294 times.
# 'Dominion Observatory' appears 23 times.
# 'Dominion Astrophysical Observatory' appears 28 times.
# 'Dominion Radio Astrophysical Observatory' appears 4 times.
# 'Dunsink Observatory' appears 3 times.
# 'Durham University Observatory' appears 1 times.
# 'Dyer Observatory' appears 0 times.
# 'Effelsberg 100-m Radio Telescope' appears 0 times.
# 'Ege University Observatory' appears 1 times.
# 'Einstein Observatory (defunct)' appears 0 times.
# 'Elginfield Observatory' appears 0 times.
# 'Ellis Observatory' appears 0 times.
# 'Embry-Riddle Observatory' appears 0 times.
# 'Eskdalemuir Observatory' appears 1 times.
# 'European Gravitational Observatory' appears 0 times.
# 'Euclid Telescope' appears 1 times.
# 'European Southern Observatory La Silla Observatory New Technology Telescope Llano de Chajnantor Observatory Very Large Telescope Paranal Observatory European Extremely Large Telescope' appears 0 times.
# 'Fabra Observatory' appears 5 times.
# 'Fan Mountain Observatory' appears 0 times.
# 'Five-hundred-meter Aperture Spherical Radio Telescope' appears 0 times.
# 'Félix Aguilar Observatory' appears 0 times.
# 'Fernbank Observatory' appears 0 times.
# 'Fermi Gamma-ray Space Telescope' appears 4 times.
# 'Fick Observatory' appears 0 times.
# 'Five College Radio Astronomy Observatory (defunct)' appears 0 times.
# 'Flarestar Observatory' appears 0 times.
# 'Foggy Bottom Observatory' appears 0 times.
# 'Foothill Observatory' appears 0 times.
# 'Ford Observatory' appears 3 times.
# 'Fox Observatory' appears 0 times.
# 'Fox Park Public Observatory' appears 0 times.
# 'Francis Marion University Observatory' appears 0 times.
# 'Fred Lawrence Whipple Observatory' appears 1 times.
# 'Fremont Peak Observatory' appears 0 times.
# 'Frosty Drew Observatory' appears 0 times.
# 'Fuertes Observatory' appears 0 times.
# 'Galaxy Evolution Explorer (GALEX)' appears 0 times.
# 'Gaocheng Astronomical Observatory' appears 0 times.
# 'Gauribidanur Radio Observatory' appears 0 times.
# 'Gemini Observatory' appears 3 times.
# 'Giant Meterwave Radio Telescope (GMRT)' appears 0 times.
# 'Gifford Observatory' appears 0 times.
# 'Girawali Observatory' appears 0 times.
# 'Glen D. Riley Observatory' appears 0 times.
# 'Godlee Observatory' appears 0 times.
# 'Goodsell Observatory' appears 15 times.
# 'Goethe Link Observatory' appears 0 times.
# 'Goldendale Observatory' appears 0 times.
# 'Gornergrat (HFSJG) (defunct)' appears 0 times.
# 'Granat (defunct)' appears 0 times.
# 'Gran Telescopio Canarias' appears 1 times.
# 'Grant O. Gale Observatory' appears 0 times.
# 'Green Bank Telescope,' appears 2 times.
# 'Green Point Observatory,' appears 0 times.
# 'Grenfell Observatory' appears 0 times.
# 'Griffith Observatory' appears 0 times.
# 'Guillermo Haro Observatory' appears 0 times.
# 'HALCA (defunct)' appears 0 times.
# 'Haleakala Observatory' appears 1 times.
# 'Halley Observatory' appears 0 times.
# 'Hamburg Observatory' appears 4 times.
# 'Hat Creek Radio Observatory' appears 0 times.
# 'Hard Labor Creek Observatory' appears 0 times.
# 'Space Hard X-Ray Modulation Telescope (HXMT)' appears 0 times.
# 'Hartung–Boothroyd Observatory' appears 0 times.
# 'Hartebeesthoek Radio Astronomy Observatory' appears 1 times.
# 'Hartwell House' appears 0 times.
# 'Harvard College Observatory' appears 196 times.
# 'Haute-Provence Observatory' appears 7 times.
# 'Haystack Observatory' appears 6 times.
# 'Hector J Robinson Observatory' appears 0 times.
# 'Helium and Lead Observatory' appears 0 times.
# 'Helmos Observatory' appears 0 times.
# 'Helsinki University Observatory' appears 0 times.
# 'Herrett Observatory' appears 0 times.
# 'Herschel Space Observatory' appears 3 times.
# 'Hidden Valley Observatory' appears 0 times.
# 'Hida Observatory, Kyoto University' appears 0 times.
# 'Heyden Observatory, Georgetown University' appears 0 times.
# 'High Altitude Water Cherenkov Observatory' appears 1 times.
# 'High Energy Stereoscopic System' appears 2 times.
# 'Highland Road Park Observatory' appears 0 times.
# 'Hinode' appears 44 times.
# 'Hirsch Observatory' appears 0 times.
# 'Hobbs Observatory' appears 0 times.
# 'Hoher List Observatory' appears 0 times.
# 'Holcomb Observatory and Planetarium' appears 0 times.
# 'Hong Kong Observatory' appears 17 times.
# 'Hoober Observatory' appears 0 times.
# 'Hopkins Observatory' appears 0 times.
# 'Howell Observatory' appears 0 times.
# 'Hradec Králové Observatory' appears 1 times.
# 'Huairou Solar Observing Station' appears 0 times.
# 'Hubble Space Telescope' appears 52 times.
# 'Huggins Observatory defunct' appears 0 times.
# 'Hume Cronyn Memorial Observatory' appears 0 times.
# 'Hyde Memorial Observatory' appears 0 times.
# 'IceCube Neutrino Observatory' appears 5 times.
# 'Indian Astronomical Observatory' appears 1 times.
# 'Instituto de Astrofísica de Canarias' appears 4 times.
# 'INTEGRAL' appears 2709 times.
# 'Infrared Astronomical Satellite (IRAS) (defunct)' appears 0 times.
# 'Infrared Space Observatory (ISO) (defunct)' appears 0 times.
# 'Innsbruck Observatory' appears 0 times.
# 'IRAM 30m telescope' appears 1 times.
# 'IRAM Plateau de Bure Interferometer' appears 0 times.
# 'Iranian National Observatory' appears 0 times.
# 'Isaac Newton Group of Telescopes' appears 1 times.
# 'Isasc Roberts' Observatory (defunct)' appears 0 times.
# 'Iso-Heikkilä Observatory (defunct)' appears 0 times.
# 'Constantinople Observatory of Taqi ad-Din' appears 0 times.
# 'Istanbul University Observatory' appears 0 times.
# 'Istituto Ricerche Solari Locarno, IRSOL' appears 0 times.
# 'IXPE' appears 5 times.
# 'Jack C. Davis Observatory' appears 0 times.
# 'Astronomical Observatory of the Jagiellonian University' appears 0 times.
# 'James Clerk Maxwell Telescope' appears 1 times.
# 'James Gregory Telescope' appears 0 times.
# 'James Webb Space Telescope' appears 6 times.
# 'James Wylie Shepherd Observatory' appears 0 times.
# 'Jakarta Observatory' appears 0 times.
# 'Jantar Mantar' appears 0 times.
# 'Jena Observatory' appears 0 times.
# 'Jewett Observatory' appears 0 times.
# 'Jodrell Bank Observatory' appears 0 times.
# 'JAC Johor Astronomy' appears 0 times.
# 'Jones Observatory' appears 0 times.
# 'Judson B. Coit Observatory' appears 0 times.
# 'KAIRA' appears 4 times.
# 'Khajeh Nasiredin Observatory' appears 0 times.
# 'Kamioka Observatory' appears 0 times.
# 'Kanzelhoehe Solar Observatory' appears 0 times.
# 'Karl Schwarzschild Observatory' appears 0 times.
# 'Keck Observatory' appears 3 times.
# 'Keeble Observatory' appears 0 times.
# 'Keele Observatory' appears 0 times.
# 'Kennon Observatory' appears 0 times.
# 'Kepler Space Observatory' appears 0 times.
# 'Kevola Observatory' appears 0 times.
# 'Kielder Observatory' appears 0 times.
# 'King's Observatory (defunct)' appears 0 times.
# 'Kirkwood Observatory' appears 4 times.
# 'Kitami Observatory' appears 0 times.
# 'Kitt Peak National Observatory' appears 4 times.
# 'Kleť Observatory' appears 0 times.
# 'Kodaikanal Solar Observatory' appears 0 times.
# 'Konkoly Observatory' appears 7 times.
# 'Kopernik Observatory & Science Center' appears 0 times.
# 'KOSMA observatory' appears 0 times.
# 'Kottamia Astronomical Observatory' appears 0 times.
# 'Kuffner observatory' appears 0 times.
# 'Kuiper Airborne Observatory (retired)' appears 0 times.
# 'Kwasan Observatory, Kyoto University' appears 0 times.
# 'Kvistaberg Observatory' appears 0 times.
# 'Kyung Hee Observatory' appears 0 times.
# 'Laboratoire d'Astrophysique de Grenoble' appears 0 times.
# 'Observatorio de La Cañada (La Cañada Observatory)' appears 0 times.
# 'Ladd Observatory' appears 5 times.
# 'Lake Afton Public Observatory' appears 0 times.
# 'Lamont–Hussey Observatory (defunct)' appears 0 times.
# 'Landessternwarte Heidelberg-Königstuhl' appears 0 times.
# 'Landolt Astronomical Observatory' appears 0 times.
# 'La Plata Astronomical Observatory' appears 0 times.
# 'La Silla Observatory' appears 1 times.
# 'Large High Altitude Air Shower Observatory (LHAASO)' appears 1 times.
# 'Large Sky Area Multi-Object Fibre Spectroscopic Telescope (LAMOST)' appears 0 times.
# 'Large Millimeter Telescope' appears 1 times.
# 'Las Brisas Observatory' appears 0 times.
# 'Las Campanas Observatory' appears 5 times.
# 'Las Cumbres Observatory Global Telescope' appears 1 times.
# 'Laws Observatory' appears 16 times.
# 'Leander McCormick Observatory' appears 26 times.
# 'Lee Observatory' appears 0 times.
# 'Leiden Observatory' appears 10 times.
# 'Leipzig Observatory' appears 0 times.
# 'Leoncito Astronomical Complex' appears 0 times.
# 'Levenhagen Observatory' appears 0 times.
# 'Lick Observatory' appears 528 times.
# 'LightBuckets (commercial observatory)' appears 0 times.
# 'LIGO' appears 599 times.
# 'Lindheimer Astrophysical Research Center (defunct)' appears 0 times.
# 'Llano de Chajnantor Observatory' appears 0 times.
# 'Llano del Hato National Astronomical Observatory' appears 0 times.
# 'Lockyer Technology Centre' appears 0 times.
# 'Long Wavelength Array' appears 0 times.
# 'Longa Vista Observatory' appears 0 times.
# 'Lowell Observatory Anderson Mesa Station' appears 0 times.
# 'Lucknow (King of Oudh's) Observatory' appears 0 times.
# 'Lulin Observatory' appears 0 times.
# 'Lund Observatory' appears 4 times.
# 'Luoxue Mountain Cosmic Rays Research Center' appears 0 times.
# 'Lyon Observatory' appears 0 times.
# 'Macalester College Observatory' appears 0 times.
# 'Macfarlane Observatory defunct' appears 0 times.
# 'Magdalena Ridge Observatory (under construction)' appears 0 times.
# 'Majorca Observatory' appears 0 times.
# 'Malakoff Tower' appears 0 times.
# 'Manastash Ridge Observatory' appears 0 times.
# 'Manuel Foster Observatory (defunct)' appears 0 times.
# 'Maragheh Observatory' appears 0 times.
# 'Margaret M. Jacoby Observatory' appears 0 times.
# 'Maria Mitchell Observatory' appears 4 times.
# 'Marina Towers Observatory (Not In Use)' appears 0 times.
# 'Markree Observatory (defunct)' appears 0 times.
# 'Marseille Observatory' appears 0 times.
# 'Martz Observatory' appears 0 times.
# 'Mauna Kea Observatory' appears 1 times.
# 'Mauna Loa Solar Observatory' appears 1 times.
# 'Maynard F. Jordan Observatory' appears 0 times.
# 'McDonald Observatory' appears 5 times.
# 'McKim Observatory' appears 0 times.
# 'McMath–Hulbert Solar Observatory' appears 0 times.
# 'MDM Observatory' appears 0 times.
# 'Mead Observatory' appears 0 times.
# 'Medicina Radio Observatory' appears 0 times.
# 'Mees Observatory' appears 0 times.
# 'Mehalso Observatory' appears 0 times.
# 'Melbourne Observatory' appears 7 times.
# 'Melton Memorial Observatory' appears 0 times.
# 'Mendenhall Observatory' appears 0 times.
# 'Menke Observatory' appears 0 times.
# 'Metsähovi Observatory' appears 0 times.
# 'Meudon Observatory' appears 7 times.
# 'Meyer–Womble Observatory' appears 0 times.
# 'Michigan State University Observatory' appears 0 times.
# 'Observatoire Midi-Pyrénées Pic du Midi Observatory Toulouse Observatory' appears 0 times.
# 'Milagro' appears 272 times.
# 'Miller Observatory' appears 0 times.
# 'Mills Observatory' appears 12 times.
# 'Mind's Eye Observatory IAU W42' appears 0 times.
# 'MMT Observatory' appears 0 times.
# 'Modine-Benstead Observatory' appears 0 times.
# 'Modra Observatory' appears 0 times.
# 'Mohr Observatory (demolished)' appears 0 times.
# 'Moletai Astronomical Observatory' appears 0 times.
# 'Molonglo Observatory Synthesis Telescope (MOST)' appears 0 times.
# 'Mont Mégantic Observatory' appears 0 times.
# 'Monterey Institute for Research in Astronomy(Oliver Observing Station)' appears 0 times.
# 'Montevideo National Observatory' appears 0 times.
# 'Moore Observatory' appears 0 times.
# 'Morgan–Monroe Observatory' appears 0 times.
# 'Morris Observatory' appears 0 times.
# 'Morrison Observatory' appears 0 times.
# 'Moscow Cosmic-Ray Station' appears 0 times.
# 'Mount Stony Brook Observatory' appears 0 times.
# 'Mounds Observatory' appears 0 times.
# 'Mount Abu InfraRed Observatory' appears 0 times.
# 'Mount Burnett Observatory' appears 0 times.
# 'Mount Cuba Astronomical Observatory' appears 0 times.
# 'Mount Graham International Observatory' appears 0 times.
# 'Mount John University Observatory' appears 0 times.
# 'Mount Laguna Observatory' appears 0 times.
# 'Mount Lemmon Observatory' appears 0 times.
# 'Mount Pleasant Radio Observatory' appears 0 times.
# 'Mount Stromlo Observatory' appears 0 times.
# 'Mount Suhora Observatory' appears 0 times.
# 'Mount Wilson Observatory' appears 129 times.
# 'Mountain Skies Observatory' appears 0 times.
# 'Mullard Radio Astronomy Observatory' appears 0 times.
# 'Murchison Radio-astronomy Observatory' appears 0 times.
# 'Nachi-Katsuura Observatory' appears 0 times.
# 'Nançay Radio Telescope' appears 0 times.
# 'Nanjing Astronomical Instruments Research Centre' appears 0 times.
# 'National Astronomical Observatory (Colombia)' appears 0 times.
# 'National Astronomical Observatory of Japan' appears 9 times.
# 'National Astronomical Observatory (Mexico)' appears 0 times.
# 'National Observatory (Brazil)' appears 0 times.
# 'National Observatory of Athens' appears 85 times.
# 'National Optical Astronomy Observatory Cerro Tololo Inter-American Observatory Gemini Observatory Kitt Peak National Observatory National Solar Observatory' appears 0 times.
# 'National Optical Observatory' appears 0 times.
# 'National Radio Astronomy Observatory Atacama Large Millimeter Array Green Bank Telescope Very Large Array Very Long Baseline Array' appears 0 times.
# 'National Research Institute of Astronomy and Geophysics (NRIAG)' appears 0 times.
# 'National Solar Observatory' appears 26 times.
# 'Naval Research Lab. Radio Sta.' appears 0 times.
# 'Naylor Observatory' appears 0 times.
# 'Neuchâtel Observatory' appears 0 times.
# 'Nice Observatory' appears 8 times.
# 'Nizamia Observatory' appears 0 times.
# 'Nordic Optical Telescope' appears 1 times.
# 'Norilsk Cosmic-Ray Station' appears 0 times.
# 'Norman Lockyer Observatory' appears 1 times.
# 'Northern Arizona University Observatory' appears 0 times.
# 'Northern Skies Observatory' appears 0 times.
# 'Northolt Branch Observatory' appears 0 times.
# 'Northolt Branch Observatory 2, Shepherd's Bush' appears 0 times.
# 'Northolt Branch Observatory 3, Blandford Forum' appears 0 times.
# 'North Georgia Astronomical Observatory' appears 0 times.
# 'North Otago Astronomical Society Observatory' appears 0 times.
# 'Nyrölä Observatory' appears 0 times.
# 'OAC (Observatorio Astronómico de Córdoba)' appears 0 times.
# 'OAO (Observatorio de Aras de los Olmos)' appears 0 times.
# 'O'Brien Observatory' appears 0 times.
# 'Observatoire du Pic de Château-Renard' appears 0 times.
# 'Observatorio Astronómico Nacional (Colombia)' appears 0 times.
# 'Observatorio Astronomico Nacional Tonantzintla' appears 0 times.
# 'Observatorio Solar Carl Sagan' appears 0 times.
# 'Observatory House (defunct)' appears 0 times.
# 'Observatory of the rue Serpente (defunct)' appears 0 times.
# 'Oil Region Astronomical Observatory' appears 0 times.
# 'Onan Observatory' appears 0 times.
# 'Ondokuz Mayıs University Observatory' appears 0 times.
# 'Ondřejov Observatory' appears 0 times.
# 'Onsala Space Observatory' appears 7 times.
# 'Ooty Radio Telescope' appears 2 times.
# 'Orchard Hill Observatory' appears 0 times.
# 'Orioloromano Observatory' appears 0 times.
# 'Orion 1 (defunct)' appears 0 times.
# 'Orion 2 (defunct)' appears 0 times.
# 'Orion Ranch Observatory' appears 0 times.
# 'Orwell Park School Observatory' appears 0 times.
# 'Ostrowik Observatory' appears 0 times.
# 'Otter Creek Observatory' appears 0 times.
# 'Oulu Cosmic-Ray Station' appears 0 times.
# 'Owens Valley Radio Observatory' appears 1 times.
# 'Pachmarhi Array of Cerenkov Telescopes (PACT)' appears 0 times.
# 'Palisades-Dows Observatory' appears 0 times.
# 'PAGASA Astronomical Observatory' appears 0 times.
# 'Palermo Observatory' appears 0 times.
# 'Palomar Observatory' appears 2 times.
# 'Panzano Observatory' appears 0 times.
# 'Paranal Observatory' appears 0 times.
# 'Paris Observatory' appears 62 times.
# 'Parkes Observatory' appears 0 times.
# 'Paul Robinson Observatory' appears 0 times.
# 'Peach Mountain Observatory' appears 0 times.
# 'Perkins Observatory' appears 2 times.
# 'Perth Observatory' appears 5 times.
# 'Peterberg Observatory' appears 0 times.
# 'Pic du Midi Observatory' appears 5 times.
# 'Pico dos Dias Observatory' appears 0 times.
# 'Piera Observatory' appears 0 times.
# 'Pierre Auger Observatory' appears 30 times.
# 'Pine Bluff Observatory' appears 0 times.
# 'Pine Mountain Observatory' appears 0 times.
# 'Pistoia Mountains Astronomical Observatory' appears 0 times.
# 'Piwnice Ovservatory' appears 0 times.
# 'Planetarium and Astronomical Observatory in Grudziądz' appears 0 times.
# 'Pollock Astronomical Observatory' appears 0 times.
# 'Portage Lake Observatory (defunct)' appears 0 times.
# 'Poznań Observatory' appears 0 times.
# 'Puckett Observatory' appears 0 times.
# 'Pula Observatory' appears 0 times.
# 'Pulkovo Observatory' appears 4 times.
# 'Purple Mountain Observatory' appears 2 times.
# 'Quito Astronomical Observatory' appears 0 times.
# 'Radcliffe Observatory' appears 5 times.
# 'Rainwater Observatory' appears 0 times.
# 'Ralph A. Worley Observatory' appears 0 times.
# 'Rankin Science Observatory' appears 0 times.
# 'Rancho Mirage Library and Observatory' appears 0 times.
# 'Rattlesnake Mountain Observatory (defunct)' appears 0 times.
# 'Real Instituto y Observatorio de la Armada (Spain)' appears 0 times.
# 'Red Barn Observatory' appears 0 times.
# 'Red Buttes Observatory' appears 0 times.
# 'Riley Observatory' appears 0 times.
# 'RIT Observatory' appears 0 times.
# 'Ritter Observatory' appears 0 times.
# 'Robert A. Schommer Observatory' appears 0 times.
# 'Robert Brownlee Observatory' appears 0 times.
# 'Robinson Observatory' appears 0 times.
# 'Robotic Lunar Observatory (defunct)' appears 0 times.
# 'Roger Twitchell Observatory[3]' appears 0 times.
# 'Rogers Observatory' appears 0 times.
# 'Rolnick Observatory' appears 0 times.
# 'Rome Observatory' appears 2 times.
# 'Roseland Observatory' appears 0 times.
# 'Rossall School Observatory' appears 0 times.
# 'Rothney Astrophysical Observatory' appears 0 times.
# 'Royal Observatory, Greenwich' appears 26 times.
# 'Royal Observatory, Edinburgh' appears 5 times.
# 'Roque de los Muchachos Observatory' appears 3 times.
# 'Rosemary Hill Observatory' appears 0 times.
# 'Rozhen Observatory' appears 0 times.
# 'Rutherford Observatory' appears 0 times.
# 'San Fernando Observatory (SFO)' appears 0 times.
# 'Sankt Andreasberg Observatory' appears 0 times.
# 'Sayan Spectrographic Cosmic Ray Complex' appears 0 times.
# 'SFA Observatory' appears 0 times.
# 'Sagamore Hill Radio Observatory' appears 1 times.
# 'Shattuck Observatory' appears 5 times.
# 'Sherwood Observatory' appears 0 times.
# 'Seven Hills Observatory' appears 0 times.
# 'Shamakhi Astrophysical Observatory' appears 0 times.
# 'Shanghai Astronomical Observatory' appears 1 times.
# 'Sherzer Observatory' appears 0 times.
# 'Sheshan Astronomical Observatory' appears 0 times.
# 'Siding Spring Observatory' appears 1 times.
# 'Sidmouth Observatory' appears 0 times.
# 'Sierra Nevada Observatory' appears 3 times.
# 'Silesian Planetarium and Astronomical Observatory' appears 0 times.
# 'Simeiz Observatory' appears 0 times.
# 'Skalnaté Pleso Observatory' appears 0 times.
# 'Skinakas Observatory' appears 0 times.
# 'Skylab' appears 17 times.
# 'Smith Observatory' appears 12 times.
# 'Smithsonian Astrophysical Observatory' appears 51 times.
# 'Sobaeksan Optical Astronomy Observatory' appears 0 times.
# 'Sola Fide Observatory' appears 0 times.
# 'Solar and Heliospheric Observatory (SOHO)' appears 3 times.
# 'Solar Space Telescope' appears 0 times.
# 'Sommers–Bausch Observatory' appears 0 times.
# 'Sonnenborgh Observatory' appears 0 times.
# 'Sonoma State Observatory' appears 0 times.
# 'South African Astronomical Observatory Cape Town Sutherland' appears 0 times.
# 'Southern Astrophysical Research Telescope (SOAR)' appears 0 times.
# 'South Pole Telescope' appears 2 times.
# 'Spanish National Observatory' appears 0 times.
# 'Special Astrophysical Observatory of the Russian Academy of Sciences' appears 1 times.
# 'Sperry Observatory' appears 0 times.
# 'Spitzer Space Telescope' appears 6 times.
# 'Springfield Observatory' appears 0 times.
# 'Sproul Observatory' appears 20 times.
# 'Stardome Observatory' appears 0 times.
# 'Starkenburg Observatory' appears 0 times.
# 'Štefánik's Observatory' appears 0 times.
# 'Stellafane Observatory' appears 0 times.
# 'Stephens Memorial Observatory' appears 0 times.
# 'Steward Observatory MMT Observatory Mount Graham International Observatory Mount Lemmon Observatory' appears 0 times.
# 'Stickney Observatory[4]' appears 0 times.
# 'Stjerneborg' appears 1 times.
# 'Stockholm Observatory' appears 2 times.
# 'Stokesville Observatory' appears 0 times.
# 'Stone Observatory' appears 0 times.
# 'Stonyhurst Observatory' appears 2 times.
# 'Strasbourg Observatory' appears 0 times.
# 'Stratospheric Observatory for Infrared Astronomy' appears 0 times.
# 'Stull Observatory' appears 0 times.
# 'Stuttgart Observatory' appears 0 times.
# 'Submillimeter Array' appears 4 times.
# 'St. Thomas Observatory' appears 0 times.
# 'Sudbury Neutrino Observatory' appears 7 times.
# 'Sunriver Observatory' appears 0 times.
# 'Swift Gamma-Ray Burst Mission' appears 0 times.
# 'Swiss Observatory Polychron and Astronomy' appears 0 times.
# 'Sydney Observatory' appears 6 times.
# 'Table Mountain Observatory' appears 3 times.
# 'Tacubaya Observatory' appears 1 times.
# 'Taeduk Radio Astronomy Observatory' appears 0 times.
# 'Tamke-Allan Observatory' appears 0 times.
# 'Tartu Observatory' appears 8 times.
# 'Teide Observatory' appears 4 times.
# 'Ten Acre Observatory' appears 0 times.
# 'Terskol Peak Observatory' appears 0 times.
# 'Thai National Observatory' appears 0 times.
# 'The Dam Observatory' appears 0 times.
# 'The Heights Observatory' appears 0 times.
# 'Texas A&M Astronomical Observatory' appears 0 times.
# 'Theodore Jacobsen Observatory' appears 0 times.
# 'Thompson Observatory' appears 0 times.
# 'Tien Shan Astronomical Observatory' appears 0 times.
# 'Tuorla Observatory' appears 3 times.
# 'Trieste Observatory' appears 0 times.
# 'Troodos Observatory' appears 0 times.
# 'Turin Observatory' appears 2 times.
# 'Udaipur Solar Observatory' appears 3 times.
# 'Ukrainian T-shaped Radio telescope, second modification' appears 0 times.
# 'Ulugh Beg Observatory' appears 0 times.
# 'University of Alabama Observatory' appears 0 times.
# 'University of Alabama Observatory (Old)' appears 0 times.
# 'University of North Alabama Observatory' appears 0 times.
# 'University of Illinois Astronomical Observatory' appears 0 times.
# 'University of London Observatory' appears 0 times.
# 'University of Maryland Observatory' appears 0 times.
# 'University of Michigan-Dearborn Observatory' appears 0 times.
# 'University of New Hampshire Observatory' appears 0 times.
# 'University of Oklahoma Observatory' appears 0 times.
# 'University of Puerto Rico at Humacao Observatory[5]' appears 0 times.
# 'University of Valencia Astronomical Observatory' appears 0 times.
# 'Uppsala Astronomical Observatory' appears 1 times.
# 'Urania (Antwerp)' appears 0 times.
# 'Urania (Berlin)' appears 0 times.
# 'Urania (Vienna)' appears 0 times.
# 'Urania Observatory (Zürich)' appears 0 times.
# 'Uraniborg' appears 0 times.
# 'Urumqi Astronomical Observatory' appears 0 times.
# 'U.S. Naval Observatory (USNO)[6] Depot of Charts and Instruments (U.S. Navy) (precursor, renamed to USNO) U.S. Naval Observatory (Flagstaff Station)' appears 0 times.
# 'Valongo Observatory' appears 0 times.
# 'Vainu Bappu Observatory' appears 0 times.
# 'Astronomical observatory of Aosta Valley' appears 0 times.
# 'Van Vleck Observatory' appears 7 times.
# 'Vanderbilt University Observatory' appears 0 times.
# 'Vartiovuori Observatory (defunct)' appears 0 times.
# 'Vassar College Observatory (defunct)' appears 0 times.
# 'Vatican Observatory Vatican Advanced Technology Telescope' appears 0 times.
# 'Veen Observatory' appears 0 times.
# 'Vega–Bray Observatory' appears 0 times.
# 'Ventspils Starptautiskais Radioastronomijas Centrs' appears 0 times.
# 'Vernonia Peak Observatory' appears 0 times.
# 'Very Large Array' appears 9 times.
# 'Very Long Baseline Array' appears 2 times.
# 'Vienna Observatory' appears 3 times.
# 'Vilnius University Observatory' appears 0 times.
# 'Višnjan Observatory' appears 0 times.
# 'Vsetín Observatory' appears 0 times.
# 'Warkworth Radio Observatory' appears 0 times.
# 'Warner Observatory (defunct)' appears 0 times.
# 'Warner and Swasey Observatory' appears 2 times.
# 'Warren Rupp Observatory' appears 0 times.
# 'Warsaw University Observatory' appears 3 times.
# 'Washburn Observatory' appears 32 times.
# 'Wast Hills Observatory' appears 0 times.
# 'Weaver Student Observatory' appears 0 times.
# 'Weitkamp Observatory' appears 0 times.
# 'West Mountain Observatory' appears 0 times.
# 'Whakatane Astronomical Society' appears 0 times.
# 'Whitin Observatory' appears 7 times.
# 'Widener University Observatory' appears 0 times.
# 'Wilder Observatory' appears 0 times.
# 'Willard L. Eccles Observatory' appears 0 times.
# 'William Brydone Jack Observatory' appears 0 times.
# 'Williams Observatory' appears 0 times.
# 'Winer Observatory' appears 1 times.
# 'Winfree Observatory' appears 0 times.
# 'Wise Observatory' appears 3 times.
# 'Witte Observatory' appears 0 times.
# 'WIYN Observatory' appears 0 times.
# 'Wyoming Infrared Observatory' appears 1 times.
# 'Xiangfen Astronomical Observatory' appears 0 times.
# 'Xinglong Station (NAOC)' appears 0 times.
# 'Xinjiang Astronomical Observatory' appears 1 times.
# 'XMM-Newton' appears 16 times.
# 'XRISM' appears 0 times.
# 'Xujiahui Astronomical Observatory' appears 0 times.
# 'Arctic Space Weather Center' appears 0 times.
# 'Yale Student Observatory' appears 0 times.
# 'Yangbajing International Cosmic-Ray Observatory' appears 0 times.
# 'Yantra Mandir' appears 0 times.
# 'Yerevan Cosmic-Ray Station' appears 0 times.
# 'Yerkes Observatory' appears 200 times.
# 'York University Observatory' appears 0 times.
# 'Yuba City Astronomical Observatory' appears 0 times.
# 'Yunnan Astronomical Observatory' appears 2 times.
# 'Zimmerwald Observatory' appears 1 times.
# 'Zadko Observatory' appears 0 times.
# 'AVN-Ghana' appears 0 times.
# 'C-BASS South' appears 0 times.
# 'HartRAO 26m' appears 0 times.
# 'HartRAO XDM' appears 0 times.
# 'Hydrogen Epoch of Reionization Array (HERA)' appears 0 times.
# 'Hydrogen Intensity and Real-time Analysis eXperiment (HIRAX)' appears 0 times.
# 'Indlebe' appears 1 times.
# 'KAT-7' appears 1 times.
# 'MeerKAT' appears 4 times.
# 'Precision Array for Probing the Epoch of Reionization (PAPER)' appears 0 times.
# 'Degree Angular Scale Interferometer (DASI)' appears 0 times.
# 'South Pole Telescope (SPT)' appears 0 times.
# 'Delingha 13.7 m' appears 0 times.
# 'Sheshan' appears 2 times.
# 'Nanshan 25m' appears 0 times.
# 'Primeval Structure Telescope (PaST)' appears 0 times.
# 'Chinese Spectral Radio Heliograph (CSRH)' appears 0 times.
# 'Miyun Synthesis Radio Telescope (MSRT)' appears 0 times.
# 'Miyun 50m Radio Telescope' appears 0 times.
# 'Kunming 40m Radio Telescope' appears 0 times.
# 'Tian Ma 65m Radio Telescope' appears 0 times.
# 'Giant Metrewave Radio Telescope (GMRT)' appears 1 times.
# 'Ooty Radio Telescope (ORT)' appears 0 times.
# 'Nobeyama radio observatory' appears 1 times.
# 'Siberian Solar Radio Telescope (SSRT)' appears 0 times.
# 'Badary Radio Astronomical Observatory' appears 0 times.
# 'Galenki RT-70 radio telescope' appears 0 times.
# 'Suffa RT-70 radio telescope' appears 0 times.
# 'Five hundred meter Aperture Spherical Telescope (FAST)' appears 0 times.
# 'Qitai Radio Telescope' appears 0 times.
# 'Thai National Radio Telescope' appears 0 times.
# 'VERA' appears 21677 times.
# 'Mingantu interplanetary scintillation telescope' appears 0 times.
# 'Taeduk Radio Astronomy Observatory (TRAO)' appears 0 times.
# 'Korean VLBI Network (KVN)' appears 0 times.
# 'Australian Square Kilometre Array Pathfinder (ASKAP)' appears 0 times.
# 'Australia Telescope Compact Array (ATCA)' appears 0 times.
# 'Canberra Deep Space Communication Complex (CDSCC)' appears 0 times.
# 'Ceduna Radio Observatory' appears 0 times.
# 'Mopra Radio Telescope' appears 0 times.
# 'Mount Pleasant Radio Telescope' appears 0 times.
# 'Murchison Widefield Array (MWA)' appears 0 times.
# 'Parkes Radio Telescope' appears 0 times.
# 'Ukrainian T-shaped Radio telescope, second modification (UTR-2)' appears 0 times.
# 'Giant Ukrainian Radio Telescope (GURT)' appears 0 times.
# 'Lovell Telescope' appears 0 times.
# 'Yevpatoria RT-70 radio telescope' appears 0 times.
# 'RATAN-600' appears 1 times.
# 'RT-64 (TNA-1500)' appears 0 times.
# 'RT-22' appears 0 times.
# 'DKR-1000' appears 0 times.
# 'BSA' appears 742 times.
# 'Radioastronomical Observatory Zelenchukskaya' appears 0 times.
# 'Svetloe Radio Astronomical Observatory' appears 0 times.
# 'RT-7.5 (Bauman's radio telescope)' appears 0 times.
# 'Yebes RT 40 m' appears 0 times.
# 'Toruń RT4 32 m' appears 0 times.
# 'RT-32' appears 2 times.
# 'Northern Cross Radio Telescope' appears 0 times.
# '32 m VLBI dish' appears 0 times.
# 'MERLIN (Multi-Element Radio Linked Interferometer Network)' appears 0 times.
# 'EAARO – East Anglian Astrophysiscal Research Organisation' appears 0 times.
# 'TNA-400' appears 0 times.
# 'IRAM – 30m' appears 0 times.
# 'Mark II' appears 54 times.
# 'Stockert' appears 0 times.
# 'Toruń RT3 15 m' appears 0 times.
# 'Westerbork Synthesis Radio Telescope (WSRT)' appears 0 times.
# '25 m telescope' appears 0 times.
# 'Dwingeloo (CAMRAS)' appears 0 times.
# '22 m telescope' appears 0 times.
# '20 m telescope' appears 0 times.
# 'Pluton (complex)' appears 0 times.
# 'RT-16' appears 4 times.
# 'Metsähovi Radio Observatory' appears 0 times.
# 'Ryle Telescope' appears 0 times.
# 'Erciyes University Radio Observatory' appears 0 times.
# 'Wurzburg v2.0 LAB/OASU (Bordeaux Observatory radio telescope)' appears 0 times.
# 'European VLBI Network (EVN)' appears 0 times.
# 'Plateau de Bure Interferometer' appears 1 times.
# 'Northern Extended Millimeter Array' appears 0 times.
# 'Nançay Radio Telescope (NRT)' appears 0 times.
# 'Nançay Decameter Array (DAM)' appears 0 times.
# 'Nançay Radio Heliographe (NRH)' appears 0 times.
# 'ALLBIN (Amateur Linked Long Baseline Interferometer Network)' appears 0 times.
# 'LOFAR (LOw Frequency ARray)' appears 0 times.
# 'São Gião radio telescope (SGRT)' appears 0 times.
# 'Arcminute Microkelvin Imager' appears 2 times.
# 'The European Radio Astronomy Club Telescope and Development Facility (ERAC Telescope)' appears 0 times.
# 'ERAC Phased Array' appears 0 times.
# '64 m Sardinia Radio Telescope' appears 0 times.
# 'ROT-54/2.6' appears 0 times.
# 'Algonquin Radio Telescope' appears 0 times.
# 'Allen Telescope Array' appears 0 times.
# 'ARO 12m Radio Telescope' appears 0 times.
# 'C-BASS North' appears 0 times.
# 'Canadian Hydrogen Intensity Mapping Experiment (CHIME)' appears 0 times.
# 'CfA 1.2 m Millimeter-Wave Telescope' appears 0 times.
# 'Combined Array for Research in Millimeter-wave Astronomy (CARMA)' appears 0 times.
# 'Distributed Array Radio Telescope (DART)' appears 0 times.
# 'Five College Radio Astronomy Observatory (FCRAO)' appears 0 times.
# 'Goldstone Radio Telescope' appears 0 times.
# 'Green Bank Interferometer (GBI)' appears 0 times.
# 'Green Bank Telescope (GBT)' appears 2 times.
# 'Green Bank 140 Foot Telescope (140foot)' appears 0 times.
# 'Green Bank 20m Telescope' appears 0 times.
# 'Heinrich Hertz Submillimeter Telescope (SMT)' appears 0 times.
# 'Large Millimeter Telescope (LMT)' appears 0 times.
# 'Leuschner Observatory' appears 1 times.
# 'Long Wavelength Array (LWA)' appears 0 times.
# 'Morehead State University 21m.' appears 0 times.
# 'Paul Plishner Radio Astronomy and Space Sciences Center' appears 0 times.
# 'OVRO 40 meter Telescope' appears 0 times.
# 'Solar monitor, two 1.8 m dishes' appears 0 times.
# 'SRI International Antenna Facility' appears 0 times.
# 'Synthesis Telescope, seven-element interferometer' appears 0 times.
# 'Very Large Array (VLA)' appears 2 times.
# 'Very Small Array (VSA)' appears 0 times.
# 'Very Long Baseline Array (VLBA)' appears 1 times.
# 'Pisgah Astronomical Research Institute (PARI)' appears 0 times.
# 'Atacama B-Mode Search (ABS)' appears 0 times.
# 'Atacama Cosmology Telescope (ACT)' appears 1 times.
# 'Atacama Large Millimeter Array (ALMA)' appears 0 times.
# 'Atacama Submillimeter Telescope Experiment (ASTE)' appears 0 times.
# 'Baryon Acoustic Oscillations in Integrated Neutral Gas Observations (BINGO)' appears 0 times.
# 'Brazilian Decimetric Array (BDA)' appears 0 times.
# 'Cosmic Background Imager (CBI)' appears 0 times.
# 'Itapetinga Radio Observatory' appears 0 times.
# 'Jicamarca Radio Observatory (ROJ)' appears 0 times.
# 'Cosmology Large Angular Scale Surveyor (CLASS)' appears 1 times.
# 'NANTEN2 Observatory (NANTEN2)' appears 0 times.
# 'Northeastern Space Radio Observatory' appears 0 times.
# 'Polarization Emission of Millimeter Activity at the Sun' appears 0 times.
# 'Q/U Imaging Experiment (QUIET)' appears 0 times.
# 'Solar Submillimeter Telescope (SST)' appears 0 times.
# 'Swedish-ESO Submillimetre Telescope (SEST)' appears 0 times.
# 'Estación de Espacio Lejano [es]' appears 0 times.
# 'Malargüe Station' appears 0 times.
# 'Greenland Telescope' appears 1 times.
# 'Eiscat Radio Telescope' appears 0 times.
# 'Arecibo Telescope' appears 3 times.
# 'Mauritius Radio Telescope' appears 0 times.
# 'Caltech Submillimeter Observatory' appears 1 times.
# 'Submillimeter Array (SMA)' appears 0 times.
# 'Warkworth Radio Telescope' appears 0 times.
# 'Warkworth 2 dish' appears 0 times.
# 'Transient Array Radio Telescope' appears 0 times.
# 'HALCA (Highly Advanced Laboratory for Communications and Astronomy)' appears 0 times.
# 'Zond 3' appears 0 times.
# 'Spektr-R or RadioAstron' appears 0 times.
# 'Chang'e 4' appears 0 times.
# 'EAARO - East Anglian Astrophysical Research Organisation' appears 0 times.
# 'Large Latin American Millimeter Array (LLAMA)' appears 0 times.
# 'Qitai 110m Radio Telescope (QTT)' appears 0 times.
# 'Square Kilometer Array (SKA-Phase1)' appears 0 times.
# '30m Sub-Millimeter Telescope (TSMT)' appears 0 times.
# 'LOFAR Super Station (LSS)' appears 0 times.
# 'Lunar Crater Radio Telescope (LCRT)' appears 0 times.
# 'Square Kilometer Array (SKA-Phase2)' appears 0 times.
# 'Daniel K. Inouye Solar Telescope (DKIST)' appears 0 times.
# 'Chinese Large Solar Telescope (CLST)' appears 0 times.
# 'GREGOR, Teide Observatory' appears 0 times.
# 'Goode Solar Telescope (GST), Big Bear Solar Observatory' appears 0 times.
# 'New Vacuum Solar Telescope (NVST), Yunnan Astronomical Observatory' appears 0 times.
# 'Andrei Severny Tower Solar Telescope, Crimean Astrophysical Observatory' appears 0 times.
# 'Multi-Purpose Automated Solar Telescope, Sayan Solar Observatory' appears 0 times.
# 'Large Solar Vakuum Telescope, Baikal Astrophysical Observatory' appears 0 times.
# 'Optical and Near-Infrared Solar Eruption Tracer (ONSET), School of Astronomy & Space Science, Nanjing University' appears 0 times.
# 'Bulgarian 15-cm Solar Coronagraph,[10] Rozhen National Astronomical Observatory Bulgaria' appears 0 times.
# 'Swedish Solar Telescope (SST), Roque de los Muchachos Observatory' appears 0 times.
# 'Prairie View Solar Observatory (PVSO)[12]' appears 0 times.
# 'Upgraded Coronal Multi-Channel Polarimeter (UCOMP)' appears 0 times.
# 'K-Coronagraph (K-COR)' appears 0 times.
# 'Dutch Open Telescope (DOT), Roque de los Muchachos Observatory' appears 0 times.
# 'THÉMIS Solar Telescope, Teide Observatory' appears 0 times.
# 'Vacuum Tower Telescope (VTT), Teide Observatory' appears 0 times.
# 'Hida Domeless Solar Telescope (ja)' appears 0 times.
# 'Udaipur Solar ObservatoryMASTFull Disk H-alpha TelescopeH-alpha Spar TelescopeCoudé Telescope' appears 0 times.
# 'Richard B. Dunn Solar Telescope (DST), Sacramento Peak' appears 0 times.
# 'Solar Observatory Tower Meudon' appears 0 times.
# 'McMath–Pierce solar telescope, KPO' appears 0 times.
# 'ARIES Observatory' appears 0 times.
# 'Solar Tunnel Telescope, Kodaikanal Solar Observatory' appears 0 times.
# '45-cm-Turmteleskop' appears 0 times.
# 'Gregory Coudé Telescope' appears 0 times.
# 'Solar Tower Telescope by Zeiss' appears 0 times.
# 'Einsteinturm' appears 0 times.
# '150-foot tower, Mount Wilson Observatory' appears 0 times.
# 'Snow Solar Telescope, Mount Wilson Observatory' appears 0 times.
# 'Lerebour/Grubb-Parsons, Kodaikanal Solar Observatory' appears 0 times.
# 'Solar-T [pt]' appears 0 times.
# 'Swedish Vacuum Solar Telescope, Roque de los Muchachos Observatory' appears 0 times.
# 'Gregory Coude Telescope (GCT)' appears 0 times.
# 'Evans Solar Facility (ESF), Sacramento Peak' appears 0 times.
# 'Göttinger Sonnenturm (Solar Tower Telescope)' appears 0 times.
# 'McMath-Hulbert Observatory' appears 0 times.
# '50-foot tower, McMath-Hulbert Observatory' appears 0 times.
# '10.5 inch, McMath-Hulbert Observatory' appears 0 times.
# 'Arcetri Solar Tower, Arcetri Observatory' appears 0 times.
# 'Chinese Spectral Radioheliograph (CSRH)' appears 0 times.
# 'Nançay Radioheliographe (NRH), Nançay Radio Observatory' appears 0 times.
# 'Expanded Owens Valley Solar Array (EOVSA)' appears 0 times.
# 'Nobeyama Radioheliograph (NoRH), Nobeyama Radio Observatory' appears 0 times.
# 'Nobeyama Radio Polarimeters, Nobeyama Radio Observatory' appears 0 times.
# 'Solar Submillimeter Telescope (SST), Complejo Astronomico El Leoncito' appears 0 times.
# 'Polarization Emission of Millimeter Activity at the Sun (POEMAS), Complejo Astronomico El Leoncito' appears 0 times.
# 'Bleien Radio Observatory' appears 0 times.
# 'Radio Solar Telescope Network (RSTN)' appears 0 times.
# 'Proton-1' appears 1 times.
# 'Proton-2' appears 0 times.
# 'Proton-4' appears 1 times.
# 'Small Astronomy Satellite 2 (SAS-B)' appears 0 times.
# 'Cos-B' appears 5 times.
# 'High Energy Astronomy Observatory 3 (HEAO 3)' appears 0 times.
# 'Granat' appears 99 times.
# 'Gamma' appears 1228 times.
# 'Compton Gamma Ray Observatory (CGRO)' appears 0 times.
# 'Low Energy Gamma Ray Imager (LEGRI)' appears 0 times.
# 'High Energy Transient Explorer 2 (HETE 2)' appears 0 times.
# 'International Gamma Ray Astrophysics Laboratory (INTEGRAL)' appears 0 times.
# 'Swift Gamma Ray Burst Explorer' appears 0 times.
# 'Astrorivelatore Gamma ad Immagini LEggero (AGILE)' appears 0 times.
# 'Gamma-Ray Burst Polarimeter (GAP)' appears 0 times.
# 'Uhuru (Small Astronomy Satellite 1, SAS-A)' appears 0 times.
# 'Astronomical Netherlands Satellite (ANS)' appears 0 times.
# 'Ariel V' appears 1 times.
# 'Aryabhata' appears 3 times.
# 'Small Astronomy Satellite 3 (SAS-C)' appears 0 times.
# 'Cosmic Radiation Satellite (CORSA)' appears 0 times.
# 'High Energy Astronomy Observatory 1 (HEAO 1)' appears 0 times.
# 'Einstein Observatory (HEAO 2)' appears 0 times.
# 'Hakucho (CORSA-b)' appears 0 times.
# 'Tenma (Astro-B)' appears 0 times.
# 'Astron' appears 4550 times.
# 'EXOSAT' appears 4 times.
# 'Ginga (Astro-C)' appears 0 times.
# 'ROSAT' appears 229 times.
# 'Broad Band X-ray Telescope / Astro 1' appears 0 times.
# 'Advanced Satellite for Cosmology and Astrophysics (ASCA, Astro-D)' appears 0 times.
# 'Array of Low Energy X-ray Imaging Sensors (Alexis)' appears 0 times.
# 'Rossi X-ray Timing Explorer (RXTE)' appears 0 times.
# 'BeppoSAX' appears 9 times.
# 'A Broadband Imaging X-ray All-sky Survey (ABRIXAS)' appears 0 times.
# 'Suzaku (Astro-E2)' appears 0 times.
# 'AGILE' appears 500 times.
# 'Nuclear Spectroscopic Telescope Array (NuSTAR)' appears 0 times.
# 'Astrosat' appears 1 times.
# 'Hitomi (Astro-H)' appears 0 times.
# 'Mikhailo Lomonosov' appears 0 times.
# 'Neutron Star Interior Composition Explorer (NICER)' appears 0 times.
# 'Hard X-ray Modulation Telescope (HXMT)' appears 0 times.
# 'Spektr-RG' appears 0 times.
# 'OAO-2 (Stargazer)' appears 0 times.
# 'Orion 1 and Orion 2 Space Observatories' appears 0 times.
# 'Far Ultraviolet Camera/Spectrograph (UVC)' appears 0 times.
# 'OAO-3 Copernicus' appears 0 times.
# 'International Ultraviolet Explorer (IUE)' appears 1 times.
# 'Extreme Ultraviolet Explorer (EUVE)' appears 0 times.
# 'Astro 2' appears 1 times.
# 'Far Ultraviolet Spectroscopic Explorer (FUSE)' appears 0 times.
# 'Cosmic Hot Interstellar Spectrometer (CHIPS)' appears 0 times.
# 'Korea Advanced Institute of Science and Technology Satellite 4 (Kaistsat 4)' appears 0 times.
# 'Swift Gamma Ray Burst Explorer (Swift)' appears 0 times.
# 'Interface Region Imaging Spectrograph (IRIS)' appears 0 times.
# 'Hisaki (SPRINT-A)' appears 0 times.
# 'Venus Spectral Rocket Experiment' appears 0 times.
# 'Lunar-based ultraviolet telescope (LUT)' appears 0 times.
# 'Spatial Heterodyne Interferometric Emission Line Dynamics Spectrometer (SHIELDS)' appears 0 times.
# 'Hipparcos' appears 6 times.
# 'MOST' appears 22041 times.
# 'Kepler' appears 247 times.
# 'BRITE constellation' appears 0 times.
# 'Near Earth Object Surveillance Satellite (NEOSSat)' appears 0 times.
# 'Gaia (astrometry)' appears 0 times.
# 'Transiting Exoplanet Survey Satellite (TESS)' appears 0 times.
# 'CHEOPS' appears 27 times.
# 'IRAS' appears 335 times.
# 'Infrared Telescope in Space' appears 0 times.
# 'Infrared Space Observatory (ISO)' appears 0 times.
# 'Midcourse Space Experiment (MSX)' appears 0 times.
# 'Submillimeter Wave Astronomy Satellite (SWAS)' appears 0 times.
# 'Wide Field Infrared Explorer (WIRE)' appears 0 times.
# 'Akari (Astro-F)' appears 0 times.
# 'Wide-field Infrared Survey Explorer (WISE)' appears 0 times.
# 'James Webb Space Telescope (JWST)' appears 1 times.
# 'Euclid' appears 767 times.
# 'Cosmic Background Explorer (COBE)' appears 4 times.
# 'Odin' appears 3016 times.
# 'WMAP' appears 72 times.
# 'Planck' appears 1495 times.
# 'Highly Advanced Laboratory for Communications and Astronomy (HALCA, VSOP or MUSES-B)' appears 0 times.
# 'Spektr-R (RadioAstron)' appears 0 times.
# 'High Energy Astrophysics Observatory 3 (HEAO 3)' appears 0 times.
# 'SAMPEX' appears 9 times.
# 'Alpha Magnetic Spectrometer 01 (AMS-01)' appears 0 times.
# 'Payload for Antimatter Matter Exploration and Light-nuclei Astrophysics (PAMELA)' appears 0 times.
# 'IBEX' appears 29 times.
# 'Alpha Magnetic Spectrometer 02 (AMS-02)' appears 0 times.
# 'Lunar Surface Gravimeter' appears 0 times.
# 'X-ray Polarimeter Satellite (XPoSat)' appears 0 times.
# 'International Lunar Observatory Precursor (ILO-X)' appears 0 times.
# 'TOLIMAN' appears 1 times.
# 'Xuntian' appears 0 times.
# 'SPHEREx' appears 0 times.
# 'Astrosat-2' appears 0 times.
# 'PLATO' appears 153 times.
# 'ULTRASAT' appears 0 times.
# 'Nancy Grace Roman Space Telescope (Wide Field Infrared Survey Telescope; WFIRST)' appears 0 times.
# 'ARIEL' appears 83 times.
# 'Advanced Telescope for High Energy Astrophysics (Athena)' appears 0 times.
# 'Laser Interferometer Space Antenna (LISA)' appears 0 times.

# %%
# Process each label and count occurrences of its tokens and bigrams
for idx, label in enumerate(Labels['Labels']):
    # Token counts
    tokens = label.split()  # Split the label into tokens
    token_counts = [full_text.str.contains(re.escape(token), case=False, na=False).sum() for token in tokens]
    print(f"{tokens} appears {token_counts} times in full text data.")
    
    # Bigram counts
    bigrams = generate_bigrams(label)
    bigram_counts = [full_text.str.contains(re.escape(bigram), case=False, na=False).sum() for bigram in bigrams]
    print(f"{bigrams} appears {bigram_counts} times in full text data.")
    print('-' * 80)
# Out:
# ['Abastumani', 'Astrophysical', 'Observatory'] appears [9, 901, 3881] times in full text data.
# ['Abastumani Astrophysical', 'Astrophysical Observatory'] appears [3, 179] times in full text data.
# --------------------------------------------------------------------------------
# ['Abu', 'Reyhan-e', 'Birooni', 'Observatory'] appears [6795, 0, 0, 3881] times in full text data.
# ['Abu Reyhan-e', 'Reyhan-e Birooni', 'Birooni Observatory'] appears [0, 0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Adirondack', 'Public', 'Observatory'] appears [97, 15272, 3881] times in full text data.
# ['Adirondack Public', 'Public Observatory'] appears [0, 2] times in full text data.
# --------------------------------------------------------------------------------
# ['Adolphson', 'Observatory'] appears [0, 3881] times in full text data.
# ['Adolphson Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Airdrie', 'Public', 'Observatory'] appears [8, 15272, 3881] times in full text data.
# ['Airdrie Public', 'Public Observatory'] appears [0, 2] times in full text data.
# --------------------------------------------------------------------------------
# ['Aker', 'Observatory'] appears [6790, 3881] times in full text data.
# ['Aker Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Aldershot', 'Observatory'] appears [7, 3881] times in full text data.
# ['Aldershot Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Algonquin', 'Radio', 'Observatory'] appears [29, 6733, 3881] times in full text data.
# ['Algonquin Radio', 'Radio Observatory'] appears [0, 32] times in full text data.
# --------------------------------------------------------------------------------
# ['Allegheny', 'Observatory'] appears [183, 3881] times in full text data.
# ['Allegheny Observatory'] appears [75] times in full text data.
# --------------------------------------------------------------------------------
# ['Ametlla', 'de', 'Mar', 'Observatory'] appears [1, 24877, 23522, 3881] times in full text data.
# ['Ametlla de', 'de Mar', 'Mar Observatory'] appears [1, 431, 16] times in full text data.
# --------------------------------------------------------------------------------
# ['AMiBA'] appears [2] times in full text data.
# [] appears [] times in full text data.
# --------------------------------------------------------------------------------
# ['Anderson', 'Mesa', 'Station'] appears [3934, 387, 11781] times in full text data.
# ['Anderson Mesa', 'Mesa Station'] appears [2, 2] times in full text data.
# --------------------------------------------------------------------------------
# ['Angell', 'Hall', 'Observatory'] appears [164, 13726, 3881] times in full text data.
# ['Angell Hall', 'Hall Observatory'] appears [0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Ankara', 'University', 'Observatory'] appears [626, 18790, 3881] times in full text data.
# ['Ankara University', 'University Observatory'] appears [5, 65] times in full text data.
# --------------------------------------------------------------------------------
# ['Antarctic', 'Muon', 'and', 'Neutrino', 'Detector', 'Array'] appears [3103, 353, 24855, 284, 3156, 2538] times in full text data.
# ['Antarctic Muon', 'Muon and', 'and Neutrino', 'Neutrino Detector', 'Detector Array'] appears [1, 43, 80, 35, 78] times in full text data.
# --------------------------------------------------------------------------------
# ['Antarctic', 'Submillimeter', 'Telescope', 'and', 'Remote', 'Observatory'] appears [3103, 116, 1771, 24855, 8343, 3881] times in full text data.
# ['Antarctic Submillimeter', 'Submillimeter Telescope', 'Telescope and', 'and Remote', 'Remote Observatory'] appears [0, 1, 261, 2405, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['ANTARES'] appears [73] times in full text data.
# [] appears [] times in full text data.
# --------------------------------------------------------------------------------
# ['Apache-Sitgreaves', 'Observatory'] appears [0, 3881] times in full text data.
# ['Apache-Sitgreaves Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Apache', 'Point', 'Observatory'] appears [99, 20384, 3881] times in full text data.
# ['Apache Point', 'Point Observatory'] appears [2, 4] times in full text data.
# --------------------------------------------------------------------------------
# ['Apatity', 'Cosmic-Ray', 'Station'] appears [44, 168, 11781] times in full text data.
# ['Apatity Cosmic-Ray', 'Cosmic-Ray Station'] appears [0, 2] times in full text data.
# --------------------------------------------------------------------------------
# ['Apollo', 'Observatory'] appears [259, 3881] times in full text data.
# ['Apollo Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Arcetri', 'Observatory'] appears [16, 3881] times in full text data.
# ['Arcetri Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Arecibo', 'Observatory'] appears [96, 3881] times in full text data.
# ['Arecibo Observatory'] appears [21] times in full text data.
# --------------------------------------------------------------------------------
# ['Argentine', 'Institute', 'of', 'Radio', 'Astronomy'] appears [268, 12296, 24853, 6733, 2145] times in full text data.
# ['Argentine Institute', 'Institute of', 'of Radio', 'Radio Astronomy'] appears [0, 7409, 1248, 43] times in full text data.
# --------------------------------------------------------------------------------
# ['Armagh', 'Observatory'] appears [13, 3881] times in full text data.
# ['Armagh Observatory'] appears [3] times in full text data.
# --------------------------------------------------------------------------------
# ['Aryabhatta', 'Research', 'Institute', 'of', 'Observational', 'Sciences'] appears [4, 18817, 12296, 24853, 4433, 16402] times in full text data.
# ['Aryabhatta Research', 'Research Institute', 'Institute of', 'of Observational', 'Observational Sciences'] appears [4, 1654, 7409, 629, 7] times in full text data.
# --------------------------------------------------------------------------------
# ['Ashton', 'Observatory'] appears [65, 3881] times in full text data.
# ['Ashton Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Asiago', 'Astrophysical', 'Observatory'] appears [2, 901, 3881] times in full text data.
# ['Asiago Astrophysical', 'Astrophysical Observatory'] appears [0, 179] times in full text data.
# --------------------------------------------------------------------------------
# ['Assheton', 'Observatory'] appears [2, 3881] times in full text data.
# ['Assheton Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Astron', '(defunct)'] appears [4550, 0] times in full text data.
# ['Astron (defunct)'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Astronomical', 'Observatory', 'Aurora'] appears [2206, 3881, 924] times in full text data.
# ['Astronomical Observatory', 'Observatory Aurora'] appears [139, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Astronomical', 'Observatory', 'of', 'Lisbon'] appears [2206, 3881, 24853, 238] times in full text data.
# ['Astronomical Observatory', 'Observatory of', 'of Lisbon'] appears [139, 582, 43] times in full text data.
# --------------------------------------------------------------------------------
# ['Astronomy', 'Centre'] appears [2145, 7555] times in full text data.
# ['Astronomy Centre'] appears [4] times in full text data.
# --------------------------------------------------------------------------------
# ['Astronomy', 'Tower', 'of', 'the', 'Sorbonne'] appears [2145, 1862, 24853, 24856, 208] times in full text data.
# ['Astronomy Tower', 'Tower of', 'of the', 'the Sorbonne'] appears [0, 158, 24800, 47] times in full text data.
# --------------------------------------------------------------------------------
# ['Astrophysical', 'Institute', 'Potsdam'] appears [901, 12296, 628] times in full text data.
# ['Astrophysical Institute', 'Institute Potsdam'] appears [6, 3] times in full text data.
# --------------------------------------------------------------------------------
# ['Atacama', 'Pathfinder', 'Experiment', '(APEX)'] appears [75, 391, 15373, 16] times in full text data.
# ['Atacama Pathfinder', 'Pathfinder Experiment', 'Experiment (APEX)'] appears [0, 0, 9] times in full text data.
# --------------------------------------------------------------------------------
# ['Australia', 'Telescope', 'Compact', 'Array'] appears [3321, 1771, 2321, 2538] times in full text data.
# ['Australia Telescope', 'Telescope Compact', 'Compact Array'] appears [1, 0, 3] times in full text data.
# --------------------------------------------------------------------------------
# ['Australian', 'Astronomical', 'Observatory'] appears [1257, 2206, 3881] times in full text data.
# ['Australian Astronomical', 'Astronomical Observatory'] appears [0, 139] times in full text data.
# --------------------------------------------------------------------------------
# ['Badlands', 'Observatory'] appears [30, 3881] times in full text data.
# ['Badlands Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Baikal', 'Deep', 'Underwater', 'Neutrino', 'Telescope'] appears [104, 8419, 315, 284, 1771] times in full text data.
# ['Baikal Deep', 'Deep Underwater', 'Underwater Neutrino', 'Neutrino Telescope'] appears [0, 6, 3, 38] times in full text data.
# --------------------------------------------------------------------------------
# ['Bangladesh', 'Astronomical', 'Observatory'] appears [145, 2206, 3881] times in full text data.
# ['Bangladesh Astronomical', 'Astronomical Observatory'] appears [0, 139] times in full text data.
# --------------------------------------------------------------------------------
# ['Baker', 'Observatory'] appears [2109, 3881] times in full text data.
# ['Baker Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Baksan', 'Neutrino', 'Observatory'] appears [9, 284, 3881] times in full text data.
# ['Baksan Neutrino', 'Neutrino Observatory'] appears [0, 20] times in full text data.
# --------------------------------------------------------------------------------
# ['Ball', 'State', 'University', 'Observatory'] appears [5928, 18939, 18790, 3881] times in full text data.
# ['Ball State', 'State University', 'University Observatory'] appears [4, 1771, 65] times in full text data.
# --------------------------------------------------------------------------------
# ['Barnard', 'Observatory', '(defunct)'] appears [521, 3881, 0] times in full text data.
# ['Barnard Observatory', 'Observatory (defunct)'] appears [0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bareket', 'Observatory'] appears [0, 3881] times in full text data.
# ['Bareket Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Barnett', 'Observatory'] appears [416, 3881] times in full text data.
# ['Barnett Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bayfordbury', 'Observatory'] appears [3, 3881] times in full text data.
# ['Bayfordbury Observatory'] appears [2] times in full text data.
# --------------------------------------------------------------------------------
# ['Behlen', 'Observatory'] appears [1, 3881] times in full text data.
# ['Behlen Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Beijing', 'Astronomical', 'Observatory'] appears [2418, 2206, 3881] times in full text data.
# ['Beijing Astronomical', 'Astronomical Observatory'] appears [0, 139] times in full text data.
# --------------------------------------------------------------------------------
# ['Beijing', 'Ancient', 'Observatory'] appears [2418, 1877, 3881] times in full text data.
# ['Beijing Ancient', 'Ancient Observatory'] appears [0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Belgrade', 'Observatory'] appears [83, 3881] times in full text data.
# ['Belgrade Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Belogradchik', 'Observatory'] appears [0, 3881] times in full text data.
# ['Belogradchik Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Benmore', 'Peak', 'Observatory'] appears [4, 11241, 3881] times in full text data.
# ['Benmore Peak', 'Peak Observatory'] appears [0, 10] times in full text data.
# --------------------------------------------------------------------------------
# ['BeppoSAX', '(defunct)'] appears [9, 0] times in full text data.
# ['BeppoSAX (defunct)'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bergisch', 'Gladbach', 'Observatory'] appears [34, 5, 3881] times in full text data.
# ['Bergisch Gladbach', 'Gladbach Observatory'] appears [1, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Berlin', 'Observatory'] appears [3664, 3881] times in full text data.
# ['Berlin Observatory'] appears [29] times in full text data.
# --------------------------------------------------------------------------------
# ['Besançon', 'Observatory'] appears [8, 3881] times in full text data.
# ['Besançon Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['BESS'] appears [974] times in full text data.
# [] appears [] times in full text data.
# --------------------------------------------------------------------------------
# ['Bidston', 'Observatory'] appears [3, 3881] times in full text data.
# ['Bidston Observatory'] appears [1] times in full text data.
# --------------------------------------------------------------------------------
# ['Big', 'Bear', 'Lake', 'Solar', 'Observatory'] appears [6753, 4153, 5251, 7758, 3881] times in full text data.
# ['Big Bear', 'Bear Lake', 'Lake Solar', 'Solar Observatory'] appears [16, 22, 0, 245] times in full text data.
# --------------------------------------------------------------------------------
# ['Bisdee', 'Tier', 'Optical', 'Astronomy', 'Observatory'] appears [0, 3930, 7021, 2145, 3881] times in full text data.
# ['Bisdee Tier', 'Tier Optical', 'Optical Astronomy', 'Astronomy Observatory'] appears [0, 0, 11, 15] times in full text data.
# --------------------------------------------------------------------------------
# ['Black', 'Moshannon', 'Observatory', '(defunct)'] appears [10856, 1, 3881, 0] times in full text data.
# ['Black Moshannon', 'Moshannon Observatory', 'Observatory (defunct)'] appears [0, 0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Blackett', 'Observatory'] appears [54, 3881] times in full text data.
# ['Blackett Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Blue', 'Mesa', 'Observatory', '(defunct)'] appears [9405, 387, 3881, 0] times in full text data.
# ['Blue Mesa', 'Mesa Observatory', 'Observatory (defunct)'] appears [0, 0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Boambee', 'Observatory'] appears [0, 3881] times in full text data.
# ['Boambee Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bohyunsan', 'Optical', 'Astronomy', 'Observatory', '(BOAO)'] appears [0, 7021, 2145, 3881, 0] times in full text data.
# ['Bohyunsan Optical', 'Optical Astronomy', 'Astronomy Observatory', 'Observatory (BOAO)'] appears [0, 11, 15, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['BOOTES'] appears [11] times in full text data.
# [] appears [] times in full text data.
# --------------------------------------------------------------------------------
# ['Bordeaux', 'Observatory'] appears [182, 3881] times in full text data.
# ['Bordeaux Observatory'] appears [1] times in full text data.
# --------------------------------------------------------------------------------
# ['Bosscha', 'Observatory'] appears [2, 3881] times in full text data.
# ['Bosscha Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Boswell', 'Observatory', '(defunct)'] appears [34, 3881, 0] times in full text data.
# ['Boswell Observatory', 'Observatory (defunct)'] appears [0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bowman', 'Observatory'] appears [860, 3881] times in full text data.
# ['Bowman Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Boyden', 'Observatory'] appears [30, 3881] times in full text data.
# ['Boyden Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bradstreet', 'Observatory'] appears [11, 3881] times in full text data.
# ['Bradstreet Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bradley', 'Observatory'] appears [605, 3881] times in full text data.
# ['Bradley Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Braeside', 'Observatory', '(defunct)'] appears [0, 3881, 0] times in full text data.
# ['Braeside Observatory', 'Observatory (defunct)'] appears [0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Brera', 'Observatory'] appears [185, 3881] times in full text data.
# ['Brera Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bridgewater', 'State', 'University', 'Observatory'] appears [10, 18939, 18790, 3881] times in full text data.
# ['Bridgewater State', 'State University', 'University Observatory'] appears [0, 1771, 65] times in full text data.
# --------------------------------------------------------------------------------
# ['Brooks', 'Observatory'] appears [1146, 3881] times in full text data.
# ['Brooks Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Brooks', 'Astronomical', 'Observatory'] appears [1146, 2206, 3881] times in full text data.
# ['Brooks Astronomical', 'Astronomical Observatory'] appears [0, 139] times in full text data.
# --------------------------------------------------------------------------------
# ['Brorfelde', 'Observatory'] appears [1, 3881] times in full text data.
# ['Brorfelde Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bucharest', 'Observatory'] appears [146, 3881] times in full text data.
# ['Bucharest Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Bucknell', 'Observatory'] appears [5, 3881] times in full text data.
# ['Bucknell Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Burrell', 'Memorial', 'Observatory'] appears [24, 855, 3881] times in full text data.
# ['Burrell Memorial', 'Memorial Observatory'] appears [0, 5] times in full text data.
# --------------------------------------------------------------------------------
# ['Byurakan', 'Observatory'] appears [2, 3881] times in full text data.
# ['Byurakan Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Cagigal', 'Observatory'] appears [1, 3881] times in full text data.
# ['Cagigal Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Cagliari', 'Observatory'] appears [54, 3881] times in full text data.
# ['Cagliari Observatory'] appears [1] times in full text data.
# --------------------------------------------------------------------------------
# ['Calais', 'Observatory', '(defunct)'] appears [69, 3881, 0] times in full text data.
# ['Calais Observatory', 'Observatory (defunct)'] appears [0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Calar', 'Alto', 'Observatory'] appears [1495, 2916, 3881] times in full text data.
# ['Calar Alto', 'Alto Observatory'] appears [3, 4] times in full text data.
# --------------------------------------------------------------------------------
# ['Caltech', 'Submillimeter', 'Observatory', '(defunct)'] appears [189, 116, 3881, 0] times in full text data.
# ['Caltech Submillimeter', 'Submillimeter Observatory', 'Observatory (defunct)'] appears [1, 1, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Cambridge', 'Observatory'] appears [5588, 3881] times in full text data.
# ['Cambridge Observatory'] appears [12] times in full text data.
# --------------------------------------------------------------------------------
# ['Camille', 'Flammarion', 'Observatory'] appears [76, 35, 3881] times in full text data.
# ['Camille Flammarion', 'Flammarion Observatory'] appears [7, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Campbelltown', 'Rotary', 'Observatory'] appears [3, 290, 3881] times in full text data.
# ['Campbelltown Rotary', 'Rotary Observatory'] appears [0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Campo', 'Imperatore', 'Near-Earth', 'Object', 'Survey'] appears [929, 8, 213, 9996, 7134] times in full text data.
# ['Campo Imperatore', 'Imperatore Near-Earth', 'Near-Earth Object', 'Object Survey'] appears [1, 0, 8, 3] times in full text data.
# --------------------------------------------------------------------------------
# ['Canopus', 'Hill', 'Observatory'] appears [50, 7665, 3881] times in full text data.
# ['Canopus Hill', 'Hill Observatory'] appears [0, 68] times in full text data.
# --------------------------------------------------------------------------------
# ['Capilla', 'Peak', 'Observatory'] appears [501, 11241, 3881] times in full text data.
# ['Capilla Peak', 'Peak Observatory'] appears [0, 10] times in full text data.
# --------------------------------------------------------------------------------
# ['Capodimonte', 'Observatory'] appears [5, 3881] times in full text data.
# ['Capodimonte Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Carter', 'Observatory'] appears [757, 3881] times in full text data.
# ['Carter Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Catania', 'Astrophysical', 'Observatory'] appears [244, 901, 3881] times in full text data.
# ['Catania Astrophysical', 'Astrophysical Observatory'] appears [1, 179] times in full text data.
# --------------------------------------------------------------------------------
# ['Cawthron', 'Atkinson', 'Observatory'] appears [2, 680, 3881] times in full text data.
# ['Cawthron Atkinson', 'Atkinson Observatory'] appears [0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Celestial', 'Observatory'] appears [556, 3881] times in full text data.
# ['Celestial Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Centennial', 'Observatory'] appears [577, 3881] times in full text data.
# ['Centennial Observatory'] appears [0] times in full text data.
# --------------------------------------------------------------------------------
# ['Center', 'for', 'Astrophysics', '|', 'Harvard', '&', 'Smithsonian'] appears [12720, 24844, 863, 6340, 1823, 10103, 675] times in full text data.
# ['Center for', 'for Astrophysics', 'Astrophysics |', '| Harvard', 'Harvard &', '& Smithsonian'] appears [3210, 114, 1, 1, 0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Cerro', 'Armazones', 'Observatory'] appears [157, 3, 3881] times in full text data.
# ['Cerro Armazones', 'Armazones Observatory'] appears [2, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Cerro', 'Tololo', 'Inter-American', 'Observatory'] appears [157, 11, 11, 3881] times in full text data.
# ['Cerro Tololo', 'Tololo Inter-American', 'Inter-American Observatory'] appears [7, 1, 1] times in full text data.
# --------------------------------------------------------------------------------
# ['Cerro', 'Pachón', 'Observatory'] appears [157, 1, 3881] times in full text data.
# ['Cerro Pachón', 'Pachón Observatory'] appears [0, 0] times in full text data.
# --------------------------------------------------------------------------------
# ['Chabot', 'Space', '&', 'Science', 'Center'] appears [47, 14059, 10103, 21180, 12720] times in full text data.
# ['Chabot Space', 'Space &', '& Science', 'Science Center'] appears [0, 15, 31, 202] times in full text data.
# --------------------------------------------------------------------------------
# ['Chamberlin', 'Observatory'] appears [245, 3881] times in full text data.
# ['Chamberlin Observatory'] appears [21] times in full text data.
# --------------------------------------------------------------------------------
# ['Changchun', 'Astronomical', 'Observatory'] appears [98, 2206, 3881] times in full text data.
# ['Changchun Astronomical', 'Astronomical Observatory'] appears [0, 139] times in full text data.
# --------------------------------------------------------------------------------
# ['Chandra', 'X-ray', 'Observatory'] appears [866, 1225, 3881] times in full text data.
# ['Chandra X-ray', 'X-ray Observatory'] appears [6, 8] times in full text data.
# --------------------------------------------------------------------------------
# ['Chianti', 'Polifunctional', 'Observatory'] appears [20, 0, 3881] times in full text data.

# %%
def get_indices(full_text, pattern):
    """Return indices of rows in full_text containing the pattern."""
    return set(full_text[full_text.str.contains(re.escape(pattern), case=False, na=False)].index.tolist())

# Collect indices of all rows that contain any bigram
all_bigram_indices = set()

for label in Labels['Labels']:
    bigrams = generate_bigrams(label)
    for bigram in bigrams:
        all_bigram_indices.update(get_indices(full_text, bigram))

# Determine indices of rows that don't contain any bigram
no_bigram_indices = set(full_text.index) - all_bigram_indices

# Display results
print(f"Number of rows that don't contain any bigram: {len(no_bigram_indices)}")
print(f"Indices of rows without any bigrams: {sorted(list(no_bigram_indices))}")

# %% [markdown]
# # Labeling Task

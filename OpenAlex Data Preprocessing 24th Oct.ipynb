# %%
import pandas as pd

# Read the CSV
df = pd.read_csv('preprocessed_data_Jul14.csv')

# %%
# Filter out rows where all columns are identical
df = df[df.ne(df.iloc[:, 0], axis=0).any(axis=1)]

# %%
df
# Out:
#                            concept_id                           work_id  \
# 0      https://openalex.org/C44870925  https://openalex.org/W1993867637
# 1      https://openalex.org/C44870925  https://openalex.org/W2022503540
# 2      https://openalex.org/C44870925  https://openalex.org/W2077626606
# 3       https://openalex.org/C1276947  https://openalex.org/W3104346433
# 4      https://openalex.org/C44870925  https://openalex.org/W2081151530
# ...                               ...                               ...
# 63994  https://openalex.org/C44870925  https://openalex.org/W3102168087
# 63995   https://openalex.org/C1276947  https://openalex.org/W3098886327
# 63996  https://openalex.org/C44870925  https://openalex.org/W3093754290
# 63997  https://openalex.org/C44870925  https://openalex.org/W3121322575
# 63998   https://openalex.org/C1276947  https://openalex.org/W3106172125
#
#        publication_year                                              title  \
# ...

# %%
# Save the preprocessed data
df.to_csv('preprocessed_data_Jul14_cleaned.csv', index=False)
